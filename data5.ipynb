# %%
import numpy as np
import scipy.io 
import theano.tensor as T
import lasagne
import string
import theano
import BatchNormLayer
import matplotlib.pylab as plt
batch_norm = BatchNormLayer.batch_norm
# Out:
# Using gpu device 2: GeForce GTX TITAN Black (CNMeM is disabled, CuDNN 3007)
# /home/zli/2016/ntm-lasagne/src/theano/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
############# TrainData and TestData Preparation #############

# trainx: 780*50*6 
# trainy: 780*52 or 780
# mask_train: 780*50
loaddata = scipy.io.loadmat('../dataset/Data5.mat')
traindata = loaddata['TrainData']
testdata = loaddata['TestData']

trainx = []
trainy = []

for i in xrange(traindata.shape[0]):
	for j in xrange(traindata.shape[1]):
		trainx.append(traindata[i][j])
		trainy.append(i)

trainx = np.asarray(trainx)
trainy = np.asarray(trainy)
mask_train = np.ones([trainx.shape[0], trainx.shape[1]])
#print trainy.shape
#print trainy

# testx: 624*20*6
# testy: 624*52 or 624
# mask_test: 624*20
testx = []
testy = []

for i in xrange(testdata.shape[0]):
	for j in xrange(testdata.shape[1]):
		testx.append(testdata[i][j])
		testy.append(i)

testx = np.asarray(testx)
testy = np.asarray(testy)
mask_test = np.ones([testx.shape[0], testx.shape[1]])
#print testy.shape
#print testy

# %%
##########  Initialize Parameters ########
N_BATCH = 52
MAX_LENGTH = trainx.shape[1]
features_num = 6
GRAD_CLIP = 100
TOL = 1e-5
LEARNING_RATE = 1e-2
N_HIDDEN = 120
num_epochs = 300

##########  Build Model for Prediction #######################
mask = np.ones([N_BATCH, MAX_LENGTH])
target_values = T.ivector('target_output')
sym_mask = T.matrix('mask')

print("Building network ...")

l_in = lasagne.layers.InputLayer(shape=(N_BATCH, MAX_LENGTH, features_num))
#l_mask = lasagne.layers.InputLayer(shape=(N_BATCH, MAX_LENGTH))
#### Bidirectional RNN layers ###
l_forward = lasagne.layers.GRULayer(
        l_in, N_HIDDEN, grad_clipping=GRAD_CLIP, only_return_final=True)
        #W_in_to_hid=lasagne.init.HeUniform(),
        #W_hid_to_hid=lasagne.init.HeUniform(),
        #nonlinearity=lasagne.nonlinearities.tanh, only_return_final=True)

l_backward = lasagne.layers.GRULayer(
        l_in, N_HIDDEN, grad_clipping=GRAD_CLIP, only_return_final=True, backwards=True)
        #W_in_to_hid=lasagne.init.HeUniform(),
        #W_hid_to_hid=lasagne.init.HeUniform(),
        #nonlinearity=lasagne.nonlinearities.tanh,
        #only_return_final=True, backwards=True)


l_concat = lasagne.layers.ConcatLayer([l_forward, l_backward])
l_concat = batch_norm(l_concat)

###  Softmax for prediction output ######
l_fc1 = lasagne.layers.DenseLayer(
	    lasagne.layers.dropout(l_concat, p=.5),
        num_units=100, nonlinearity=lasagne.nonlinearities.rectify)
l_fc1 = batch_norm(l_fc1)

l_out = lasagne.layers.DenseLayer(
	    lasagne.layers.dropout(l_fc1, p=.5),
        num_units=52, nonlinearity=lasagne.nonlinearities.softmax)
# Out:
# Building network ...

# %%
########### Debug ###########
all_layers = lasagne.layers.get_all_layers(l_out)
num_params = lasagne.layers.count_params(l_out)
print("  number of parameters: %d" % num_params)
print("  layer output shapes:")
for layer in all_layers:
	name = string.ljust(layer.__class__.__name__, 32)
	print("    %s %s" % (name, lasagne.layers.get_output_shape(layer)))

############## Compile the model, calculate cost, update ######################
#########  #######
network_output = lasagne.layers.get_output(l_out)

out_train = lasagne.layers.get_output(l_out, mask = sym_mask, deterministic=False)

out_test = lasagne.layers.get_output(l_out, mask = sym_mask, deterministic=True)

cost = T.nnet.categorical_crossentropy(T.clip(network_output, TOL, 1-TOL), target_values)
cost = cost.mean()
# Retrieve all parameters from the network
all_params = lasagne.layers.get_all_params(l_out, trainable=True)

all_grads = T.grad(cost, all_params)

updates, norm_calc = lasagne.updates.total_norm_constraint(all_grads, max_norm= 20, return_norm=True)

# Compute SGD updates for training
print("Computing updates ...")
#updates = lasagne.updates.adagrad(cost, all_params, LEARNING_RATE)
updates = lasagne.updates.adam(cost, all_params, LEARNING_RATE)

print("Compiling functions ...")
train = theano.function([l_in.input_var, target_values, sym_mask], \
	                    [cost, out_train], updates=updates, \
	                    on_unused_input='ignore', allow_input_downcast=True)
#compute_cost = theano.function([l_in.input_var, target_values, l_mask.input_var], cost)
test = theano.function([l_in.input_var, target_values, sym_mask], \
                        [cost, out_test], on_unused_input='ignore', allow_input_downcast=True)
# Out:
#   number of parameters: 122292
#   layer output shapes:
#     InputLayer                       (52, 50, 6)
#     GRULayer                         (52, 120)
#     GRULayer                         (52, 120)
#     ConcatLayer                      (52, 240)
#     BatchNormLayer                   (52, 240)
#     DropoutLayer                     (52, 240)
#     DenseLayer                       (52, 100)
#     BatchNormLayer                   (52, 100)
#     NonlinearityLayer                (52, 100)
#     DropoutLayer                     (52, 100)
#     DenseLayer                       (52, 52)
# Computing updates ...
# Compiling functions ...

# %%
print("Training ...")
seq_names = np.arange(0, trainx.shape[0])
np.random.shuffle(seq_names)
trainx = trainx[seq_names]
trainy = trainy[seq_names]  
mask_train = mask_train[seq_names]
cost_train = []
out_train = []
EPOCH_SIZE_TRAIN = trainx.shape[0]// N_BATCH
accuracy_train = []

seq_names_test = np.arange(0, testx.shape[0])
np.random.shuffle(seq_names_test)
testx = testx[seq_names_test]
testy = testy[seq_names_test]  
mask_test = mask_test[seq_names_test]
cost_test = []
out_test = []
EPOCH_SIZE_TEST = testx.shape[0]// N_BATCH
accuracy_test = []

for epoch in range(num_epochs):
	### Train part ###
    out_train_epoch = []
    cost_train_epoch = 0
    for i in xrange(EPOCH_SIZE_TRAIN):
    	idx = xrange(i*N_BATCH, (i+1)*N_BATCH)
    	x_batch = trainx[idx]
    	y_batch = trainy[idx]
    	mask_batch = mask_train[idx]

    	cost_train_batch, out_train_batch = train(x_batch, y_batch, mask_batch)
    	out_train_epoch.append(out_train_batch)
    	cost_train_epoch += cost_train_batch

    out_train_epoch = np.asarray(out_train_epoch)
    out_train_epoch = out_train_epoch.reshape(-1, 52)    
    out_train.append(out_train_epoch)
    cost_train.append(cost_train_epoch)
    ### Accuracy calculation ####
    sum = 0
    for i in xrange(out_train_epoch.shape[0]):
    	predict_label = np.argmax(out_train_epoch[i,:])
    	if predict_label == trainy[i]:
    		sum += 1
    accuracytrain = float(sum)/float(out_train_epoch.shape[0])
    accuracy_train.append(accuracytrain)
    print("Epoch {} train cost = {}".format(epoch, cost_train_epoch))
    print("Epoch {} train accuracy = {}".format(epoch, accuracytrain))

    ### Inference Part ###
    out_test_epoch = []
    cost_test_epoch = 0
    for i in range(EPOCH_SIZE_TEST):
		idx = range(i*N_BATCH, (i+1)*N_BATCH)
		x_batch = testx[idx]
		y_batch = testy[idx]
		mask_batch = mask_test[idx]

		cost_test_batch, out_test_batch = test(x_batch, y_batch, mask_batch)
		out_test_epoch.append(out_test_batch)
		cost_test_epoch += cost_test_batch

    out_test_epoch = np.asarray(out_test_epoch)
    out_test_epoch = out_test_epoch.reshape(-1, 52)
    out_test.append(out_test_epoch)
    cost_test.append(cost_test_epoch)
    #print out_test_epoch.shape
    #print out_test_epoch
    ### Accuracy calculation ####
    sum = 0
    for i in xrange(out_test_epoch.shape[0]):
    	predict_label = np.argmax(out_test_epoch[i,:])
    	if predict_label == testy[i]:
    		sum += 1
    accuracytest = float(sum)/float(out_test_epoch.shape[0])
    accuracy_test.append(accuracytest)
    print("Epoch {} test cost = {}".format(epoch, cost_test_epoch))
    print("Epoch {} test accuracy = {}".format(epoch, accuracytest))
# Out:
# Training ...
# Epoch 0 train cost = 57.5078237057
# Epoch 0 train accuracy = 0.0692307692308
# Epoch 0 test cost = 36.5215771198
# Epoch 0 test accuracy = 0.0512820512821
# Epoch 1 train cost = 40.3378696442
# Epoch 1 train accuracy = 0.235897435897
# Epoch 1 test cost = 28.8539078236
# Epoch 1 test accuracy = 0.0560897435897
# Epoch 2 train cost = 30.7596378326
# Epoch 2 train accuracy = 0.379487179487
# Epoch 2 test cost = 23.418325901
# Epoch 2 test accuracy = 0.233974358974
# Epoch 3 train cost = 24.9328368902
# Epoch 3 train accuracy = 0.467948717949
# Epoch 3 test cost = 20.5192832947
# Epoch 3 test accuracy = 0.310897435897
# Epoch 4 train cost = 21.9520534277
# Epoch 4 train accuracy = 0.530769230769
# Epoch 4 test cost = 18.01872015
# Epoch 4 test accuracy = 0.453525641026
# Epoch 5 train cost = 19.3049503565
# Epoch 5 train accuracy = 0.548717948718
# Epoch 5 test cost = 17.2645460367
# Epoch 5 test accuracy = 0.469551282051
# Epoch 6 train cost = 18.4345536232
# Epoch 6 train accuracy = 0.597435897436
# Epoch 6 test cost = 15.7545548677
# Epoch 6 test accuracy = 0.310897435897
# Epoch 7 train cost = 15.9639667869
# Epoch 7 train accuracy = 0.612820512821
# Epoch 7 test cost = 14.8323659897
# Epoch 7 test accuracy = 0.379807692308
# Epoch 8 train cost = 15.9603523612
# Epoch 8 train accuracy = 0.667948717949
# Epoch 8 test cost = 13.917834878
# Epoch 8 test accuracy = 0.626602564103
# Epoch 9 train cost = 14.7642914653
# Epoch 9 train accuracy = 0.670512820513
# Epoch 9 test cost = 14.7190830112
# Epoch 9 test accuracy = 0.608974358974
# Epoch 10 train cost = 14.5359625816
# Epoch 10 train accuracy = 0.674358974359
# Epoch 10 test cost = 14.1258890629
# Epoch 10 test accuracy = 0.572115384615
# Epoch 11 train cost = 13.0502023101
# Epoch 11 train accuracy = 0.7
# Epoch 11 test cost = 14.5886082053
# Epoch 11 test accuracy = 0.653846153846
# Epoch 12 train cost = 12.7544617653
# Epoch 12 train accuracy = 0.691025641026
# Epoch 12 test cost = 12.9463821054
# Epoch 12 test accuracy = 0.629807692308
# Epoch 13 train cost = 11.9507873654
# Epoch 13 train accuracy = 0.738461538462
# Epoch 13 test cost = 13.1527870893
# Epoch 13 test accuracy = 0.668269230769
# Epoch 14 train cost = 12.2897328734
# Epoch 14 train accuracy = 0.734615384615
# Epoch 14 test cost = 11.9584320784
# Epoch 14 test accuracy = 0.6875
# Epoch 15 train cost = 9.94774001837
# Epoch 15 train accuracy = 0.762820512821
# Epoch 15 test cost = 12.9035326242
# Epoch 15 test accuracy = 0.727564102564
# Epoch 16 train cost = 10.7952218652
# Epoch 16 train accuracy = 0.760256410256
# Epoch 16 test cost = 13.3357634544
# Epoch 16 test accuracy = 0.692307692308
# Epoch 17 train cost = 10.0204844177
# Epoch 17 train accuracy = 0.747435897436
# Epoch 17 test cost = 13.065420568
# Epoch 17 test accuracy = 0.674679487179
# Epoch 18 train cost = 10.754668057
# Epoch 18 train accuracy = 0.753846153846
# Epoch 18 test cost = 12.5870348215
# Epoch 18 test accuracy = 0.758012820513
# Epoch 19 train cost = 10.154676199
# Epoch 19 train accuracy = 0.779487179487
# Epoch 19 test cost = 11.9116067886
# Epoch 19 test accuracy = 0.774038461538
# Epoch 20 train cost = 10.7369001508
# Epoch 20 train accuracy = 0.775641025641
# Epoch 20 test cost = 10.9782173634
# Epoch 20 test accuracy = 0.762820512821
# Epoch 21 train cost = 10.3729865849
# Epoch 21 train accuracy = 0.747435897436
# Epoch 21 test cost = 10.5704286098
# Epoch 21 test accuracy = 0.772435897436
# Epoch 22 train cost = 8.48288947344
# Epoch 22 train accuracy = 0.812820512821
# Epoch 22 test cost = 10.594720006
# Epoch 22 test accuracy = 0.865384615385
# Epoch 23 train cost = 7.9368301034
# Epoch 23 train accuracy = 0.811538461538
# Epoch 23 test cost = 11.0964567065
# Epoch 23 test accuracy = 0.838141025641
# Epoch 24 train cost = 7.59991148114
# Epoch 24 train accuracy = 0.796153846154
# Epoch 24 test cost = 10.4434469342
# Epoch 24 test accuracy = 0.834935897436
# Epoch 25 train cost = 7.95169633627
# Epoch 25 train accuracy = 0.802564102564
# Epoch 25 test cost = 9.98849564791
# Epoch 25 test accuracy = 0.830128205128
# Epoch 26 train cost = 7.27015912533
# Epoch 26 train accuracy = 0.812820512821
# Epoch 26 test cost = 10.052577734
# Epoch 26 test accuracy = 0.844551282051
# Epoch 27 train cost = 6.7939247787
# Epoch 27 train accuracy = 0.857692307692
# Epoch 27 test cost = 9.90574592352
# Epoch 27 test accuracy = 0.855769230769
# Epoch 28 train cost = 6.89675746858
# Epoch 28 train accuracy = 0.839743589744
# Epoch 28 test cost = 9.59233689308
# Epoch 28 test accuracy = 0.809294871795
# Epoch 29 train cost = 6.20554238558
# Epoch 29 train accuracy = 0.825641025641
# Epoch 29 test cost = 9.0918200314
# Epoch 29 test accuracy = 0.847756410256
# Epoch 30 train cost = 6.54943332076
# Epoch 30 train accuracy = 0.875641025641
# Epoch 30 test cost = 9.21187138557
# Epoch 30 test accuracy = 0.891025641026
# Epoch 31 train cost = 6.16947580874
# Epoch 31 train accuracy = 0.870512820513
# Epoch 31 test cost = 8.93588262796
# Epoch 31 test accuracy = 0.863782051282
# Epoch 32 train cost = 5.9648655355
# Epoch 32 train accuracy = 0.852564102564
# Epoch 32 test cost = 9.63149183989
# Epoch 32 test accuracy = 0.834935897436
# Epoch 33 train cost = 5.4342469424
# Epoch 33 train accuracy = 0.852564102564
# Epoch 33 test cost = 10.6365170479
# Epoch 33 test accuracy = 0.810897435897
# Epoch 34 train cost = 6.20957776904
# Epoch 34 train accuracy = 0.862820512821
# Epoch 34 test cost = 9.39973187447
# Epoch 34 test accuracy = 0.886217948718
# Epoch 35 train cost = 5.49642679095
# Epoch 35 train accuracy = 0.887179487179
# Epoch 35 test cost = 8.42927712202
# Epoch 35 test accuracy = 0.910256410256
# Epoch 36 train cost = 5.40393137932
# Epoch 36 train accuracy = 0.870512820513
# Epoch 36 test cost = 9.09835427999
# Epoch 36 test accuracy = 0.875
# Epoch 37 train cost = 5.56395789981
# Epoch 37 train accuracy = 0.867948717949
# Epoch 37 test cost = 9.39869517088
# Epoch 37 test accuracy = 0.883012820513
# Epoch 38 train cost = 5.26573255658
# Epoch 38 train accuracy = 0.873076923077
# Epoch 38 test cost = 9.51680603623
# Epoch 38 test accuracy = 0.873397435897
# Epoch 39 train cost = 5.43766662478
# Epoch 39 train accuracy = 0.873076923077
# Epoch 39 test cost = 9.2557644248
# Epoch 39 test accuracy = 0.849358974359
# Epoch 40 train cost = 5.51973466575
# Epoch 40 train accuracy = 0.862820512821
# Epoch 40 test cost = 7.93593478203
# Epoch 40 test accuracy = 0.850961538462
# Epoch 41 train cost = 5.61472086608
# Epoch 41 train accuracy = 0.894871794872
# Epoch 41 test cost = 9.38254758716
# Epoch 41 test accuracy = 0.850961538462
# Epoch 42 train cost = 5.01675595343
# Epoch 42 train accuracy = 0.888461538462
# Epoch 42 test cost = 8.37331682444
# Epoch 42 test accuracy = 0.855769230769
# Epoch 43 train cost = 4.27429814637
# Epoch 43 train accuracy = 0.9
# Epoch 43 test cost = 8.33917668462
# Epoch 43 test accuracy = 0.873397435897
# Epoch 44 train cost = 5.5207529217
# Epoch 44 train accuracy = 0.880769230769
# Epoch 44 test cost = 8.0220233202
# Epoch 44 test accuracy = 0.897435897436
# Epoch 45 train cost = 5.20721288025
# Epoch 45 train accuracy = 0.897435897436
# Epoch 45 test cost = 9.50897097588
# Epoch 45 test accuracy = 0.889423076923
# Epoch 46 train cost = 5.81273344159
# Epoch 46 train accuracy = 0.874358974359
# Epoch 46 test cost = 8.79346746206
# Epoch 46 test accuracy = 0.858974358974
# Epoch 47 train cost = 5.07189901173
# Epoch 47 train accuracy = 0.866666666667
# Epoch 47 test cost = 7.61879843473
# Epoch 47 test accuracy = 0.863782051282
# Epoch 48 train cost = 4.33291102946
# Epoch 48 train accuracy = 0.884615384615
# Epoch 48 test cost = 10.2329685986
# Epoch 48 test accuracy = 0.852564102564
# Epoch 49 train cost = 4.11088883877
# Epoch 49 train accuracy = 0.901282051282
# Epoch 49 test cost = 8.50029662251
# Epoch 49 test accuracy = 0.884615384615
# Epoch 50 train cost = 4.53842259943
# Epoch 50 train accuracy = 0.905128205128
# Epoch 50 test cost = 8.21898338199
# Epoch 50 test accuracy = 0.887820512821
# Epoch 51 train cost = 3.87018692493
# Epoch 51 train accuracy = 0.911538461538
# Epoch 51 test cost = 8.0827639401
# Epoch 51 test accuracy = 0.916666666667
# Epoch 52 train cost = 4.45452475548
# Epoch 52 train accuracy = 0.9
# Epoch 52 test cost = 9.15700957179
# Epoch 52 test accuracy = 0.883012820513
# Epoch 53 train cost = 4.6350312233
# Epoch 53 train accuracy = 0.907692307692
# Epoch 53 test cost = 8.63249304891
# Epoch 53 test accuracy = 0.892628205128
# Epoch 54 train cost = 4.06375746429
# Epoch 54 train accuracy = 0.914102564103
# Epoch 54 test cost = 7.43606841564
# Epoch 54 test accuracy = 0.907051282051
# Epoch 55 train cost = 3.72247645259
# Epoch 55 train accuracy = 0.905128205128
# Epoch 55 test cost = 7.77946034074
# Epoch 55 test accuracy = 0.918269230769
# Epoch 56 train cost = 3.79190371931
# Epoch 56 train accuracy = 0.908974358974
# Epoch 56 test cost = 8.93558496237
# Epoch 56 test accuracy = 0.879807692308
# Epoch 57 train cost = 3.25522345304
# Epoch 57 train accuracy = 0.920512820513
# Epoch 57 test cost = 9.2763196826
# Epoch 57 test accuracy = 0.895833333333
# Epoch 58 train cost = 3.65002483875
# Epoch 58 train accuracy = 0.912820512821
# Epoch 58 test cost = 10.0191987753
# Epoch 58 test accuracy = 0.839743589744
# Epoch 59 train cost = 3.91687080264
# Epoch 59 train accuracy = 0.907692307692
# Epoch 59 test cost = 7.81499934196
# Epoch 59 test accuracy = 0.871794871795
# Epoch 60 train cost = 3.36108895391
# Epoch 60 train accuracy = 0.921794871795
# Epoch 60 test cost = 7.5466453433
# Epoch 60 test accuracy = 0.921474358974
# Epoch 61 train cost = 2.83568461239
# Epoch 61 train accuracy = 0.919230769231
# Epoch 61 test cost = 7.31881463528
# Epoch 61 test accuracy = 0.921474358974
# Epoch 62 train cost = 3.25169340521
# Epoch 62 train accuracy = 0.928205128205
# Epoch 62 test cost = 8.0769148469
# Epoch 62 test accuracy = 0.907051282051
# Epoch 63 train cost = 3.40317453817
# Epoch 63 train accuracy = 0.894871794872
# Epoch 63 test cost = 7.32876226306
# Epoch 63 test accuracy = 0.919871794872
# Epoch 64 train cost = 4.07554832101
# Epoch 64 train accuracy = 0.916666666667
# Epoch 64 test cost = 7.68586316705
# Epoch 64 test accuracy = 0.891025641026
# Epoch 65 train cost = 3.41755248606
# Epoch 65 train accuracy = 0.9
# Epoch 65 test cost = 9.52415585518
# Epoch 65 test accuracy = 0.884615384615
# Epoch 66 train cost = 3.89562854171
# Epoch 66 train accuracy = 0.896153846154
# Epoch 66 test cost = 8.32510390878
# Epoch 66 test accuracy = 0.905448717949
# Epoch 67 train cost = 4.05324225128
# Epoch 67 train accuracy = 0.933333333333
# Epoch 67 test cost = 7.39363914728
# Epoch 67 test accuracy = 0.915064102564
# Epoch 68 train cost = 3.53797031939
# Epoch 68 train accuracy = 0.910256410256
# Epoch 68 test cost = 7.77035614848
# Epoch 68 test accuracy = 0.902243589744
# Epoch 69 train cost = 3.63526575267
# Epoch 69 train accuracy = 0.920512820513
# Epoch 69 test cost = 8.04042905569
# Epoch 69 test accuracy = 0.891025641026
# Epoch 70 train cost = 4.02008424699
# Epoch 70 train accuracy = 0.90641025641
# Epoch 70 test cost = 8.36920011044
# Epoch 70 test accuracy = 0.903846153846
# Epoch 71 train cost = 3.67475228012
# Epoch 71 train accuracy = 0.930769230769
# Epoch 71 test cost = 8.39658650756
# Epoch 71 test accuracy = 0.905448717949
# Epoch 72 train cost = 2.96864489466
# Epoch 72 train accuracy = 0.914102564103
# Epoch 72 test cost = 7.67604160309
# Epoch 72 test accuracy = 0.886217948718
# Epoch 73 train cost = 3.48146062344
# Epoch 73 train accuracy = 0.9
# Epoch 73 test cost = 7.33422985673
# Epoch 73 test accuracy = 0.919871794872
# Epoch 74 train cost = 3.68877483159
# Epoch 74 train accuracy = 0.925641025641
# Epoch 74 test cost = 7.89361602068
# Epoch 74 test accuracy = 0.887820512821
# Epoch 75 train cost = 3.44735063612
# Epoch 75 train accuracy = 0.896153846154
# Epoch 75 test cost = 7.9169254005
# Epoch 75 test accuracy = 0.903846153846
# Epoch 76 train cost = 3.02940315753
# Epoch 76 train accuracy = 0.935897435897
# Epoch 76 test cost = 7.05753821135
# Epoch 76 test accuracy = 0.927884615385
# Epoch 77 train cost = 3.14273710549
# Epoch 77 train accuracy = 0.930769230769
# Epoch 77 test cost = 7.18949604034
# Epoch 77 test accuracy = 0.93108974359
# Epoch 78 train cost = 2.40554546565
# Epoch 78 train accuracy = 0.917948717949
# Epoch 78 test cost = 8.04919064045
# Epoch 78 test accuracy = 0.900641025641
# Epoch 79 train cost = 3.59087483585
# Epoch 79 train accuracy = 0.917948717949
# Epoch 79 test cost = 8.04613181949
# Epoch 79 test accuracy = 0.908653846154
# Epoch 80 train cost = 3.52200509608
# Epoch 80 train accuracy = 0.908974358974
# Epoch 80 test cost = 7.89851146936
# Epoch 80 test accuracy = 0.883012820513
# Epoch 81 train cost = 3.26462741941
# Epoch 81 train accuracy = 0.929487179487
# Epoch 81 test cost = 7.71179407835
# Epoch 81 test accuracy = 0.899038461538
# Epoch 82 train cost = 3.03775884211
# Epoch 82 train accuracy = 0.928205128205
# Epoch 82 test cost = 7.38643270731
# Epoch 82 test accuracy = 0.916666666667
# Epoch 83 train cost = 3.31328205019
# Epoch 83 train accuracy = 0.934615384615
# Epoch 83 test cost = 8.37107342482
# Epoch 83 test accuracy = 0.913461538462
# Epoch 84 train cost = 2.738890104
# Epoch 84 train accuracy = 0.930769230769
# Epoch 84 test cost = 9.33569046855
# Epoch 84 test accuracy = 0.876602564103
# Epoch 85 train cost = 2.81313889846
# Epoch 85 train accuracy = 0.939743589744
# Epoch 85 test cost = 9.51653006673
# Epoch 85 test accuracy = 0.883012820513
# Epoch 86 train cost = 2.92966013402
# Epoch 86 train accuracy = 0.942307692308
# Epoch 86 test cost = 7.81641435623
# Epoch 86 test accuracy = 0.923076923077
# Epoch 87 train cost = 2.8416390568
# Epoch 87 train accuracy = 0.937179487179
# Epoch 87 test cost = 7.14126682281
# Epoch 87 test accuracy = 0.924679487179
# Epoch 88 train cost = 3.00222232938
# Epoch 88 train accuracy = 0.94358974359
# Epoch 88 test cost = 8.62292093039
# Epoch 88 test accuracy = 0.921474358974
# Epoch 89 train cost = 2.58910974115
# Epoch 89 train accuracy = 0.932051282051
# Epoch 89 test cost = 8.68323367834
# Epoch 89 test accuracy = 0.902243589744
# Epoch 90 train cost = 2.85699189827
# Epoch 90 train accuracy = 0.929487179487
# Epoch 90 test cost = 8.96166735888
# Epoch 90 test accuracy = 0.902243589744
# Epoch 91 train cost = 3.25137446821
# Epoch 91 train accuracy = 0.923076923077
# Epoch 91 test cost = 7.44729700685
# Epoch 91 test accuracy = 0.891025641026
# Epoch 92 train cost = 2.55016514659
# Epoch 92 train accuracy = 0.921794871795
# Epoch 92 test cost = 6.86362683773
# Epoch 92 test accuracy = 0.918269230769
# Epoch 93 train cost = 2.52949312329
# Epoch 93 train accuracy = 0.95
# Epoch 93 test cost = 7.62843835354
# Epoch 93 test accuracy = 0.907051282051
# Epoch 94 train cost = 2.91434593871
# Epoch 94 train accuracy = 0.94358974359
# Epoch 94 test cost = 9.66448140144
# Epoch 94 test accuracy = 0.889423076923
# Epoch 95 train cost = 3.12171155214
# Epoch 95 train accuracy = 0.921794871795
# Epoch 95 test cost = 8.02137601376
# Epoch 95 test accuracy = 0.903846153846
# Epoch 96 train cost = 2.90386390686
# Epoch 96 train accuracy = 0.912820512821
# Epoch 96 test cost = 8.48378267884
# Epoch 96 test accuracy = 0.919871794872
# Epoch 97 train cost = 2.77593082935
# Epoch 97 train accuracy = 0.932051282051
# Epoch 97 test cost = 7.61467647552
# Epoch 97 test accuracy = 0.918269230769
# Epoch 98 train cost = 2.66478661448
# Epoch 98 train accuracy = 0.941025641026
# Epoch 98 test cost = 8.40965938568
# Epoch 98 test accuracy = 0.895833333333
# Epoch 99 train cost = 3.12946702912
# Epoch 99 train accuracy = 0.937179487179
# Epoch 99 test cost = 8.29425893724
# Epoch 99 test accuracy = 0.900641025641
# Epoch 100 train cost = 3.69952012971
# Epoch 100 train accuracy = 0.923076923077
# Epoch 100 test cost = 8.00154578686
# Epoch 100 test accuracy = 0.918269230769
# Epoch 101 train cost = 3.33981084824
# Epoch 101 train accuracy = 0.933333333333
# Epoch 101 test cost = 8.27906388044
# Epoch 101 test accuracy = 0.915064102564
# Epoch 102 train cost = 2.32567224652
# Epoch 102 train accuracy = 0.941025641026
# Epoch 102 test cost = 9.33511310816
# Epoch 102 test accuracy = 0.905448717949
# Epoch 103 train cost = 2.39347157627
# Epoch 103 train accuracy = 0.948717948718
# Epoch 103 test cost = 6.59753128886
# Epoch 103 test accuracy = 0.910256410256
# Epoch 104 train cost = 2.26243929565
# Epoch 104 train accuracy = 0.942307692308
# Epoch 104 test cost = 7.96826720238
# Epoch 104 test accuracy = 0.923076923077
# Epoch 105 train cost = 2.40888199955
# Epoch 105 train accuracy = 0.947435897436
# Epoch 105 test cost = 7.76760736108
# Epoch 105 test accuracy = 0.934294871795
# Epoch 106 train cost = 2.744363904
# Epoch 106 train accuracy = 0.958974358974
# Epoch 106 test cost = 6.85673576593
# Epoch 106 test accuracy = 0.93108974359
# Epoch 107 train cost = 1.94308134168
# Epoch 107 train accuracy = 0.930769230769
# Epoch 107 test cost = 8.16605645418
# Epoch 107 test accuracy = 0.923076923077
# Epoch 108 train cost = 2.19016548619
# Epoch 108 train accuracy = 0.933333333333
# Epoch 108 test cost = 8.02287128568
# Epoch 108 test accuracy = 0.919871794872
# Epoch 109 train cost = 1.90344891325
# Epoch 109 train accuracy = 0.932051282051
# Epoch 109 test cost = 8.60677030683
# Epoch 109 test accuracy = 0.894230769231
# Epoch 110 train cost = 2.43412297592
# Epoch 110 train accuracy = 0.948717948718
# Epoch 110 test cost = 6.22886520624
# Epoch 110 test accuracy = 0.919871794872
# Epoch 111 train cost = 1.75147687644
# Epoch 111 train accuracy = 0.939743589744
# Epoch 111 test cost = 7.81305037439
# Epoch 111 test accuracy = 0.923076923077
# Epoch 112 train cost = 2.35994433239
# Epoch 112 train accuracy = 0.94358974359
# Epoch 112 test cost = 7.02720057964
# Epoch 112 test accuracy = 0.919871794872
# Epoch 113 train cost = 1.78483900614
# Epoch 113 train accuracy = 0.947435897436
# Epoch 113 test cost = 6.76067426801
# Epoch 113 test accuracy = 0.924679487179
# Epoch 114 train cost = 2.39936279505
# Epoch 114 train accuracy = 0.941025641026
# Epoch 114 test cost = 8.18335840106
# Epoch 114 test accuracy = 0.900641025641
# Epoch 115 train cost = 2.48269892484
# Epoch 115 train accuracy = 0.94358974359
# Epoch 115 test cost = 7.44824677706
# Epoch 115 test accuracy = 0.918269230769
# Epoch 116 train cost = 2.77735579386
# Epoch 116 train accuracy = 0.939743589744
# Epoch 116 test cost = 8.27169266343
# Epoch 116 test accuracy = 0.886217948718
# Epoch 117 train cost = 2.87821618095
# Epoch 117 train accuracy = 0.929487179487
# Epoch 117 test cost = 8.95835536718
# Epoch 117 test accuracy = 0.894230769231
# Epoch 118 train cost = 2.95882353932
# Epoch 118 train accuracy = 0.919230769231
# Epoch 118 test cost = 9.29596072435
# Epoch 118 test accuracy = 0.86858974359
# Epoch 119 train cost = 3.33799395338
# Epoch 119 train accuracy = 0.934615384615
# Epoch 119 test cost = 8.7025821805
# Epoch 119 test accuracy = 0.883012820513
# Epoch 120 train cost = 3.23532368243
# Epoch 120 train accuracy = 0.933333333333
# Epoch 120 test cost = 8.58193892241
# Epoch 120 test accuracy = 0.905448717949
# Epoch 121 train cost = 2.41296803951
# Epoch 121 train accuracy = 0.942307692308
# Epoch 121 test cost = 8.58859242499
# Epoch 121 test accuracy = 0.892628205128
# Epoch 122 train cost = 3.04682343639
# Epoch 122 train accuracy = 0.923076923077
# Epoch 122 test cost = 7.22557374835
# Epoch 122 test accuracy = 0.927884615385
# Epoch 123 train cost = 2.17156647891
# Epoch 123 train accuracy = 0.955128205128
# Epoch 123 test cost = 7.33994796872
# Epoch 123 test accuracy = 0.926282051282
# Epoch 124 train cost = 2.07981871441
# Epoch 124 train accuracy = 0.944871794872
# Epoch 124 test cost = 7.23909923434
# Epoch 124 test accuracy = 0.927884615385
# Epoch 125 train cost = 2.42975474894
# Epoch 125 train accuracy = 0.94358974359
# Epoch 125 test cost = 6.82942417264
# Epoch 125 test accuracy = 0.929487179487
# Epoch 126 train cost = 2.29742174409
# Epoch 126 train accuracy = 0.969230769231
# Epoch 126 test cost = 7.20068344474
# Epoch 126 test accuracy = 0.9375
# Epoch 127 train cost = 2.20951690525
# Epoch 127 train accuracy = 0.947435897436
# Epoch 127 test cost = 7.38889843225
# Epoch 127 test accuracy = 0.929487179487
# Epoch 128 train cost = 2.11881690845
# Epoch 128 train accuracy = 0.952564102564
# Epoch 128 test cost = 6.5240329802
# Epoch 128 test accuracy = 0.935897435897
# Epoch 129 train cost = 1.75233894959
# Epoch 129 train accuracy = 0.94358974359
# Epoch 129 test cost = 7.11607828736
# Epoch 129 test accuracy = 0.927884615385
# Epoch 130 train cost = 1.99795059115
# Epoch 130 train accuracy = 0.962820512821
# Epoch 130 test cost = 7.65615543723
# Epoch 130 test accuracy = 0.934294871795
# Epoch 131 train cost = 1.6087843813
# Epoch 131 train accuracy = 0.957692307692
# Epoch 131 test cost = 6.95458309352
# Epoch 131 test accuracy = 0.924679487179
# Epoch 132 train cost = 1.63940890133
# Epoch 132 train accuracy = 0.95
# Epoch 132 test cost = 7.35697257519
# Epoch 132 test accuracy = 0.942307692308
# Epoch 133 train cost = 1.49891489744
# Epoch 133 train accuracy = 0.962820512821
# Epoch 133 test cost = 7.355554685
# Epoch 133 test accuracy = 0.927884615385
# Epoch 134 train cost = 1.72155913338
# Epoch 134 train accuracy = 0.965384615385
# Epoch 134 test cost = 7.74310804904
# Epoch 134 test accuracy = 0.939102564103
# Epoch 135 train cost = 1.96819934249
# Epoch 135 train accuracy = 0.944871794872
# Epoch 135 test cost = 7.43225758523
# Epoch 135 test accuracy = 0.926282051282
# Epoch 136 train cost = 2.01515256241
# Epoch 136 train accuracy = 0.95641025641
# Epoch 136 test cost = 7.897482723
# Epoch 136 test accuracy = 0.929487179487
# Epoch 137 train cost = 2.07266342826
# Epoch 137 train accuracy = 0.948717948718
# Epoch 137 test cost = 7.7097478807
# Epoch 137 test accuracy = 0.923076923077
# Epoch 138 train cost = 1.86406763643
# Epoch 138 train accuracy = 0.95641025641
# Epoch 138 test cost = 5.84639668465
# Epoch 138 test accuracy = 0.910256410256
# Epoch 139 train cost = 1.84201228246
# Epoch 139 train accuracy = 0.960256410256
# Epoch 139 test cost = 6.92212946713
# Epoch 139 test accuracy = 0.919871794872
# Epoch 140 train cost = 1.98047717474
# Epoch 140 train accuracy = 0.953846153846
# Epoch 140 test cost = 6.16263027489
# Epoch 140 test accuracy = 0.926282051282
# Epoch 141 train cost = 1.89559360594
# Epoch 141 train accuracy = 0.95641025641
# Epoch 141 test cost = 8.49043244123
# Epoch 141 test accuracy = 0.934294871795
# Epoch 142 train cost = 2.16253339127
# Epoch 142 train accuracy = 0.946153846154
# Epoch 142 test cost = 9.11119258404
# Epoch 142 test accuracy = 0.908653846154
# Epoch 143 train cost = 1.90657873265
# Epoch 143 train accuracy = 0.947435897436
# Epoch 143 test cost = 7.58898358792
# Epoch 143 test accuracy = 0.897435897436
# Epoch 144 train cost = 2.63174368441
# Epoch 144 train accuracy = 0.942307692308
# Epoch 144 test cost = 7.57017275691
# Epoch 144 test accuracy = 0.894230769231
# Epoch 145 train cost = 2.1357552968
# Epoch 145 train accuracy = 0.95
# Epoch 145 test cost = 8.33458521962
# Epoch 145 test accuracy = 0.913461538462
# Epoch 146 train cost = 2.70644841343
# Epoch 146 train accuracy = 0.94358974359
# Epoch 146 test cost = 7.98553442955
# Epoch 146 test accuracy = 0.93108974359
# Epoch 147 train cost = 1.64416749217
# Epoch 147 train accuracy = 0.966666666667
# Epoch 147 test cost = 6.8023416698
# Epoch 147 test accuracy = 0.934294871795
# Epoch 148 train cost = 1.91189282015
# Epoch 148 train accuracy = 0.941025641026
# Epoch 148 test cost = 8.77791410685
# Epoch 148 test accuracy = 0.927884615385
# Epoch 149 train cost = 2.63396849856
# Epoch 149 train accuracy = 0.947435897436
# Epoch 149 test cost = 7.26070162654
# Epoch 149 test accuracy = 0.913461538462
# Epoch 150 train cost = 1.7088906467
# Epoch 150 train accuracy = 0.958974358974
# Epoch 150 test cost = 5.78236091137
# Epoch 150 test accuracy = 0.942307692308
# Epoch 151 train cost = 2.07787084207
# Epoch 151 train accuracy = 0.951282051282
# Epoch 151 test cost = 7.28827629983
# Epoch 151 test accuracy = 0.935897435897
# Epoch 152 train cost = 1.53890451789
# Epoch 152 train accuracy = 0.970512820513
# Epoch 152 test cost = 6.04850825667
# Epoch 152 test accuracy = 0.934294871795
# Epoch 153 train cost = 1.78057143092
# Epoch 153 train accuracy = 0.953846153846
# Epoch 153 test cost = 6.94572916627
# Epoch 153 test accuracy = 0.910256410256
# Epoch 154 train cost = 1.39680529945
# Epoch 154 train accuracy = 0.955128205128
# Epoch 154 test cost = 6.80782049894
# Epoch 154 test accuracy = 0.935897435897
# Epoch 155 train cost = 1.33264238387
# Epoch 155 train accuracy = 0.961538461538
# Epoch 155 test cost = 6.92700125277
# Epoch 155 test accuracy = 0.940705128205
# Epoch 156 train cost = 1.13913832605
# Epoch 156 train accuracy = 0.948717948718
# Epoch 156 test cost = 7.5475307107
# Epoch 156 test accuracy = 0.926282051282
# Epoch 157 train cost = 1.6207486093
# Epoch 157 train accuracy = 0.962820512821
# Epoch 157 test cost = 6.35288390517
# Epoch 157 test accuracy = 0.924679487179
# Epoch 158 train cost = 1.75323802978
# Epoch 158 train accuracy = 0.967948717949
# Epoch 158 test cost = 7.68654885888
# Epoch 158 test accuracy = 0.929487179487
# Epoch 159 train cost = 2.14210409671
# Epoch 159 train accuracy = 0.958974358974
# Epoch 159 test cost = 6.93058294058
# Epoch 159 test accuracy = 0.93108974359
# Epoch 160 train cost = 1.82616782747
# Epoch 160 train accuracy = 0.957692307692
# Epoch 160 test cost = 8.15560622513
# Epoch 160 test accuracy = 0.923076923077
# Epoch 161 train cost = 2.05384803563
# Epoch 161 train accuracy = 0.970512820513
# Epoch 161 test cost = 6.82314093411
# Epoch 161 test accuracy = 0.948717948718
# Epoch 162 train cost = 2.23045148142
# Epoch 162 train accuracy = 0.953846153846
# Epoch 162 test cost = 6.85376834869
# Epoch 162 test accuracy = 0.932692307692
# Epoch 163 train cost = 1.4267199859
# Epoch 163 train accuracy = 0.953846153846
# Epoch 163 test cost = 8.0139092505
# Epoch 163 test accuracy = 0.910256410256
# Epoch 164 train cost = 1.86197518557
# Epoch 164 train accuracy = 0.962820512821
# Epoch 164 test cost = 7.50779762864
# Epoch 164 test accuracy = 0.921474358974
# Epoch 165 train cost = 1.56250791997
# Epoch 165 train accuracy = 0.967948717949
# Epoch 165 test cost = 7.99578234553
# Epoch 165 test accuracy = 0.905448717949
# Epoch 166 train cost = 1.37570288591
# Epoch 166 train accuracy = 0.966666666667
# Epoch 166 test cost = 7.24255275726
# Epoch 166 test accuracy = 0.910256410256
# Epoch 167 train cost = 1.98159506172
# Epoch 167 train accuracy = 0.951282051282
# Epoch 167 test cost = 6.71729451418
# Epoch 167 test accuracy = 0.929487179487
# Epoch 168 train cost = 1.78338971734
# Epoch 168 train accuracy = 0.957692307692
# Epoch 168 test cost = 6.59194709361
# Epoch 168 test accuracy = 0.934294871795
# Epoch 169 train cost = 1.7619736623
# Epoch 169 train accuracy = 0.966666666667
# Epoch 169 test cost = 7.03875173628
# Epoch 169 test accuracy = 0.939102564103
# Epoch 170 train cost = 1.18458041549
# Epoch 170 train accuracy = 0.964102564103
# Epoch 170 test cost = 6.683024019
# Epoch 170 test accuracy = 0.932692307692
# Epoch 171 train cost = 1.29616540857
# Epoch 171 train accuracy = 0.95641025641
# Epoch 171 test cost = 7.06902223825
# Epoch 171 test accuracy = 0.934294871795
# Epoch 172 train cost = 1.44868757483
# Epoch 172 train accuracy = 0.974358974359
# Epoch 172 test cost = 7.119877249
# Epoch 172 test accuracy = 0.940705128205
# Epoch 173 train cost = 1.83140680753
# Epoch 173 train accuracy = 0.965384615385
# Epoch 173 test cost = 7.54212747514
# Epoch 173 test accuracy = 0.942307692308
# Epoch 174 train cost = 1.54680851847
# Epoch 174 train accuracy = 0.962820512821
# Epoch 174 test cost = 7.6904733032
# Epoch 174 test accuracy = 0.942307692308
# Epoch 175 train cost = 1.38167878427
# Epoch 175 train accuracy = 0.964102564103
# Epoch 175 test cost = 6.58770819008
# Epoch 175 test accuracy = 0.939102564103
# Epoch 176 train cost = 1.94876486436
# Epoch 176 train accuracy = 0.965384615385
# Epoch 176 test cost = 6.84637382627
# Epoch 176 test accuracy = 0.9375
# Epoch 177 train cost = 1.69056518562
# Epoch 177 train accuracy = 0.946153846154
# Epoch 177 test cost = 8.05423894525
# Epoch 177 test accuracy = 0.939102564103
# Epoch 178 train cost = 1.77639095113
# Epoch 178 train accuracy = 0.955128205128
# Epoch 178 test cost = 7.41489513218
# Epoch 178 test accuracy = 0.913461538462
# Epoch 179 train cost = 2.07520240732
# Epoch 179 train accuracy = 0.957692307692
# Epoch 179 test cost = 8.93907153606
# Epoch 179 test accuracy = 0.924679487179
# Epoch 180 train cost = 2.10033314675
# Epoch 180 train accuracy = 0.957692307692
# Epoch 180 test cost = 7.63288763165
# Epoch 180 test accuracy = 0.900641025641
# Epoch 181 train cost = 1.71753030457
# Epoch 181 train accuracy = 0.95641025641
# Epoch 181 test cost = 7.92632424831
# Epoch 181 test accuracy = 0.93108974359
# Epoch 182 train cost = 1.90433768183
# Epoch 182 train accuracy = 0.944871794872
# Epoch 182 test cost = 7.27019754052
# Epoch 182 test accuracy = 0.93108974359
# Epoch 183 train cost = 2.00030367821
# Epoch 183 train accuracy = 0.952564102564
# Epoch 183 test cost = 7.86122864485
# Epoch 183 test accuracy = 0.923076923077
# Epoch 184 train cost = 1.61039486155
# Epoch 184 train accuracy = 0.953846153846
# Epoch 184 test cost = 8.13431364298
# Epoch 184 test accuracy = 0.932692307692
# Epoch 185 train cost = 1.61978545412
# Epoch 185 train accuracy = 0.961538461538
# Epoch 185 test cost = 7.03631421924
# Epoch 185 test accuracy = 0.926282051282
# Epoch 186 train cost = 1.58253215812
# Epoch 186 train accuracy = 0.970512820513
# Epoch 186 test cost = 7.02403026819
# Epoch 186 test accuracy = 0.9375
# Epoch 187 train cost = 1.78733260185
# Epoch 187 train accuracy = 0.965384615385
# Epoch 187 test cost = 7.11004000902
# Epoch 187 test accuracy = 0.942307692308
# Epoch 188 train cost = 1.65898896195
# Epoch 188 train accuracy = 0.967948717949
# Epoch 188 test cost = 7.38642826676
# Epoch 188 test accuracy = 0.927884615385
# Epoch 189 train cost = 1.57024532557
# Epoch 189 train accuracy = 0.946153846154
# Epoch 189 test cost = 7.71244627237
# Epoch 189 test accuracy = 0.94391025641
# Epoch 190 train cost = 1.34000456613
# Epoch 190 train accuracy = 0.964102564103
# Epoch 190 test cost = 7.28833307326
# Epoch 190 test accuracy = 0.940705128205
# Epoch 191 train cost = 1.57193114422
# Epoch 191 train accuracy = 0.967948717949
# Epoch 191 test cost = 6.71250110865
# Epoch 191 test accuracy = 0.939102564103
# Epoch 192 train cost = 1.19141920051
# Epoch 192 train accuracy = 0.975641025641
# Epoch 192 test cost = 7.16759419441
# Epoch 192 test accuracy = 0.948717948718
# Epoch 193 train cost = 1.17783792131
# Epoch 193 train accuracy = 0.970512820513
# Epoch 193 test cost = 7.85336202383
# Epoch 193 test accuracy = 0.924679487179
# Epoch 194 train cost = 1.43251542421
# Epoch 194 train accuracy = 0.957692307692
# Epoch 194 test cost = 6.43768485636
# Epoch 194 test accuracy = 0.929487179487
# Epoch 195 train cost = 1.8870834019
# Epoch 195 train accuracy = 0.965384615385
# Epoch 195 test cost = 7.51496964693
# Epoch 195 test accuracy = 0.93108974359
# Epoch 196 train cost = 1.73939714395
# Epoch 196 train accuracy = 0.973076923077
# Epoch 196 test cost = 6.8155272603
# Epoch 196 test accuracy = 0.94391025641
# Epoch 197 train cost = 1.12056956999
# Epoch 197 train accuracy = 0.961538461538
# Epoch 197 test cost = 7.12154462934
# Epoch 197 test accuracy = 0.950320512821
# Epoch 198 train cost = 1.80117360316
# Epoch 198 train accuracy = 0.965384615385
# Epoch 198 test cost = 8.88125783205
# Epoch 198 test accuracy = 0.911858974359
# Epoch 199 train cost = 1.75944867358
# Epoch 199 train accuracy = 0.964102564103
# Epoch 199 test cost = 7.21172060072
# Epoch 199 test accuracy = 0.935897435897
# Epoch 200 train cost = 1.23561878223
# Epoch 200 train accuracy = 0.966666666667
# Epoch 200 test cost = 6.40463766456
# Epoch 200 test accuracy = 0.942307692308
# Epoch 201 train cost = 1.46448419616
# Epoch 201 train accuracy = 0.969230769231
# Epoch 201 test cost = 7.07664881647
# Epoch 201 test accuracy = 0.948717948718
# Epoch 202 train cost = 1.54609882459
# Epoch 202 train accuracy = 0.973076923077
# Epoch 202 test cost = 7.50407293439
# Epoch 202 test accuracy = 0.929487179487
# Epoch 203 train cost = 1.45369033515
# Epoch 203 train accuracy = 0.961538461538
# Epoch 203 test cost = 6.99358794093
# Epoch 203 test accuracy = 0.9375
# Epoch 204 train cost = 1.46752744168
# Epoch 204 train accuracy = 0.966666666667
# Epoch 204 test cost = 8.00531443954
# Epoch 204 test accuracy = 0.932692307692
# Epoch 205 train cost = 1.28114462644
# Epoch 205 train accuracy = 0.960256410256
# Epoch 205 test cost = 7.60702836514
# Epoch 205 test accuracy = 0.940705128205
# Epoch 206 train cost = 1.21389525943
# Epoch 206 train accuracy = 0.966666666667
# Epoch 206 test cost = 7.27295258641
# Epoch 206 test accuracy = 0.947115384615
# Epoch 207 train cost = 2.06088061817
# Epoch 207 train accuracy = 0.976923076923
# Epoch 207 test cost = 6.38917660713
# Epoch 207 test accuracy = 0.9375
# Epoch 208 train cost = 1.47322503477
# Epoch 208 train accuracy = 0.957692307692
# Epoch 208 test cost = 7.37044864148
# Epoch 208 test accuracy = 0.929487179487
# Epoch 209 train cost = 1.52584875934
# Epoch 209 train accuracy = 0.964102564103
# Epoch 209 test cost = 8.01663455367
# Epoch 209 test accuracy = 0.919871794872
# Epoch 210 train cost = 2.43325129524
# Epoch 210 train accuracy = 0.965384615385
# Epoch 210 test cost = 8.09325045347
# Epoch 210 test accuracy = 0.915064102564
# Epoch 211 train cost = 2.42874781042
# Epoch 211 train accuracy = 0.953846153846
# Epoch 211 test cost = 7.95085519552
# Epoch 211 test accuracy = 0.93108974359
# Epoch 212 train cost = 2.07293321192
# Epoch 212 train accuracy = 0.958974358974
# Epoch 212 test cost = 7.65589356422
# Epoch 212 test accuracy = 0.93108974359
# Epoch 213 train cost = 1.82615359989
# Epoch 213 train accuracy = 0.965384615385
# Epoch 213 test cost = 7.07760776579
# Epoch 213 test accuracy = 0.913461538462
# Epoch 214 train cost = 1.80120564252
# Epoch 214 train accuracy = 0.952564102564
# Epoch 214 test cost = 7.09073701501
# Epoch 214 test accuracy = 0.916666666667
# Epoch 215 train cost = 1.98611120693
# Epoch 215 train accuracy = 0.95641025641
# Epoch 215 test cost = 7.02655225992
# Epoch 215 test accuracy = 0.939102564103
# Epoch 216 train cost = 1.34518590197
# Epoch 216 train accuracy = 0.967948717949
# Epoch 216 test cost = 7.42285078764
# Epoch 216 test accuracy = 0.932692307692
# Epoch 217 train cost = 1.12584631238
# Epoch 217 train accuracy = 0.962820512821
# Epoch 217 test cost = 8.41934868693
# Epoch 217 test accuracy = 0.927884615385
# Epoch 218 train cost = 1.73051294591
# Epoch 218 train accuracy = 0.962820512821
# Epoch 218 test cost = 7.05780915916
# Epoch 218 test accuracy = 0.927884615385
# Epoch 219 train cost = 1.28267789632
# Epoch 219 train accuracy = 0.970512820513
# Epoch 219 test cost = 8.29845272005
# Epoch 219 test accuracy = 0.93108974359
# Epoch 220 train cost = 1.52151839249
# Epoch 220 train accuracy = 0.960256410256
# Epoch 220 test cost = 7.87911966443
# Epoch 220 test accuracy = 0.913461538462
# Epoch 221 train cost = 2.06285764836
# Epoch 221 train accuracy = 0.953846153846
# Epoch 221 test cost = 7.87840870023
# Epoch 221 test accuracy = 0.921474358974
# Epoch 222 train cost = 1.85997166298
# Epoch 222 train accuracy = 0.962820512821
# Epoch 222 test cost = 7.30699699745
# Epoch 222 test accuracy = 0.935897435897
# Epoch 223 train cost = 1.89292653091
# Epoch 223 train accuracy = 0.953846153846
# Epoch 223 test cost = 8.44294691086
# Epoch 223 test accuracy = 0.919871794872
# Epoch 224 train cost = 1.76031523198
# Epoch 224 train accuracy = 0.961538461538
# Epoch 224 test cost = 7.70517638326
# Epoch 224 test accuracy = 0.932692307692
# Epoch 225 train cost = 1.55258800648
# Epoch 225 train accuracy = 0.973076923077
# Epoch 225 test cost = 7.476793468
# Epoch 225 test accuracy = 0.94391025641
# Epoch 226 train cost = 1.04512608051
# Epoch 226 train accuracy = 0.971794871795
# Epoch 226 test cost = 7.81667709351
# Epoch 226 test accuracy = 0.9375
# Epoch 227 train cost = 1.06900658831
# Epoch 227 train accuracy = 0.974358974359
# Epoch 227 test cost = 6.95861661434
# Epoch 227 test accuracy = 0.945512820513
# Epoch 228 train cost = 1.06924346555
# Epoch 228 train accuracy = 0.975641025641
# Epoch 228 test cost = 6.88756608963
# Epoch 228 test accuracy = 0.942307692308
# Epoch 229 train cost = 1.11310818233
# Epoch 229 train accuracy = 0.987179487179
# Epoch 229 test cost = 6.92240520939
# Epoch 229 test accuracy = 0.94391025641
# Epoch 230 train cost = 0.670548868366
# Epoch 230 train accuracy = 0.971794871795
# Epoch 230 test cost = 5.86125746369
# Epoch 230 test accuracy = 0.948717948718
# Epoch 231 train cost = 1.0858348324
# Epoch 231 train accuracy = 0.975641025641
# Epoch 231 test cost = 7.93613941967
# Epoch 231 test accuracy = 0.927884615385
# Epoch 232 train cost = 1.08721043263
# Epoch 232 train accuracy = 0.971794871795
# Epoch 232 test cost = 7.75116980076
# Epoch 232 test accuracy = 0.93108974359
# Epoch 233 train cost = 1.1375785172
# Epoch 233 train accuracy = 0.974358974359
# Epoch 233 test cost = 8.71933595836
# Epoch 233 test accuracy = 0.935897435897
# Epoch 234 train cost = 1.31249304535
# Epoch 234 train accuracy = 0.970512820513
# Epoch 234 test cost = 7.01941388845
# Epoch 234 test accuracy = 0.934294871795
# Epoch 235 train cost = 1.15807489678
# Epoch 235 train accuracy = 0.966666666667
# Epoch 235 test cost = 7.11784616113
# Epoch 235 test accuracy = 0.932692307692
# Epoch 236 train cost = 1.15070677828
# Epoch 236 train accuracy = 0.966666666667
# Epoch 236 test cost = 7.53510513902
# Epoch 236 test accuracy = 0.93108974359
# Epoch 237 train cost = 1.24345480278
# Epoch 237 train accuracy = 0.957692307692
# Epoch 237 test cost = 7.58509796858
# Epoch 237 test accuracy = 0.921474358974
# Epoch 238 train cost = 1.21856101975
# Epoch 238 train accuracy = 0.965384615385
# Epoch 238 test cost = 7.19058218598
# Epoch 238 test accuracy = 0.916666666667
# Epoch 239 train cost = 1.61945115402
# Epoch 239 train accuracy = 0.960256410256
# Epoch 239 test cost = 7.26742114127
# Epoch 239 test accuracy = 0.932692307692
# Epoch 240 train cost = 2.00803320203
# Epoch 240 train accuracy = 0.961538461538
# Epoch 240 test cost = 6.83798953891
# Epoch 240 test accuracy = 0.9375
# Epoch 241 train cost = 1.62636693753
# Epoch 241 train accuracy = 0.964102564103
# Epoch 241 test cost = 6.71011272073
# Epoch 241 test accuracy = 0.942307692308
# Epoch 242 train cost = 1.54585668165
# Epoch 242 train accuracy = 0.966666666667
# Epoch 242 test cost = 7.03584419191
# Epoch 242 test accuracy = 0.939102564103
# Epoch 243 train cost = 1.84642134095
# Epoch 243 train accuracy = 0.962820512821
# Epoch 243 test cost = 8.47558671236
# Epoch 243 test accuracy = 0.940705128205
# Epoch 244 train cost = 1.18004304543
# Epoch 244 train accuracy = 0.967948717949
# Epoch 244 test cost = 7.42412471771
# Epoch 244 test accuracy = 0.94391025641
# Epoch 245 train cost = 1.67267522309
# Epoch 245 train accuracy = 0.962820512821
# Epoch 245 test cost = 6.33402490616
# Epoch 245 test accuracy = 0.929487179487
# Epoch 246 train cost = 1.66661402397
# Epoch 246 train accuracy = 0.962820512821
# Epoch 246 test cost = 6.79101754725
# Epoch 246 test accuracy = 0.932692307692
# Epoch 247 train cost = 1.69482634496
# Epoch 247 train accuracy = 0.964102564103
# Epoch 247 test cost = 7.92004463077
# Epoch 247 test accuracy = 0.929487179487
# Epoch 248 train cost = 1.86760194786
# Epoch 248 train accuracy = 0.965384615385
# Epoch 248 test cost = 7.64213728905
# Epoch 248 test accuracy = 0.939102564103
# Epoch 249 train cost = 1.58620735072
# Epoch 249 train accuracy = 0.961538461538
# Epoch 249 test cost = 6.5035739392
# Epoch 249 test accuracy = 0.932692307692
# Epoch 250 train cost = 1.88307383563
# Epoch 250 train accuracy = 0.962820512821
# Epoch 250 test cost = 7.57290239632
# Epoch 250 test accuracy = 0.919871794872
# Epoch 251 train cost = 1.92038169689
# Epoch 251 train accuracy = 0.965384615385
# Epoch 251 test cost = 7.91111472249
# Epoch 251 test accuracy = 0.93108974359
# Epoch 252 train cost = 1.38850828633
# Epoch 252 train accuracy = 0.946153846154
# Epoch 252 test cost = 6.95447801054
# Epoch 252 test accuracy = 0.927884615385
# Epoch 253 train cost = 1.4953390602
# Epoch 253 train accuracy = 0.973076923077
# Epoch 253 test cost = 7.35067429394
# Epoch 253 test accuracy = 0.93108974359
# Epoch 254 train cost = 1.48960090242
# Epoch 254 train accuracy = 0.971794871795
# Epoch 254 test cost = 7.93088625371
# Epoch 254 test accuracy = 0.9375
# Epoch 255 train cost = 1.11849714164
# Epoch 255 train accuracy = 0.967948717949
# Epoch 255 test cost = 8.85802677274
# Epoch 255 test accuracy = 0.94391025641
# Epoch 256 train cost = 1.90739216097
# Epoch 256 train accuracy = 0.971794871795
# Epoch 256 test cost = 7.49902302027
# Epoch 256 test accuracy = 0.940705128205
# Epoch 257 train cost = 1.15169921378
# Epoch 257 train accuracy = 0.967948717949
# Epoch 257 test cost = 7.71224024892
# Epoch 257 test accuracy = 0.942307692308
# Epoch 258 train cost = 0.928739080671
# Epoch 258 train accuracy = 0.979487179487
# Epoch 258 test cost = 6.9710688591
# Epoch 258 test accuracy = 0.942307692308
# Epoch 259 train cost = 1.06944769435
# Epoch 259 train accuracy = 0.975641025641
# Epoch 259 test cost = 7.1442411989
# Epoch 259 test accuracy = 0.94391025641
# Epoch 260 train cost = 0.868296412751
# Epoch 260 train accuracy = 0.979487179487
# Epoch 260 test cost = 6.73291639984
# Epoch 260 test accuracy = 0.9375
# Epoch 261 train cost = 1.32240404352
# Epoch 261 train accuracy = 0.973076923077
# Epoch 261 test cost = 7.20685176551
# Epoch 261 test accuracy = 0.927884615385
# Epoch 262 train cost = 1.57525437325
# Epoch 262 train accuracy = 0.974358974359
# Epoch 262 test cost = 8.27032011747
# Epoch 262 test accuracy = 0.93108974359
# Epoch 263 train cost = 1.22762967227
# Epoch 263 train accuracy = 0.967948717949
# Epoch 263 test cost = 6.93632391095
# Epoch 263 test accuracy = 0.942307692308
# Epoch 264 train cost = 1.20398082957
# Epoch 264 train accuracy = 0.971794871795
# Epoch 264 test cost = 6.51754000783
# Epoch 264 test accuracy = 0.945512820513
# Epoch 265 train cost = 1.37727849465
# Epoch 265 train accuracy = 0.967948717949
# Epoch 265 test cost = 6.83201548457
# Epoch 265 test accuracy = 0.950320512821
# Epoch 266 train cost = 1.51107293088
# Epoch 266 train accuracy = 0.987179487179
# Epoch 266 test cost = 8.29638016224
# Epoch 266 test accuracy = 0.908653846154
# Epoch 267 train cost = 1.37502407492
# Epoch 267 train accuracy = 0.971794871795
# Epoch 267 test cost = 7.03707396984
# Epoch 267 test accuracy = 0.9375
# Epoch 268 train cost = 0.696735233068
# Epoch 268 train accuracy = 0.983333333333
# Epoch 268 test cost = 6.91510543227
# Epoch 268 test accuracy = 0.940705128205
# Epoch 269 train cost = 0.91493787244
# Epoch 269 train accuracy = 0.983333333333
# Epoch 269 test cost = 6.21850699186
# Epoch 269 test accuracy = 0.945512820513
# Epoch 270 train cost = 1.01854280103
# Epoch 270 train accuracy = 0.980769230769
# Epoch 270 test cost = 6.57016727328
# Epoch 270 test accuracy = 0.939102564103
# Epoch 271 train cost = 1.32096977904
# Epoch 271 train accuracy = 0.975641025641
# Epoch 271 test cost = 7.42062414438
# Epoch 271 test accuracy = 0.919871794872
# Epoch 272 train cost = 1.27455776371
# Epoch 272 train accuracy = 0.984615384615
# Epoch 272 test cost = 7.56710082293
# Epoch 272 test accuracy = 0.940705128205
# Epoch 273 train cost = 1.17253398057
# Epoch 273 train accuracy = 0.978205128205
# Epoch 273 test cost = 8.02580425143
# Epoch 273 test accuracy = 0.924679487179
# Epoch 274 train cost = 1.21864593495
# Epoch 274 train accuracy = 0.973076923077
# Epoch 274 test cost = 7.65548866987
# Epoch 274 test accuracy = 0.939102564103
# Epoch 275 train cost = 1.06488060765
# Epoch 275 train accuracy = 0.973076923077
# Epoch 275 test cost = 7.98793675005
# Epoch 275 test accuracy = 0.939102564103
# Epoch 276 train cost = 1.35037077963
# Epoch 276 train accuracy = 0.975641025641
# Epoch 276 test cost = 9.61565542221
# Epoch 276 test accuracy = 0.924679487179
# Epoch 277 train cost = 1.37121971883
# Epoch 277 train accuracy = 0.973076923077
# Epoch 277 test cost = 8.28432822227
# Epoch 277 test accuracy = 0.924679487179
# Epoch 278 train cost = 1.22283500805
# Epoch 278 train accuracy = 0.966666666667
# Epoch 278 test cost = 6.99573976547
# Epoch 278 test accuracy = 0.935897435897
# Epoch 279 train cost = 1.43120626174
# Epoch 279 train accuracy = 0.960256410256
# Epoch 279 test cost = 7.49187366664
# Epoch 279 test accuracy = 0.934294871795
# Epoch 280 train cost = 1.71871149633
# Epoch 280 train accuracy = 0.971794871795
# Epoch 280 test cost = 8.30952256918
# Epoch 280 test accuracy = 0.924679487179
# Epoch 281 train cost = 1.30119867623
# Epoch 281 train accuracy = 0.960256410256
# Epoch 281 test cost = 9.11671328545
# Epoch 281 test accuracy = 0.926282051282
# Epoch 282 train cost = 1.39655396529
# Epoch 282 train accuracy = 0.975641025641
# Epoch 282 test cost = 6.9875318706
# Epoch 282 test accuracy = 0.9375
# Epoch 283 train cost = 1.26258649863
# Epoch 283 train accuracy = 0.976923076923
# Epoch 283 test cost = 7.98222241551
# Epoch 283 test accuracy = 0.926282051282
# Epoch 284 train cost = 1.62765773572
# Epoch 284 train accuracy = 0.966666666667
# Epoch 284 test cost = 7.69976258278
# Epoch 284 test accuracy = 0.929487179487
# Epoch 285 train cost = 1.7234554328
# Epoch 285 train accuracy = 0.973076923077
# Epoch 285 test cost = 7.86049515009
# Epoch 285 test accuracy = 0.935897435897
# Epoch 286 train cost = 1.40968458541
# Epoch 286 train accuracy = 0.960256410256
# Epoch 286 test cost = 8.19444552809
# Epoch 286 test accuracy = 0.923076923077
# Epoch 287 train cost = 1.29853941593
# Epoch 287 train accuracy = 0.974358974359
# Epoch 287 test cost = 7.65514416993
# Epoch 287 test accuracy = 0.932692307692
# Epoch 288 train cost = 1.46089578979
# Epoch 288 train accuracy = 0.969230769231
# Epoch 288 test cost = 7.90406623483
# Epoch 288 test accuracy = 0.932692307692
# Epoch 289 train cost = 1.21287667938
# Epoch 289 train accuracy = 0.971794871795
# Epoch 289 test cost = 6.96443626285
# Epoch 289 test accuracy = 0.927884615385
# Epoch 290 train cost = 1.12478309311
# Epoch 290 train accuracy = 0.967948717949
# Epoch 290 test cost = 7.95912863314
# Epoch 290 test accuracy = 0.926282051282
# Epoch 291 train cost = 0.828864831012
# Epoch 291 train accuracy = 0.965384615385
# Epoch 291 test cost = 7.24442541599
# Epoch 291 test accuracy = 0.942307692308
# Epoch 292 train cost = 0.876501311082
# Epoch 292 train accuracy = 0.973076923077
# Epoch 292 test cost = 7.02060598135
# Epoch 292 test accuracy = 0.932692307692
# Epoch 293 train cost = 1.66919852421
# Epoch 293 train accuracy = 0.969230769231
# Epoch 293 test cost = 8.32864914834
# Epoch 293 test accuracy = 0.939102564103
# Epoch 294 train cost = 2.10956325009
# Epoch 294 train accuracy = 0.955128205128
# Epoch 294 test cost = 9.85474419594
# Epoch 294 test accuracy = 0.93108974359
# Epoch 295 train cost = 1.96608191915
# Epoch 295 train accuracy = 0.951282051282
# Epoch 295 test cost = 6.69600561261
# Epoch 295 test accuracy = 0.940705128205
# Epoch 296 train cost = 1.56090580299
# Epoch 296 train accuracy = 0.962820512821
# Epoch 296 test cost = 8.67356106639
# Epoch 296 test accuracy = 0.93108974359
# Epoch 297 train cost = 1.8935524337
# Epoch 297 train accuracy = 0.966666666667
# Epoch 297 test cost = 8.77544724941
# Epoch 297 test accuracy = 0.905448717949
# Epoch 298 train cost = 2.33445092849
# Epoch 298 train accuracy = 0.935897435897
# Epoch 298 test cost = 9.48039746284
# Epoch 298 test accuracy = 0.918269230769
# Epoch 299 train cost = 2.12429659255
# Epoch 299 train accuracy = 0.961538461538
# Epoch 299 test cost = 7.7186755836
# Epoch 299 test accuracy = 0.910256410256

# %%
# %matplotlib inline
plt.figure(1)
plt.plot(cost_train, 'c', cost_test, 'r', linewidth=2.0)
plt.legend(("cost_train", "cost_test"),'upper left')

plt.figure(2)
plt.plot(accuracy_train, 'y', accuracy_test, 'b', linewidth=2.0)
plt.legend(("accuracy_train", "accuracy_test"),'lower left')

print "train max", np.max(accuracy_train), " is at", np.argmax(accuracy_train), "epoch \n"  
print "test max", np.max(accuracy_test), " is at", np.argmax(accuracy_test), "epoch \n"  
#plt.show()
# Out:
# train max 0.987179487179  is at 229 epoch
#
# test max 0.950320512821  is at 197 epoch
# /home/zli/anaconda/lib/python2.7/site-packages/matplotlib/cbook.py:137: MatplotlibDeprecationWarning: The "loc" positional argument to legend is deprecated. Please use the "loc" keyword instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
