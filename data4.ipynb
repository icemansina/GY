# %%
import numpy as np
import scipy.io 
import theano.tensor as T
import lasagne
import string
import theano
import BatchNormLayer
import matplotlib.pylab as plt
batch_norm = BatchNormLayer.batch_norm
# Out:
# Using gpu device 2: GeForce GTX TITAN Black (CNMeM is disabled, CuDNN 3007)
# /home/zli/2016/ntm-lasagne/src/theano/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
############# TrainData and TestData Preparation #############

# trainx: 780*50*6 
# trainy: 780*52 or 780
# mask_train: 780*50
loaddata = scipy.io.loadmat('../dataset/Data4.mat')
traindata = loaddata['TrainData']
testdata = loaddata['TestData']

trainx = []
trainy = []

for i in xrange(traindata.shape[0]):
	for j in xrange(traindata.shape[1]):
		trainx.append(traindata[i][j])
		trainy.append(i)

trainx = np.asarray(trainx)
trainy = np.asarray(trainy)
mask_train = np.ones([trainx.shape[0], trainx.shape[1]])
#print trainy.shape
#print trainy

# testx: 624*20*6
# testy: 624*52 or 624
# mask_test: 624*20
testx = []
testy = []

for i in xrange(testdata.shape[0]):
	for j in xrange(testdata.shape[1]):
		testx.append(testdata[i][j])
		testy.append(i)

testx = np.asarray(testx)
testy = np.asarray(testy)
mask_test = np.ones([testx.shape[0], testx.shape[1]])
#print testy.shape
#print testy

# %%
##########  Initialize Parameters ########
N_BATCH = 52
MAX_LENGTH = trainx.shape[1]
features_num = 6
GRAD_CLIP = 100
TOL = 1e-5
LEARNING_RATE = 1e-2
N_HIDDEN = 120
num_epochs = 300

##########  Build Model for Prediction #######################
mask = np.ones([N_BATCH, MAX_LENGTH])
target_values = T.ivector('target_output')
sym_mask = T.matrix('mask')

print("Building network ...")

l_in = lasagne.layers.InputLayer(shape=(N_BATCH, MAX_LENGTH, features_num))
#l_mask = lasagne.layers.InputLayer(shape=(N_BATCH, MAX_LENGTH))
#### Bidirectional RNN layers ###
l_forward = lasagne.layers.GRULayer(
        l_in, N_HIDDEN, grad_clipping=GRAD_CLIP, only_return_final=True)
        #W_in_to_hid=lasagne.init.HeUniform(),
        #W_hid_to_hid=lasagne.init.HeUniform(),
        #nonlinearity=lasagne.nonlinearities.tanh, only_return_final=True)

l_backward = lasagne.layers.GRULayer(
        l_in, N_HIDDEN, grad_clipping=GRAD_CLIP, only_return_final=True, backwards=True)
        #W_in_to_hid=lasagne.init.HeUniform(),
        #W_hid_to_hid=lasagne.init.HeUniform(),
        #nonlinearity=lasagne.nonlinearities.tanh,
        #only_return_final=True, backwards=True)


l_concat = lasagne.layers.ConcatLayer([l_forward, l_backward])
l_concat = batch_norm(l_concat)

###  Softmax for prediction output ######
l_fc1 = lasagne.layers.DenseLayer(
	    lasagne.layers.dropout(l_concat, p=.5),
        num_units=100, nonlinearity=lasagne.nonlinearities.rectify)
l_fc1 = batch_norm(l_fc1)

l_out = lasagne.layers.DenseLayer(
	    lasagne.layers.dropout(l_fc1, p=.5),
        num_units=52, nonlinearity=lasagne.nonlinearities.softmax)
# Out:
# Building network ...

# %%
########### Debug ###########
all_layers = lasagne.layers.get_all_layers(l_out)
num_params = lasagne.layers.count_params(l_out)
print("  number of parameters: %d" % num_params)
print("  layer output shapes:")
for layer in all_layers:
	name = string.ljust(layer.__class__.__name__, 32)
	print("    %s %s" % (name, lasagne.layers.get_output_shape(layer)))

############## Compile the model, calculate cost, update ######################
#########  #######
network_output = lasagne.layers.get_output(l_out)

out_train = lasagne.layers.get_output(l_out, mask = sym_mask, deterministic=False)

out_test = lasagne.layers.get_output(l_out, mask = sym_mask, deterministic=True)

cost = T.nnet.categorical_crossentropy(T.clip(network_output, TOL, 1-TOL), target_values)
cost = cost.mean()
# Retrieve all parameters from the network
all_params = lasagne.layers.get_all_params(l_out, trainable=True)

all_grads = T.grad(cost, all_params)

updates, norm_calc = lasagne.updates.total_norm_constraint(all_grads, max_norm= 20, return_norm=True)

# Compute SGD updates for training
print("Computing updates ...")
#updates = lasagne.updates.adagrad(cost, all_params, LEARNING_RATE)
updates = lasagne.updates.adam(cost, all_params, LEARNING_RATE)

print("Compiling functions ...")
train = theano.function([l_in.input_var, target_values, sym_mask], \
	                    [cost, out_train], updates=updates, \
	                    on_unused_input='ignore', allow_input_downcast=True)
#compute_cost = theano.function([l_in.input_var, target_values, l_mask.input_var], cost)
test = theano.function([l_in.input_var, target_values, sym_mask], \
                        [cost, out_test], on_unused_input='ignore', allow_input_downcast=True)
# Out:
#   number of parameters: 122292
#   layer output shapes:
#     InputLayer                       (52, 20, 6)
#     GRULayer                         (52, 120)
#     GRULayer                         (52, 120)
#     ConcatLayer                      (52, 240)
#     BatchNormLayer                   (52, 240)
#     DropoutLayer                     (52, 240)
#     DenseLayer                       (52, 100)
#     BatchNormLayer                   (52, 100)
#     NonlinearityLayer                (52, 100)
#     DropoutLayer                     (52, 100)
#     DenseLayer                       (52, 52)
# Computing updates ...
# Compiling functions ...

# %%
print("Training ...")
seq_names = np.arange(0, trainx.shape[0])
np.random.shuffle(seq_names)
trainx = trainx[seq_names]
trainy = trainy[seq_names]  
mask_train = mask_train[seq_names]
cost_train = []
out_train = []
EPOCH_SIZE_TRAIN = trainx.shape[0]// N_BATCH
accuracy_train = []

seq_names_test = np.arange(0, testx.shape[0])
np.random.shuffle(seq_names_test)
testx = testx[seq_names_test]
testy = testy[seq_names_test]  
mask_test = mask_test[seq_names_test]
cost_test = []
out_test = []
EPOCH_SIZE_TEST = testx.shape[0]// N_BATCH
accuracy_test = []

for epoch in range(num_epochs):
	### Train part ###
    out_train_epoch = []
    cost_train_epoch = 0
    for i in xrange(EPOCH_SIZE_TRAIN):
    	idx = xrange(i*N_BATCH, (i+1)*N_BATCH)
    	x_batch = trainx[idx]
    	y_batch = trainy[idx]
    	mask_batch = mask_train[idx]

    	cost_train_batch, out_train_batch = train(x_batch, y_batch, mask_batch)
    	out_train_epoch.append(out_train_batch)
    	cost_train_epoch += cost_train_batch

    out_train_epoch = np.asarray(out_train_epoch)
    out_train_epoch = out_train_epoch.reshape(-1, 52)    
    out_train.append(out_train_epoch)
    cost_train.append(cost_train_epoch)
    ### Accuracy calculation ####
    sum = 0
    for i in xrange(out_train_epoch.shape[0]):
    	predict_label = np.argmax(out_train_epoch[i,:])
    	if predict_label == trainy[i]:
    		sum += 1
    accuracytrain = float(sum)/float(out_train_epoch.shape[0])
    accuracy_train.append(accuracytrain)
    print("Epoch {} train cost = {}".format(epoch, cost_train_epoch))
    print("Epoch {} train accuracy = {}".format(epoch, accuracytrain))

    ### Inference Part ###
    out_test_epoch = []
    cost_test_epoch = 0
    for i in range(EPOCH_SIZE_TEST):
		idx = range(i*N_BATCH, (i+1)*N_BATCH)
		x_batch = testx[idx]
		y_batch = testy[idx]
		mask_batch = mask_test[idx]

		cost_test_batch, out_test_batch = test(x_batch, y_batch, mask_batch)
		out_test_epoch.append(out_test_batch)
		cost_test_epoch += cost_test_batch

    out_test_epoch = np.asarray(out_test_epoch)
    out_test_epoch = out_test_epoch.reshape(-1, 52)
    out_test.append(out_test_epoch)
    cost_test.append(cost_test_epoch)
    #print out_test_epoch.shape
    #print out_test_epoch
    ### Accuracy calculation ####
    sum = 0
    for i in xrange(out_test_epoch.shape[0]):
    	predict_label = np.argmax(out_test_epoch[i,:])
    	if predict_label == testy[i]:
    		sum += 1
    accuracytest = float(sum)/float(out_test_epoch.shape[0])
    accuracy_test.append(accuracytest)
    print("Epoch {} test cost = {}".format(epoch, cost_test_epoch))
    print("Epoch {} test accuracy = {}".format(epoch, accuracytest))
# Out:
# Training ...
# Epoch 0 train cost = 54.1387379169
# Epoch 0 train accuracy = 0.0987179487179
# Epoch 0 test cost = 33.0398356915
# Epoch 0 test accuracy = 0.253205128205
# Epoch 1 train cost = 35.8261034489
# Epoch 1 train accuracy = 0.337179487179
# Epoch 1 test cost = 24.7952896357
# Epoch 1 test accuracy = 0.508012820513
# Epoch 2 train cost = 27.5349873304
# Epoch 2 train accuracy = 0.461538461538
# Epoch 2 test cost = 20.5310879946
# Epoch 2 test accuracy = 0.695512820513
# Epoch 3 train cost = 22.2117625475
# Epoch 3 train accuracy = 0.55641025641
# Epoch 3 test cost = 16.424634099
# Epoch 3 test accuracy = 0.766025641026
# Epoch 4 train cost = 18.3938996196
# Epoch 4 train accuracy = 0.611538461538
# Epoch 4 test cost = 15.5202351809
# Epoch 4 test accuracy = 0.758012820513
# Epoch 5 train cost = 16.0575039983
# Epoch 5 train accuracy = 0.653846153846
# Epoch 5 test cost = 14.0100668073
# Epoch 5 test accuracy = 0.735576923077
# Epoch 6 train cost = 15.3019672632
# Epoch 6 train accuracy = 0.64358974359
# Epoch 6 test cost = 13.4936958551
# Epoch 6 test accuracy = 0.762820512821
# Epoch 7 train cost = 13.7489910126
# Epoch 7 train accuracy = 0.730769230769
# Epoch 7 test cost = 12.9947082996
# Epoch 7 test accuracy = 0.802884615385
# Epoch 8 train cost = 12.323841393
# Epoch 8 train accuracy = 0.702564102564
# Epoch 8 test cost = 12.9672527313
# Epoch 8 test accuracy = 0.758012820513
# Epoch 9 train cost = 11.8622789383
# Epoch 9 train accuracy = 0.730769230769
# Epoch 9 test cost = 11.6365039349
# Epoch 9 test accuracy = 0.796474358974
# Epoch 10 train cost = 10.0395973325
# Epoch 10 train accuracy = 0.770512820513
# Epoch 10 test cost = 11.3265838623
# Epoch 10 test accuracy = 0.850961538462
# Epoch 11 train cost = 10.421215117
# Epoch 11 train accuracy = 0.746153846154
# Epoch 11 test cost = 11.720836401
# Epoch 11 test accuracy = 0.838141025641
# Epoch 12 train cost = 9.11388021708
# Epoch 12 train accuracy = 0.779487179487
# Epoch 12 test cost = 11.7019687295
# Epoch 12 test accuracy = 0.828525641026
# Epoch 13 train cost = 9.47647586465
# Epoch 13 train accuracy = 0.775641025641
# Epoch 13 test cost = 11.2132991552
# Epoch 13 test accuracy = 0.839743589744
# Epoch 14 train cost = 7.95755293965
# Epoch 14 train accuracy = 0.80641025641
# Epoch 14 test cost = 10.0173770785
# Epoch 14 test accuracy = 0.846153846154
# Epoch 15 train cost = 9.10227844119
# Epoch 15 train accuracy = 0.776923076923
# Epoch 15 test cost = 10.5598239303
# Epoch 15 test accuracy = 0.857371794872
# Epoch 16 train cost = 8.44048604369
# Epoch 16 train accuracy = 0.805128205128
# Epoch 16 test cost = 10.3519912958
# Epoch 16 test accuracy = 0.857371794872
# Epoch 17 train cost = 7.95345622301
# Epoch 17 train accuracy = 0.828205128205
# Epoch 17 test cost = 9.14895200729
# Epoch 17 test accuracy = 0.870192307692
# Epoch 18 train cost = 7.52869178355
# Epoch 18 train accuracy = 0.828205128205
# Epoch 18 test cost = 9.16524630785
# Epoch 18 test accuracy = 0.86858974359
# Epoch 19 train cost = 7.64569959044
# Epoch 19 train accuracy = 0.826923076923
# Epoch 19 test cost = 9.85785716772
# Epoch 19 test accuracy = 0.902243589744
# Epoch 20 train cost = 6.42585396767
# Epoch 20 train accuracy = 0.867948717949
# Epoch 20 test cost = 8.93311306834
# Epoch 20 test accuracy = 0.905448717949
# Epoch 21 train cost = 6.34601947665
# Epoch 21 train accuracy = 0.848717948718
# Epoch 21 test cost = 9.23576945066
# Epoch 21 test accuracy = 0.865384615385
# Epoch 22 train cost = 5.95401662588
# Epoch 22 train accuracy = 0.851282051282
# Epoch 22 test cost = 8.18846487999
# Epoch 22 test accuracy = 0.894230769231
# Epoch 23 train cost = 5.80720043182
# Epoch 23 train accuracy = 0.866666666667
# Epoch 23 test cost = 8.48115491867
# Epoch 23 test accuracy = 0.907051282051
# Epoch 24 train cost = 5.97288648784
# Epoch 24 train accuracy = 0.85641025641
# Epoch 24 test cost = 9.15599474311
# Epoch 24 test accuracy = 0.899038461538
# Epoch 25 train cost = 6.14380091429
# Epoch 25 train accuracy = 0.852564102564
# Epoch 25 test cost = 8.78531467915
# Epoch 25 test accuracy = 0.870192307692
# Epoch 26 train cost = 5.79888451099
# Epoch 26 train accuracy = 0.869230769231
# Epoch 26 test cost = 9.64368250966
# Epoch 26 test accuracy = 0.886217948718
# Epoch 27 train cost = 5.71033969522
# Epoch 27 train accuracy = 0.878205128205
# Epoch 27 test cost = 9.26751247048
# Epoch 27 test accuracy = 0.889423076923
# Epoch 28 train cost = 5.22190375626
# Epoch 28 train accuracy = 0.873076923077
# Epoch 28 test cost = 8.25274327397
# Epoch 28 test accuracy = 0.907051282051
# Epoch 29 train cost = 5.26323139668
# Epoch 29 train accuracy = 0.884615384615
# Epoch 29 test cost = 8.29149839282
# Epoch 29 test accuracy = 0.908653846154
# Epoch 30 train cost = 4.74041558802
# Epoch 30 train accuracy = 0.885897435897
# Epoch 30 test cost = 7.45589375496
# Epoch 30 test accuracy = 0.905448717949
# Epoch 31 train cost = 4.54464197159
# Epoch 31 train accuracy = 0.889743589744
# Epoch 31 test cost = 7.92494182289
# Epoch 31 test accuracy = 0.905448717949
# Epoch 32 train cost = 4.97945481539
# Epoch 32 train accuracy = 0.903846153846
# Epoch 32 test cost = 8.1018820107
# Epoch 32 test accuracy = 0.905448717949
# Epoch 33 train cost = 4.65095306933
# Epoch 33 train accuracy = 0.897435897436
# Epoch 33 test cost = 8.43642535806
# Epoch 33 test accuracy = 0.891025641026
# Epoch 34 train cost = 4.49871325493
# Epoch 34 train accuracy = 0.907692307692
# Epoch 34 test cost = 7.77490323782
# Epoch 34 test accuracy = 0.892628205128
# Epoch 35 train cost = 4.23626887053
# Epoch 35 train accuracy = 0.910256410256
# Epoch 35 test cost = 8.54207292199
# Epoch 35 test accuracy = 0.895833333333
# Epoch 36 train cost = 4.80115214735
# Epoch 36 train accuracy = 0.887179487179
# Epoch 36 test cost = 8.64921316504
# Epoch 36 test accuracy = 0.919871794872
# Epoch 37 train cost = 4.11207701266
# Epoch 37 train accuracy = 0.885897435897
# Epoch 37 test cost = 8.68274068832
# Epoch 37 test accuracy = 0.908653846154
# Epoch 38 train cost = 4.61724710464
# Epoch 38 train accuracy = 0.9
# Epoch 38 test cost = 8.48994109035
# Epoch 38 test accuracy = 0.897435897436
# Epoch 39 train cost = 4.249263376
# Epoch 39 train accuracy = 0.894871794872
# Epoch 39 test cost = 7.41546535492
# Epoch 39 test accuracy = 0.899038461538
# Epoch 40 train cost = 4.7021394074
# Epoch 40 train accuracy = 0.889743589744
# Epoch 40 test cost = 9.17050093412
# Epoch 40 test accuracy = 0.908653846154
# Epoch 41 train cost = 4.81730008125
# Epoch 41 train accuracy = 0.897435897436
# Epoch 41 test cost = 8.40938925743
# Epoch 41 test accuracy = 0.900641025641
# Epoch 42 train cost = 4.72869065404
# Epoch 42 train accuracy = 0.879487179487
# Epoch 42 test cost = 8.32635635138
# Epoch 42 test accuracy = 0.902243589744
# Epoch 43 train cost = 3.60753123462
# Epoch 43 train accuracy = 0.908974358974
# Epoch 43 test cost = 7.50769609213
# Epoch 43 test accuracy = 0.913461538462
# Epoch 44 train cost = 4.02187100798
# Epoch 44 train accuracy = 0.908974358974
# Epoch 44 test cost = 7.87151250243
# Epoch 44 test accuracy = 0.916666666667
# Epoch 45 train cost = 3.55013104528
# Epoch 45 train accuracy = 0.903846153846
# Epoch 45 test cost = 8.40227687359
# Epoch 45 test accuracy = 0.913461538462
# Epoch 46 train cost = 4.08241905272
# Epoch 46 train accuracy = 0.903846153846
# Epoch 46 test cost = 9.18437847495
# Epoch 46 test accuracy = 0.887820512821
# Epoch 47 train cost = 3.88984709978
# Epoch 47 train accuracy = 0.911538461538
# Epoch 47 test cost = 7.05062055588
# Epoch 47 test accuracy = 0.923076923077
# Epoch 48 train cost = 3.28332053125
# Epoch 48 train accuracy = 0.910256410256
# Epoch 48 test cost = 8.11468860507
# Epoch 48 test accuracy = 0.926282051282
# Epoch 49 train cost = 3.25341956317
# Epoch 49 train accuracy = 0.921794871795
# Epoch 49 test cost = 7.50142911077
# Epoch 49 test accuracy = 0.932692307692
# Epoch 50 train cost = 3.01061253995
# Epoch 50 train accuracy = 0.934615384615
# Epoch 50 test cost = 7.12467114627
# Epoch 50 test accuracy = 0.923076923077
# Epoch 51 train cost = 3.69709970802
# Epoch 51 train accuracy = 0.921794871795
# Epoch 51 test cost = 6.7208815217
# Epoch 51 test accuracy = 0.907051282051
# Epoch 52 train cost = 3.39534857124
# Epoch 52 train accuracy = 0.916666666667
# Epoch 52 test cost = 8.9458065033
# Epoch 52 test accuracy = 0.918269230769
# Epoch 53 train cost = 3.77955355495
# Epoch 53 train accuracy = 0.917948717949
# Epoch 53 test cost = 8.50254252553
# Epoch 53 test accuracy = 0.902243589744
# Epoch 54 train cost = 2.89186194539
# Epoch 54 train accuracy = 0.914102564103
# Epoch 54 test cost = 8.99060440063
# Epoch 54 test accuracy = 0.908653846154
# Epoch 55 train cost = 2.88173739612
# Epoch 55 train accuracy = 0.923076923077
# Epoch 55 test cost = 7.69102317095
# Epoch 55 test accuracy = 0.910256410256
# Epoch 56 train cost = 2.91356872022
# Epoch 56 train accuracy = 0.928205128205
# Epoch 56 test cost = 7.36170646548
# Epoch 56 test accuracy = 0.929487179487
# Epoch 57 train cost = 2.73067265749
# Epoch 57 train accuracy = 0.938461538462
# Epoch 57 test cost = 7.67647272348
# Epoch 57 test accuracy = 0.915064102564
# Epoch 58 train cost = 2.67131819576
# Epoch 58 train accuracy = 0.924358974359
# Epoch 58 test cost = 7.92283707857
# Epoch 58 test accuracy = 0.921474358974
# Epoch 59 train cost = 2.87736098468
# Epoch 59 train accuracy = 0.933333333333
# Epoch 59 test cost = 8.5583280623
# Epoch 59 test accuracy = 0.923076923077
# Epoch 60 train cost = 2.64001009986
# Epoch 60 train accuracy = 0.94358974359
# Epoch 60 test cost = 7.94279390574
# Epoch 60 test accuracy = 0.924679487179
# Epoch 61 train cost = 3.74907696247
# Epoch 61 train accuracy = 0.912820512821
# Epoch 61 test cost = 7.48537248373
# Epoch 61 test accuracy = 0.921474358974
# Epoch 62 train cost = 2.63778687268
# Epoch 62 train accuracy = 0.924358974359
# Epoch 62 test cost = 8.49179452658
# Epoch 62 test accuracy = 0.921474358974
# Epoch 63 train cost = 3.13398646191
# Epoch 63 train accuracy = 0.932051282051
# Epoch 63 test cost = 7.53309291601
# Epoch 63 test accuracy = 0.919871794872
# Epoch 64 train cost = 3.57119683921
# Epoch 64 train accuracy = 0.925641025641
# Epoch 64 test cost = 9.07357898355
# Epoch 64 test accuracy = 0.923076923077
# Epoch 65 train cost = 3.51187628508
# Epoch 65 train accuracy = 0.917948717949
# Epoch 65 test cost = 7.66544654965
# Epoch 65 test accuracy = 0.919871794872
# Epoch 66 train cost = 2.62877913564
# Epoch 66 train accuracy = 0.934615384615
# Epoch 66 test cost = 7.60891491175
# Epoch 66 test accuracy = 0.93108974359
# Epoch 67 train cost = 2.69990541786
# Epoch 67 train accuracy = 0.911538461538
# Epoch 67 test cost = 8.91183075309
# Epoch 67 test accuracy = 0.927884615385
# Epoch 68 train cost = 2.79584087431
# Epoch 68 train accuracy = 0.933333333333
# Epoch 68 test cost = 6.940025419
# Epoch 68 test accuracy = 0.93108974359
# Epoch 69 train cost = 2.10784682631
# Epoch 69 train accuracy = 0.946153846154
# Epoch 69 test cost = 7.02505350113
# Epoch 69 test accuracy = 0.942307692308
# Epoch 70 train cost = 2.46655001864
# Epoch 70 train accuracy = 0.932051282051
# Epoch 70 test cost = 7.98782938719
# Epoch 70 test accuracy = 0.918269230769
# Epoch 71 train cost = 2.12546525523
# Epoch 71 train accuracy = 0.937179487179
# Epoch 71 test cost = 8.68685233593
# Epoch 71 test accuracy = 0.905448717949
# Epoch 72 train cost = 2.37729585543
# Epoch 72 train accuracy = 0.939743589744
# Epoch 72 test cost = 8.76592293382
# Epoch 72 test accuracy = 0.926282051282
# Epoch 73 train cost = 2.75662709028
# Epoch 73 train accuracy = 0.941025641026
# Epoch 73 test cost = 7.63217163086
# Epoch 73 test accuracy = 0.927884615385
# Epoch 74 train cost = 2.03149475157
# Epoch 74 train accuracy = 0.951282051282
# Epoch 74 test cost = 8.53441575915
# Epoch 74 test accuracy = 0.929487179487
# Epoch 75 train cost = 1.59736811742
# Epoch 75 train accuracy = 0.955128205128
# Epoch 75 test cost = 7.03268699348
# Epoch 75 test accuracy = 0.923076923077
# Epoch 76 train cost = 1.57137214392
# Epoch 76 train accuracy = 0.958974358974
# Epoch 76 test cost = 7.9935952872
# Epoch 76 test accuracy = 0.93108974359
# Epoch 77 train cost = 2.1983095631
# Epoch 77 train accuracy = 0.942307692308
# Epoch 77 test cost = 7.51420366764
# Epoch 77 test accuracy = 0.927884615385
# Epoch 78 train cost = 2.15579826385
# Epoch 78 train accuracy = 0.94358974359
# Epoch 78 test cost = 8.31412622333
# Epoch 78 test accuracy = 0.916666666667
# Epoch 79 train cost = 1.9494943358
# Epoch 79 train accuracy = 0.952564102564
# Epoch 79 test cost = 7.20015323162
# Epoch 79 test accuracy = 0.929487179487
# Epoch 80 train cost = 2.1169873178
# Epoch 80 train accuracy = 0.937179487179
# Epoch 80 test cost = 8.26978877187
# Epoch 80 test accuracy = 0.929487179487
# Epoch 81 train cost = 1.6956394054
# Epoch 81 train accuracy = 0.964102564103
# Epoch 81 test cost = 8.01507636905
# Epoch 81 test accuracy = 0.910256410256
# Epoch 82 train cost = 2.16325651109
# Epoch 82 train accuracy = 0.942307692308
# Epoch 82 test cost = 7.94524994493
# Epoch 82 test accuracy = 0.918269230769
# Epoch 83 train cost = 1.89722063392
# Epoch 83 train accuracy = 0.951282051282
# Epoch 83 test cost = 6.27074736357
# Epoch 83 test accuracy = 0.915064102564
# Epoch 84 train cost = 2.15044244006
# Epoch 84 train accuracy = 0.951282051282
# Epoch 84 test cost = 7.56671777368
# Epoch 84 test accuracy = 0.940705128205
# Epoch 85 train cost = 2.20298661292
# Epoch 85 train accuracy = 0.944871794872
# Epoch 85 test cost = 8.34488901496
# Epoch 85 test accuracy = 0.929487179487
# Epoch 86 train cost = 1.86353506334
# Epoch 86 train accuracy = 0.944871794872
# Epoch 86 test cost = 8.05363252759
# Epoch 86 test accuracy = 0.918269230769
# Epoch 87 train cost = 2.79510420933
# Epoch 87 train accuracy = 0.941025641026
# Epoch 87 test cost = 7.93186661601
# Epoch 87 test accuracy = 0.923076923077
# Epoch 88 train cost = 2.60214518756
# Epoch 88 train accuracy = 0.933333333333
# Epoch 88 test cost = 7.53629897535
# Epoch 88 test accuracy = 0.919871794872
# Epoch 89 train cost = 2.59864282608
# Epoch 89 train accuracy = 0.925641025641
# Epoch 89 test cost = 8.03066337109
# Epoch 89 test accuracy = 0.916666666667
# Epoch 90 train cost = 3.47408980876
# Epoch 90 train accuracy = 0.955128205128
# Epoch 90 test cost = 8.45928868651
# Epoch 90 test accuracy = 0.932692307692
# Epoch 91 train cost = 2.22937668487
# Epoch 91 train accuracy = 0.930769230769
# Epoch 91 test cost = 6.00058554858
# Epoch 91 test accuracy = 0.942307692308
# Epoch 92 train cost = 1.89137782902
# Epoch 92 train accuracy = 0.95
# Epoch 92 test cost = 6.56944511831
# Epoch 92 test accuracy = 0.9375
# Epoch 93 train cost = 2.01218175143
# Epoch 93 train accuracy = 0.948717948718
# Epoch 93 test cost = 7.23266667128
# Epoch 93 test accuracy = 0.935897435897
# Epoch 94 train cost = 2.16020964086
# Epoch 94 train accuracy = 0.941025641026
# Epoch 94 test cost = 8.47306826711
# Epoch 94 test accuracy = 0.935897435897
# Epoch 95 train cost = 1.94304478914
# Epoch 95 train accuracy = 0.95
# Epoch 95 test cost = 7.56223417819
# Epoch 95 test accuracy = 0.94391025641
# Epoch 96 train cost = 2.94477519765
# Epoch 96 train accuracy = 0.955128205128
# Epoch 96 test cost = 6.75062279403
# Epoch 96 test accuracy = 0.927884615385
# Epoch 97 train cost = 2.64277137071
# Epoch 97 train accuracy = 0.941025641026
# Epoch 97 test cost = 7.56721416116
# Epoch 97 test accuracy = 0.942307692308
# Epoch 98 train cost = 2.94656364992
# Epoch 98 train accuracy = 0.95
# Epoch 98 test cost = 7.14623197913
# Epoch 98 test accuracy = 0.9375
# Epoch 99 train cost = 2.27219131961
# Epoch 99 train accuracy = 0.957692307692
# Epoch 99 test cost = 6.8189279139
# Epoch 99 test accuracy = 0.93108974359
# Epoch 100 train cost = 1.72091994062
# Epoch 100 train accuracy = 0.965384615385
# Epoch 100 test cost = 7.59319987893
# Epoch 100 test accuracy = 0.9375
# Epoch 101 train cost = 2.17991852388
# Epoch 101 train accuracy = 0.967948717949
# Epoch 101 test cost = 6.3942681551
# Epoch 101 test accuracy = 0.929487179487
# Epoch 102 train cost = 2.31804911047
# Epoch 102 train accuracy = 0.958974358974
# Epoch 102 test cost = 7.06233817339
# Epoch 102 test accuracy = 0.947115384615
# Epoch 103 train cost = 2.17298840731
# Epoch 103 train accuracy = 0.953846153846
# Epoch 103 test cost = 6.67387536168
# Epoch 103 test accuracy = 0.939102564103
# Epoch 104 train cost = 1.72603323311
# Epoch 104 train accuracy = 0.952564102564
# Epoch 104 test cost = 6.98551738262
# Epoch 104 test accuracy = 0.934294871795
# Epoch 105 train cost = 2.10480919853
# Epoch 105 train accuracy = 0.967948717949
# Epoch 105 test cost = 7.49563127756
# Epoch 105 test accuracy = 0.934294871795
# Epoch 106 train cost = 1.79103316925
# Epoch 106 train accuracy = 0.952564102564
# Epoch 106 test cost = 6.87988647819
# Epoch 106 test accuracy = 0.945512820513
# Epoch 107 train cost = 2.19673679955
# Epoch 107 train accuracy = 0.955128205128
# Epoch 107 test cost = 7.62827038765
# Epoch 107 test accuracy = 0.934294871795
# Epoch 108 train cost = 1.93069324642
# Epoch 108 train accuracy = 0.967948717949
# Epoch 108 test cost = 7.33128033578
# Epoch 108 test accuracy = 0.935897435897
# Epoch 109 train cost = 1.82388650812
# Epoch 109 train accuracy = 0.953846153846
# Epoch 109 test cost = 7.53159871697
# Epoch 109 test accuracy = 0.929487179487
# Epoch 110 train cost = 1.7951339297
# Epoch 110 train accuracy = 0.944871794872
# Epoch 110 test cost = 7.9923928231
# Epoch 110 test accuracy = 0.919871794872
# Epoch 111 train cost = 2.62811474502
# Epoch 111 train accuracy = 0.958974358974
# Epoch 111 test cost = 7.28845179081
# Epoch 111 test accuracy = 0.926282051282
# Epoch 112 train cost = 2.53714544699
# Epoch 112 train accuracy = 0.955128205128
# Epoch 112 test cost = 7.9529389292
# Epoch 112 test accuracy = 0.932692307692
# Epoch 113 train cost = 2.08510079235
# Epoch 113 train accuracy = 0.946153846154
# Epoch 113 test cost = 7.31951294094
# Epoch 113 test accuracy = 0.935897435897
# Epoch 114 train cost = 1.64654726535
# Epoch 114 train accuracy = 0.965384615385
# Epoch 114 test cost = 7.96436236799
# Epoch 114 test accuracy = 0.913461538462
# Epoch 115 train cost = 2.2452452071
# Epoch 115 train accuracy = 0.953846153846
# Epoch 115 test cost = 8.57164573669
# Epoch 115 test accuracy = 0.923076923077
# Epoch 116 train cost = 3.0781452097
# Epoch 116 train accuracy = 0.942307692308
# Epoch 116 test cost = 8.72475044429
# Epoch 116 test accuracy = 0.907051282051
# Epoch 117 train cost = 2.62552572787
# Epoch 117 train accuracy = 0.951282051282
# Epoch 117 test cost = 7.75483956933
# Epoch 117 test accuracy = 0.9375
# Epoch 118 train cost = 2.34174233675
# Epoch 118 train accuracy = 0.958974358974
# Epoch 118 test cost = 8.68291817605
# Epoch 118 test accuracy = 0.926282051282
# Epoch 119 train cost = 2.24971799925
# Epoch 119 train accuracy = 0.953846153846
# Epoch 119 test cost = 7.77399924397
# Epoch 119 test accuracy = 0.940705128205
# Epoch 120 train cost = 1.35708599817
# Epoch 120 train accuracy = 0.952564102564
# Epoch 120 test cost = 6.30087569356
# Epoch 120 test accuracy = 0.940705128205
# Epoch 121 train cost = 1.6761767827
# Epoch 121 train accuracy = 0.952564102564
# Epoch 121 test cost = 8.86471800506
# Epoch 121 test accuracy = 0.924679487179
# Epoch 122 train cost = 2.38971593603
# Epoch 122 train accuracy = 0.946153846154
# Epoch 122 test cost = 7.19753326476
# Epoch 122 test accuracy = 0.932692307692
# Epoch 123 train cost = 2.02479442582
# Epoch 123 train accuracy = 0.95
# Epoch 123 test cost = 6.15241668373
# Epoch 123 test accuracy = 0.919871794872
# Epoch 124 train cost = 1.98667743802
# Epoch 124 train accuracy = 0.957692307692
# Epoch 124 test cost = 6.90075846761
# Epoch 124 test accuracy = 0.940705128205
# Epoch 125 train cost = 2.08882003278
# Epoch 125 train accuracy = 0.953846153846
# Epoch 125 test cost = 8.18667851388
# Epoch 125 test accuracy = 0.927884615385
# Epoch 126 train cost = 1.78514235094
# Epoch 126 train accuracy = 0.953846153846
# Epoch 126 test cost = 7.90684172511
# Epoch 126 test accuracy = 0.932692307692
# Epoch 127 train cost = 2.30000203848
# Epoch 127 train accuracy = 0.958974358974
# Epoch 127 test cost = 7.82227939367
# Epoch 127 test accuracy = 0.919871794872
# Epoch 128 train cost = 2.10820636526
# Epoch 128 train accuracy = 0.962820512821
# Epoch 128 test cost = 7.93622332811
# Epoch 128 test accuracy = 0.924679487179
# Epoch 129 train cost = 1.58526281454
# Epoch 129 train accuracy = 0.967948717949
# Epoch 129 test cost = 7.20947341621
# Epoch 129 test accuracy = 0.926282051282
# Epoch 130 train cost = 1.74154258519
# Epoch 130 train accuracy = 0.970512820513
# Epoch 130 test cost = 7.04476723075
# Epoch 130 test accuracy = 0.934294871795
# Epoch 131 train cost = 1.81172754616
# Epoch 131 train accuracy = 0.953846153846
# Epoch 131 test cost = 6.87226420641
# Epoch 131 test accuracy = 0.926282051282
# Epoch 132 train cost = 2.10951628536
# Epoch 132 train accuracy = 0.946153846154
# Epoch 132 test cost = 9.85797388852
# Epoch 132 test accuracy = 0.918269230769
# Epoch 133 train cost = 2.2089364063
# Epoch 133 train accuracy = 0.947435897436
# Epoch 133 test cost = 9.19452372193
# Epoch 133 test accuracy = 0.915064102564
# Epoch 134 train cost = 2.1042544134
# Epoch 134 train accuracy = 0.962820512821
# Epoch 134 test cost = 7.69371165335
# Epoch 134 test accuracy = 0.913461538462
# Epoch 135 train cost = 1.73241963238
# Epoch 135 train accuracy = 0.960256410256
# Epoch 135 test cost = 6.36399447918
# Epoch 135 test accuracy = 0.93108974359
# Epoch 136 train cost = 1.28527895268
# Epoch 136 train accuracy = 0.965384615385
# Epoch 136 test cost = 7.84415952861
# Epoch 136 test accuracy = 0.94391025641
# Epoch 137 train cost = 1.46707226709
# Epoch 137 train accuracy = 0.953846153846
# Epoch 137 test cost = 8.46526089311
# Epoch 137 test accuracy = 0.932692307692
# Epoch 138 train cost = 1.81544196233
# Epoch 138 train accuracy = 0.966666666667
# Epoch 138 test cost = 8.00661973655
# Epoch 138 test accuracy = 0.940705128205
# Epoch 139 train cost = 1.32519523427
# Epoch 139 train accuracy = 0.978205128205
# Epoch 139 test cost = 6.48877575248
# Epoch 139 test accuracy = 0.929487179487
# Epoch 140 train cost = 1.24627278745
# Epoch 140 train accuracy = 0.964102564103
# Epoch 140 test cost = 8.90197867155
# Epoch 140 test accuracy = 0.923076923077
# Epoch 141 train cost = 1.33922970667
# Epoch 141 train accuracy = 0.966666666667
# Epoch 141 test cost = 8.41536641121
# Epoch 141 test accuracy = 0.923076923077
# Epoch 142 train cost = 1.29343098775
# Epoch 142 train accuracy = 0.971794871795
# Epoch 142 test cost = 7.35994103551
# Epoch 142 test accuracy = 0.932692307692
# Epoch 143 train cost = 1.76966403425
# Epoch 143 train accuracy = 0.961538461538
# Epoch 143 test cost = 7.07785090804
# Epoch 143 test accuracy = 0.93108974359
# Epoch 144 train cost = 1.36077960208
# Epoch 144 train accuracy = 0.967948717949
# Epoch 144 test cost = 7.85599289834
# Epoch 144 test accuracy = 0.915064102564
# Epoch 145 train cost = 1.07770549506
# Epoch 145 train accuracy = 0.976923076923
# Epoch 145 test cost = 8.13811935484
# Epoch 145 test accuracy = 0.905448717949
# Epoch 146 train cost = 1.3515726421
# Epoch 146 train accuracy = 0.976923076923
# Epoch 146 test cost = 7.51520624757
# Epoch 146 test accuracy = 0.93108974359
# Epoch 147 train cost = 1.61949562095
# Epoch 147 train accuracy = 0.983333333333
# Epoch 147 test cost = 7.16061226279
# Epoch 147 test accuracy = 0.9375
# Epoch 148 train cost = 1.10146804899
# Epoch 148 train accuracy = 0.975641025641
# Epoch 148 test cost = 6.9156011194
# Epoch 148 test accuracy = 0.932692307692
# Epoch 149 train cost = 0.901088750921
# Epoch 149 train accuracy = 0.967948717949
# Epoch 149 test cost = 6.98538188636
# Epoch 149 test accuracy = 0.93108974359
# Epoch 150 train cost = 1.08957950957
# Epoch 150 train accuracy = 0.961538461538
# Epoch 150 test cost = 6.99789492041
# Epoch 150 test accuracy = 0.942307692308
# Epoch 151 train cost = 0.989091153257
# Epoch 151 train accuracy = 0.983333333333
# Epoch 151 test cost = 7.02475549281
# Epoch 151 test accuracy = 0.9375
# Epoch 152 train cost = 0.869108044775
# Epoch 152 train accuracy = 0.985897435897
# Epoch 152 test cost = 6.99165248871
# Epoch 152 test accuracy = 0.9375
# Epoch 153 train cost = 1.07105348958
# Epoch 153 train accuracy = 0.979487179487
# Epoch 153 test cost = 8.22036824375
# Epoch 153 test accuracy = 0.93108974359
# Epoch 154 train cost = 0.966724548489
# Epoch 154 train accuracy = 0.979487179487
# Epoch 154 test cost = 7.34079948068
# Epoch 154 test accuracy = 0.94391025641
# Epoch 155 train cost = 1.26901465096
# Epoch 155 train accuracy = 0.978205128205
# Epoch 155 test cost = 7.0827087909
# Epoch 155 test accuracy = 0.934294871795
# Epoch 156 train cost = 1.21580129024
# Epoch 156 train accuracy = 0.960256410256
# Epoch 156 test cost = 7.62957394123
# Epoch 156 test accuracy = 0.927884615385
# Epoch 157 train cost = 1.01361890603
# Epoch 157 train accuracy = 0.979487179487
# Epoch 157 test cost = 6.44540823996
# Epoch 157 test accuracy = 0.934294871795
# Epoch 158 train cost = 1.27757214289
# Epoch 158 train accuracy = 0.962820512821
# Epoch 158 test cost = 9.04545894265
# Epoch 158 test accuracy = 0.935897435897
# Epoch 159 train cost = 0.99359313678
# Epoch 159 train accuracy = 0.966666666667
# Epoch 159 test cost = 6.67408017814
# Epoch 159 test accuracy = 0.947115384615
# Epoch 160 train cost = 1.23854767531
# Epoch 160 train accuracy = 0.976923076923
# Epoch 160 test cost = 6.48153193295
# Epoch 160 test accuracy = 0.927884615385
# Epoch 161 train cost = 1.43108647596
# Epoch 161 train accuracy = 0.957692307692
# Epoch 161 test cost = 10.1262651086
# Epoch 161 test accuracy = 0.913461538462
# Epoch 162 train cost = 1.84096837603
# Epoch 162 train accuracy = 0.969230769231
# Epoch 162 test cost = 8.85802749544
# Epoch 162 test accuracy = 0.913461538462
# Epoch 163 train cost = 1.43378722016
# Epoch 163 train accuracy = 0.953846153846
# Epoch 163 test cost = 7.85198891535
# Epoch 163 test accuracy = 0.927884615385
# Epoch 164 train cost = 1.25670271367
# Epoch 164 train accuracy = 0.976923076923
# Epoch 164 test cost = 7.66145400703
# Epoch 164 test accuracy = 0.927884615385
# Epoch 165 train cost = 0.852425657213
# Epoch 165 train accuracy = 0.970512820513
# Epoch 165 test cost = 7.33642229438
# Epoch 165 test accuracy = 0.923076923077
# Epoch 166 train cost = 1.31661786605
# Epoch 166 train accuracy = 0.966666666667
# Epoch 166 test cost = 7.61231382191
# Epoch 166 test accuracy = 0.927884615385
# Epoch 167 train cost = 1.25164488517
# Epoch 167 train accuracy = 0.971794871795
# Epoch 167 test cost = 7.61594940722
# Epoch 167 test accuracy = 0.926282051282
# Epoch 168 train cost = 1.41032523848
# Epoch 168 train accuracy = 0.970512820513
# Epoch 168 test cost = 8.61719748378
# Epoch 168 test accuracy = 0.927884615385
# Epoch 169 train cost = 1.50775594357
# Epoch 169 train accuracy = 0.973076923077
# Epoch 169 test cost = 8.40348663926
# Epoch 169 test accuracy = 0.942307692308
# Epoch 170 train cost = 1.5609754324
# Epoch 170 train accuracy = 0.964102564103
# Epoch 170 test cost = 7.94747149944
# Epoch 170 test accuracy = 0.940705128205
# Epoch 171 train cost = 1.20586299384
# Epoch 171 train accuracy = 0.973076923077
# Epoch 171 test cost = 8.37575324625
# Epoch 171 test accuracy = 0.921474358974
# Epoch 172 train cost = 1.8354472518
# Epoch 172 train accuracy = 0.95641025641
# Epoch 172 test cost = 7.76264238358
# Epoch 172 test accuracy = 0.932692307692
# Epoch 173 train cost = 1.6754604131
# Epoch 173 train accuracy = 0.980769230769
# Epoch 173 test cost = 8.01819095016
# Epoch 173 test accuracy = 0.923076923077
# Epoch 174 train cost = 1.49492500862
# Epoch 174 train accuracy = 0.976923076923
# Epoch 174 test cost = 8.0919316411
# Epoch 174 test accuracy = 0.923076923077
# Epoch 175 train cost = 1.66672612634
# Epoch 175 train accuracy = 0.967948717949
# Epoch 175 test cost = 8.08304336667
# Epoch 175 test accuracy = 0.93108974359
# Epoch 176 train cost = 1.65844896808
# Epoch 176 train accuracy = 0.965384615385
# Epoch 176 test cost = 7.46883191168
# Epoch 176 test accuracy = 0.924679487179
# Epoch 177 train cost = 1.56196383759
# Epoch 177 train accuracy = 0.967948717949
# Epoch 177 test cost = 8.11354637146
# Epoch 177 test accuracy = 0.923076923077
# Epoch 178 train cost = 1.31598336063
# Epoch 178 train accuracy = 0.969230769231
# Epoch 178 test cost = 7.84706383944
# Epoch 178 test accuracy = 0.927884615385
# Epoch 179 train cost = 1.27194165252
# Epoch 179 train accuracy = 0.969230769231
# Epoch 179 test cost = 6.6205823496
# Epoch 179 test accuracy = 0.939102564103
# Epoch 180 train cost = 1.04081709217
# Epoch 180 train accuracy = 0.973076923077
# Epoch 180 test cost = 7.63468185067
# Epoch 180 test accuracy = 0.924679487179
# Epoch 181 train cost = 1.70527864993
# Epoch 181 train accuracy = 0.966666666667
# Epoch 181 test cost = 7.44886773825
# Epoch 181 test accuracy = 0.919871794872
# Epoch 182 train cost = 1.12450594269
# Epoch 182 train accuracy = 0.975641025641
# Epoch 182 test cost = 8.500207901
# Epoch 182 test accuracy = 0.939102564103
# Epoch 183 train cost = 1.62021432538
# Epoch 183 train accuracy = 0.962820512821
# Epoch 183 test cost = 9.85444958508
# Epoch 183 test accuracy = 0.915064102564
# Epoch 184 train cost = 1.37123326771
# Epoch 184 train accuracy = 0.970512820513
# Epoch 184 test cost = 8.24884037673
# Epoch 184 test accuracy = 0.924679487179
# Epoch 185 train cost = 1.51000038721
# Epoch 185 train accuracy = 0.961538461538
# Epoch 185 test cost = 8.19165214896
# Epoch 185 test accuracy = 0.924679487179
# Epoch 186 train cost = 0.836475624703
# Epoch 186 train accuracy = 0.975641025641
# Epoch 186 test cost = 7.72256335616
# Epoch 186 test accuracy = 0.932692307692
# Epoch 187 train cost = 1.26276408229
# Epoch 187 train accuracy = 0.983333333333
# Epoch 187 test cost = 7.37129506469
# Epoch 187 test accuracy = 0.935897435897
# Epoch 188 train cost = 1.22293353733
# Epoch 188 train accuracy = 0.979487179487
# Epoch 188 test cost = 8.20710082352
# Epoch 188 test accuracy = 0.940705128205
# Epoch 189 train cost = 1.57151991129
# Epoch 189 train accuracy = 0.958974358974
# Epoch 189 test cost = 8.95356988907
# Epoch 189 test accuracy = 0.910256410256
# Epoch 190 train cost = 2.03513216414
# Epoch 190 train accuracy = 0.967948717949
# Epoch 190 test cost = 8.21389195323
# Epoch 190 test accuracy = 0.927884615385
# Epoch 191 train cost = 2.46827297285
# Epoch 191 train accuracy = 0.967948717949
# Epoch 191 test cost = 8.66435673833
# Epoch 191 test accuracy = 0.929487179487
# Epoch 192 train cost = 1.76006116718
# Epoch 192 train accuracy = 0.964102564103
# Epoch 192 test cost = 9.2424851954
# Epoch 192 test accuracy = 0.9375
# Epoch 193 train cost = 1.55417658389
# Epoch 193 train accuracy = 0.967948717949
# Epoch 193 test cost = 8.05361577868
# Epoch 193 test accuracy = 0.927884615385
# Epoch 194 train cost = 0.913028909825
# Epoch 194 train accuracy = 0.967948717949
# Epoch 194 test cost = 8.18099206686
# Epoch 194 test accuracy = 0.93108974359
# Epoch 195 train cost = 1.48241786053
# Epoch 195 train accuracy = 0.970512820513
# Epoch 195 test cost = 7.88567852974
# Epoch 195 test accuracy = 0.939102564103
# Epoch 196 train cost = 1.60037614312
# Epoch 196 train accuracy = 0.965384615385
# Epoch 196 test cost = 8.67322765291
# Epoch 196 test accuracy = 0.945512820513
# Epoch 197 train cost = 1.27729631774
# Epoch 197 train accuracy = 0.966666666667
# Epoch 197 test cost = 7.57173968852
# Epoch 197 test accuracy = 0.939102564103
# Epoch 198 train cost = 1.75297794491
# Epoch 198 train accuracy = 0.974358974359
# Epoch 198 test cost = 8.50898396969
# Epoch 198 test accuracy = 0.918269230769
# Epoch 199 train cost = 1.19981455058
# Epoch 199 train accuracy = 0.975641025641
# Epoch 199 test cost = 8.88114210963
# Epoch 199 test accuracy = 0.926282051282
# Epoch 200 train cost = 1.29164137132
# Epoch 200 train accuracy = 0.969230769231
# Epoch 200 test cost = 7.74069853127
# Epoch 200 test accuracy = 0.93108974359
# Epoch 201 train cost = 1.04451873153
# Epoch 201 train accuracy = 0.984615384615
# Epoch 201 test cost = 7.07212200761
# Epoch 201 test accuracy = 0.929487179487
# Epoch 202 train cost = 0.882169221062
# Epoch 202 train accuracy = 0.969230769231
# Epoch 202 test cost = 8.30583176017
# Epoch 202 test accuracy = 0.927884615385
# Epoch 203 train cost = 1.29106867407
# Epoch 203 train accuracy = 0.970512820513
# Epoch 203 test cost = 7.61122432351
# Epoch 203 test accuracy = 0.935897435897
# Epoch 204 train cost = 1.24887746572
# Epoch 204 train accuracy = 0.971794871795
# Epoch 204 test cost = 7.0517475009
# Epoch 204 test accuracy = 0.934294871795
# Epoch 205 train cost = 1.6339935204
# Epoch 205 train accuracy = 0.969230769231
# Epoch 205 test cost = 8.32818384469
# Epoch 205 test accuracy = 0.934294871795
# Epoch 206 train cost = 1.35706645623
# Epoch 206 train accuracy = 0.94358974359
# Epoch 206 test cost = 6.64101903886
# Epoch 206 test accuracy = 0.932692307692
# Epoch 207 train cost = 1.45705320407
# Epoch 207 train accuracy = 0.969230769231
# Epoch 207 test cost = 7.57214600593
# Epoch 207 test accuracy = 0.94391025641
# Epoch 208 train cost = 1.476318717
# Epoch 208 train accuracy = 0.969230769231
# Epoch 208 test cost = 8.42876341939
# Epoch 208 test accuracy = 0.926282051282
# Epoch 209 train cost = 1.31464432366
# Epoch 209 train accuracy = 0.961538461538
# Epoch 209 test cost = 7.68716026843
# Epoch 209 test accuracy = 0.911858974359
# Epoch 210 train cost = 1.25792571343
# Epoch 210 train accuracy = 0.967948717949
# Epoch 210 test cost = 7.3964359574
# Epoch 210 test accuracy = 0.93108974359
# Epoch 211 train cost = 1.52393163368
# Epoch 211 train accuracy = 0.965384615385
# Epoch 211 test cost = 8.43045824766
# Epoch 211 test accuracy = 0.927884615385
# Epoch 212 train cost = 1.03370807692
# Epoch 212 train accuracy = 0.967948717949
# Epoch 212 test cost = 8.34589830041
# Epoch 212 test accuracy = 0.918269230769
# Epoch 213 train cost = 0.778177073225
# Epoch 213 train accuracy = 0.982051282051
# Epoch 213 test cost = 8.36137199402
# Epoch 213 test accuracy = 0.93108974359
# Epoch 214 train cost = 1.12951659132
# Epoch 214 train accuracy = 0.978205128205
# Epoch 214 test cost = 8.29888176918
# Epoch 214 test accuracy = 0.935897435897
# Epoch 215 train cost = 1.10551230237
# Epoch 215 train accuracy = 0.966666666667
# Epoch 215 test cost = 9.23260600865
# Epoch 215 test accuracy = 0.929487179487
# Epoch 216 train cost = 1.04584417166
# Epoch 216 train accuracy = 0.976923076923
# Epoch 216 test cost = 7.88110116124
# Epoch 216 test accuracy = 0.940705128205
# Epoch 217 train cost = 1.03228347888
# Epoch 217 train accuracy = 0.975641025641
# Epoch 217 test cost = 8.0048801899
# Epoch 217 test accuracy = 0.929487179487
# Epoch 218 train cost = 0.562901301309
# Epoch 218 train accuracy = 0.983333333333
# Epoch 218 test cost = 7.33709158748
# Epoch 218 test accuracy = 0.927884615385
# Epoch 219 train cost = 0.798679784872
# Epoch 219 train accuracy = 0.976923076923
# Epoch 219 test cost = 6.90693299472
# Epoch 219 test accuracy = 0.932692307692
# Epoch 220 train cost = 0.957966791932
# Epoch 220 train accuracy = 0.985897435897
# Epoch 220 test cost = 7.27493953705
# Epoch 220 test accuracy = 0.927884615385
# Epoch 221 train cost = 0.468178806826
# Epoch 221 train accuracy = 0.975641025641
# Epoch 221 test cost = 8.28174152225
# Epoch 221 test accuracy = 0.924679487179
# Epoch 222 train cost = 1.18217411172
# Epoch 222 train accuracy = 0.974358974359
# Epoch 222 test cost = 7.14513973892
# Epoch 222 test accuracy = 0.924679487179
# Epoch 223 train cost = 0.764143745881
# Epoch 223 train accuracy = 0.991025641026
# Epoch 223 test cost = 7.33028367162
# Epoch 223 test accuracy = 0.945512820513
# Epoch 224 train cost = 1.27112243464
# Epoch 224 train accuracy = 0.983333333333
# Epoch 224 test cost = 8.82347258925
# Epoch 224 test accuracy = 0.932692307692
# Epoch 225 train cost = 1.56115682982
# Epoch 225 train accuracy = 0.965384615385
# Epoch 225 test cost = 9.38301883638
# Epoch 225 test accuracy = 0.916666666667
# Epoch 226 train cost = 2.02631971287
# Epoch 226 train accuracy = 0.955128205128
# Epoch 226 test cost = 8.82968680561
# Epoch 226 test accuracy = 0.918269230769
# Epoch 227 train cost = 1.79019679874
# Epoch 227 train accuracy = 0.966666666667
# Epoch 227 test cost = 8.36138218641
# Epoch 227 test accuracy = 0.913461538462
# Epoch 228 train cost = 1.45630587731
# Epoch 228 train accuracy = 0.95641025641
# Epoch 228 test cost = 9.17805987597
# Epoch 228 test accuracy = 0.916666666667
# Epoch 229 train cost = 1.30159992911
# Epoch 229 train accuracy = 0.978205128205
# Epoch 229 test cost = 8.45441409945
# Epoch 229 test accuracy = 0.924679487179
# Epoch 230 train cost = 1.20540583925
# Epoch 230 train accuracy = 0.976923076923
# Epoch 230 test cost = 8.93176460266
# Epoch 230 test accuracy = 0.915064102564
# Epoch 231 train cost = 1.55873583257
# Epoch 231 train accuracy = 0.966666666667
# Epoch 231 test cost = 13.0042728186
# Epoch 231 test accuracy = 0.895833333333
# Epoch 232 train cost = 2.00191164296
# Epoch 232 train accuracy = 0.95641025641
# Epoch 232 test cost = 8.45451840758
# Epoch 232 test accuracy = 0.924679487179
# Epoch 233 train cost = 1.09164847527
# Epoch 233 train accuracy = 0.965384615385
# Epoch 233 test cost = 7.7808945477
# Epoch 233 test accuracy = 0.932692307692
# Epoch 234 train cost = 0.772593203932
# Epoch 234 train accuracy = 0.975641025641
# Epoch 234 test cost = 8.3378777504
# Epoch 234 test accuracy = 0.93108974359
# Epoch 235 train cost = 1.24608133547
# Epoch 235 train accuracy = 0.976923076923
# Epoch 235 test cost = 8.33262762427
# Epoch 235 test accuracy = 0.923076923077
# Epoch 236 train cost = 1.03580797138
# Epoch 236 train accuracy = 0.974358974359
# Epoch 236 test cost = 7.51119327545
# Epoch 236 test accuracy = 0.924679487179
# Epoch 237 train cost = 0.871991655789
# Epoch 237 train accuracy = 0.979487179487
# Epoch 237 test cost = 9.16407173127
# Epoch 237 test accuracy = 0.926282051282
# Epoch 238 train cost = 0.778687558137
# Epoch 238 train accuracy = 0.974358974359
# Epoch 238 test cost = 8.31011170149
# Epoch 238 test accuracy = 0.93108974359
# Epoch 239 train cost = 1.10931695346
# Epoch 239 train accuracy = 0.975641025641
# Epoch 239 test cost = 8.21057531238
# Epoch 239 test accuracy = 0.93108974359
# Epoch 240 train cost = 1.68683526386
# Epoch 240 train accuracy = 0.974358974359
# Epoch 240 test cost = 8.12237119675
# Epoch 240 test accuracy = 0.919871794872
# Epoch 241 train cost = 1.33403800614
# Epoch 241 train accuracy = 0.974358974359
# Epoch 241 test cost = 8.01920928061
# Epoch 241 test accuracy = 0.939102564103
# Epoch 242 train cost = 0.838539296295
# Epoch 242 train accuracy = 0.976923076923
# Epoch 242 test cost = 7.01578900218
# Epoch 242 test accuracy = 0.940705128205
# Epoch 243 train cost = 1.04701103503
# Epoch 243 train accuracy = 0.978205128205
# Epoch 243 test cost = 7.86442789435
# Epoch 243 test accuracy = 0.932692307692
# Epoch 244 train cost = 1.82384768501
# Epoch 244 train accuracy = 0.976923076923
# Epoch 244 test cost = 10.3921147585
# Epoch 244 test accuracy = 0.934294871795
# Epoch 245 train cost = 1.77876483276
# Epoch 245 train accuracy = 0.970512820513
# Epoch 245 test cost = 7.44378738105
# Epoch 245 test accuracy = 0.939102564103
# Epoch 246 train cost = 1.92833608016
# Epoch 246 train accuracy = 0.965384615385
# Epoch 246 test cost = 9.57475194335
# Epoch 246 test accuracy = 0.927884615385
# Epoch 247 train cost = 1.7183480789
# Epoch 247 train accuracy = 0.971794871795
# Epoch 247 test cost = 9.15712440014
# Epoch 247 test accuracy = 0.924679487179
# Epoch 248 train cost = 1.09938750044
# Epoch 248 train accuracy = 0.975641025641
# Epoch 248 test cost = 8.62348825485
# Epoch 248 test accuracy = 0.942307692308
# Epoch 249 train cost = 1.73072412796
# Epoch 249 train accuracy = 0.975641025641
# Epoch 249 test cost = 8.81127211452
# Epoch 249 test accuracy = 0.921474358974
# Epoch 250 train cost = 3.47595363855
# Epoch 250 train accuracy = 0.947435897436
# Epoch 250 test cost = 8.63797868788
# Epoch 250 test accuracy = 0.915064102564
# Epoch 251 train cost = 3.22712758556
# Epoch 251 train accuracy = 0.95
# Epoch 251 test cost = 10.045502454
# Epoch 251 test accuracy = 0.932692307692
# Epoch 252 train cost = 1.93945379183
# Epoch 252 train accuracy = 0.947435897436
# Epoch 252 test cost = 8.43586671352
# Epoch 252 test accuracy = 0.929487179487
# Epoch 253 train cost = 1.75455015525
# Epoch 253 train accuracy = 0.95641025641
# Epoch 253 test cost = 9.49444162846
# Epoch 253 test accuracy = 0.918269230769
# Epoch 254 train cost = 1.94760555774
# Epoch 254 train accuracy = 0.961538461538
# Epoch 254 test cost = 8.59514248371
# Epoch 254 test accuracy = 0.927884615385
# Epoch 255 train cost = 1.71041729441
# Epoch 255 train accuracy = 0.951282051282
# Epoch 255 test cost = 7.39261424541
# Epoch 255 test accuracy = 0.93108974359
# Epoch 256 train cost = 1.07935762592
# Epoch 256 train accuracy = 0.966666666667
# Epoch 256 test cost = 8.26943303645
# Epoch 256 test accuracy = 0.939102564103
# Epoch 257 train cost = 1.475651416
# Epoch 257 train accuracy = 0.973076923077
# Epoch 257 test cost = 8.1072242558
# Epoch 257 test accuracy = 0.93108974359
# Epoch 258 train cost = 1.05009736866
# Epoch 258 train accuracy = 0.975641025641
# Epoch 258 test cost = 8.41986012459
# Epoch 258 test accuracy = 0.924679487179
# Epoch 259 train cost = 1.32697214
# Epoch 259 train accuracy = 0.975641025641
# Epoch 259 test cost = 8.09133297205
# Epoch 259 test accuracy = 0.94391025641
# Epoch 260 train cost = 1.35565260984
# Epoch 260 train accuracy = 0.973076923077
# Epoch 260 test cost = 8.0600014627
# Epoch 260 test accuracy = 0.939102564103
# Epoch 261 train cost = 0.871494293213
# Epoch 261 train accuracy = 0.973076923077
# Epoch 261 test cost = 6.97489544749
# Epoch 261 test accuracy = 0.94391025641
# Epoch 262 train cost = 1.12759224698
# Epoch 262 train accuracy = 0.975641025641
# Epoch 262 test cost = 6.59231328964
# Epoch 262 test accuracy = 0.94391025641
# Epoch 263 train cost = 1.28769883979
# Epoch 263 train accuracy = 0.985897435897
# Epoch 263 test cost = 7.39152801037
# Epoch 263 test accuracy = 0.94391025641
# Epoch 264 train cost = 1.18066683877
# Epoch 264 train accuracy = 0.967948717949
# Epoch 264 test cost = 7.63077074289
# Epoch 264 test accuracy = 0.926282051282
# Epoch 265 train cost = 1.43472294509
# Epoch 265 train accuracy = 0.979487179487
# Epoch 265 test cost = 7.8463948369
# Epoch 265 test accuracy = 0.934294871795
# Epoch 266 train cost = 1.12826317828
# Epoch 266 train accuracy = 0.975641025641
# Epoch 266 test cost = 8.25978323817
# Epoch 266 test accuracy = 0.940705128205
# Epoch 267 train cost = 0.862652442418
# Epoch 267 train accuracy = 0.973076923077
# Epoch 267 test cost = 8.58816886693
# Epoch 267 test accuracy = 0.93108974359
# Epoch 268 train cost = 1.18109045085
# Epoch 268 train accuracy = 0.976923076923
# Epoch 268 test cost = 7.12117055058
# Epoch 268 test accuracy = 0.932692307692
# Epoch 269 train cost = 1.19977899175
# Epoch 269 train accuracy = 0.982051282051
# Epoch 269 test cost = 9.6395932138
# Epoch 269 test accuracy = 0.934294871795
# Epoch 270 train cost = 1.38418402337
# Epoch 270 train accuracy = 0.979487179487
# Epoch 270 test cost = 7.51891215146
# Epoch 270 test accuracy = 0.932692307692
# Epoch 271 train cost = 0.603238544427
# Epoch 271 train accuracy = 0.987179487179
# Epoch 271 test cost = 7.23501455784
# Epoch 271 test accuracy = 0.94391025641
# Epoch 272 train cost = 1.04565529479
# Epoch 272 train accuracy = 0.976923076923
# Epoch 272 test cost = 6.8161916472
# Epoch 272 test accuracy = 0.947115384615
# Epoch 273 train cost = 1.21586006694
# Epoch 273 train accuracy = 0.980769230769
# Epoch 273 test cost = 6.96800044179
# Epoch 273 test accuracy = 0.934294871795
# Epoch 274 train cost = 0.510911424644
# Epoch 274 train accuracy = 0.974358974359
# Epoch 274 test cost = 6.68939295411
# Epoch 274 test accuracy = 0.94391025641
# Epoch 275 train cost = 0.981347750872
# Epoch 275 train accuracy = 0.982051282051
# Epoch 275 test cost = 7.78517779708
# Epoch 275 test accuracy = 0.921474358974
# Epoch 276 train cost = 0.884257692378
# Epoch 276 train accuracy = 0.979487179487
# Epoch 276 test cost = 6.65217933059
# Epoch 276 test accuracy = 0.932692307692
# Epoch 277 train cost = 0.882657296024
# Epoch 277 train accuracy = 0.979487179487
# Epoch 277 test cost = 8.9770026505
# Epoch 277 test accuracy = 0.916666666667
# Epoch 278 train cost = 1.15384078026
# Epoch 278 train accuracy = 0.979487179487
# Epoch 278 test cost = 7.92218439281
# Epoch 278 test accuracy = 0.935897435897
# Epoch 279 train cost = 1.34133048169
# Epoch 279 train accuracy = 0.974358974359
# Epoch 279 test cost = 8.14776828885
# Epoch 279 test accuracy = 0.939102564103
# Epoch 280 train cost = 1.26853881078
# Epoch 280 train accuracy = 0.975641025641
# Epoch 280 test cost = 8.08125125617
# Epoch 280 test accuracy = 0.9375
# Epoch 281 train cost = 1.02517519705
# Epoch 281 train accuracy = 0.969230769231
# Epoch 281 test cost = 6.59897048771
# Epoch 281 test accuracy = 0.926282051282
# Epoch 282 train cost = 1.90332233906
# Epoch 282 train accuracy = 0.969230769231
# Epoch 282 test cost = 10.6038452685
# Epoch 282 test accuracy = 0.910256410256
# Epoch 283 train cost = 3.03295019269
# Epoch 283 train accuracy = 0.929487179487
# Epoch 283 test cost = 11.6162961125
# Epoch 283 test accuracy = 0.913461538462
# Epoch 284 train cost = 3.31653551757
# Epoch 284 train accuracy = 0.920512820513
# Epoch 284 test cost = 10.0881921053
# Epoch 284 test accuracy = 0.910256410256
# Epoch 285 train cost = 3.34912481904
# Epoch 285 train accuracy = 0.934615384615
# Epoch 285 test cost = 11.3529477417
# Epoch 285 test accuracy = 0.916666666667
# Epoch 286 train cost = 3.9913199991
# Epoch 286 train accuracy = 0.923076923077
# Epoch 286 test cost = 12.0256419219
# Epoch 286 test accuracy = 0.908653846154
# Epoch 287 train cost = 3.95421884954
# Epoch 287 train accuracy = 0.923076923077
# Epoch 287 test cost = 11.9427619874
# Epoch 287 test accuracy = 0.911858974359
# Epoch 288 train cost = 3.87203714252
# Epoch 288 train accuracy = 0.929487179487
# Epoch 288 test cost = 10.1450312734
# Epoch 288 test accuracy = 0.924679487179
# Epoch 289 train cost = 2.93830687553
# Epoch 289 train accuracy = 0.921794871795
# Epoch 289 test cost = 11.2746100426
# Epoch 289 test accuracy = 0.907051282051
# Epoch 290 train cost = 2.94412176311
# Epoch 290 train accuracy = 0.947435897436
# Epoch 290 test cost = 10.7125790417
# Epoch 290 test accuracy = 0.907051282051
# Epoch 291 train cost = 2.40386219323
# Epoch 291 train accuracy = 0.94358974359
# Epoch 291 test cost = 9.24041396379
# Epoch 291 test accuracy = 0.921474358974
# Epoch 292 train cost = 2.13370667771
# Epoch 292 train accuracy = 0.962820512821
# Epoch 292 test cost = 8.46997158229
# Epoch 292 test accuracy = 0.934294871795
# Epoch 293 train cost = 2.33520614356
# Epoch 293 train accuracy = 0.961538461538
# Epoch 293 test cost = 8.53912323713
# Epoch 293 test accuracy = 0.927884615385
# Epoch 294 train cost = 2.40656902641
# Epoch 294 train accuracy = 0.957692307692
# Epoch 294 test cost = 8.84581670165
# Epoch 294 test accuracy = 0.924679487179
# Epoch 295 train cost = 1.87292226963
# Epoch 295 train accuracy = 0.960256410256
# Epoch 295 test cost = 9.69748446345
# Epoch 295 test accuracy = 0.923076923077
# Epoch 296 train cost = 1.0688394513
# Epoch 296 train accuracy = 0.964102564103
# Epoch 296 test cost = 8.63626912236
# Epoch 296 test accuracy = 0.924679487179
# Epoch 297 train cost = 1.59835313447
# Epoch 297 train accuracy = 0.975641025641
# Epoch 297 test cost = 7.77771891654
# Epoch 297 test accuracy = 0.923076923077
# Epoch 298 train cost = 1.47312979028
# Epoch 298 train accuracy = 0.965384615385
# Epoch 298 test cost = 6.83051548898
# Epoch 298 test accuracy = 0.93108974359
# Epoch 299 train cost = 1.16053790227
# Epoch 299 train accuracy = 0.971794871795
# Epoch 299 test cost = 6.55868551135
# Epoch 299 test accuracy = 0.939102564103

# %%
# %matplotlib inline
plt.figure(1)
plt.plot(cost_train, 'c', cost_test, 'r', linewidth=2.0)
plt.legend(("cost_train", "cost_test"),'upper left')

plt.figure(2)
plt.plot(accuracy_train, 'y', accuracy_test, 'b', linewidth=2.0)
plt.legend(("accuracy_train", "accuracy_test"),'lower left')

print "train max", np.max(accuracy_train), " is at", np.argmax(accuracy_train), "epoch \n"  
print "test max", np.max(accuracy_test), " is at", np.argmax(accuracy_test), "epoch \n"  
#plt.show()
# Out:
# train max 0.991025641026  is at 223 epoch
#
# test max 0.947115384615  is at 102 epoch
# /home/zli/anaconda/lib/python2.7/site-packages/matplotlib/cbook.py:137: MatplotlibDeprecationWarning: The "loc" positional argument to legend is deprecated. Please use the "loc" keyword instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
