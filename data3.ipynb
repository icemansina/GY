# %%
import numpy as np
import scipy.io 
import theano.tensor as T
import lasagne
import string
import theano
import BatchNormLayer
import matplotlib.pylab as plt
batch_norm = BatchNormLayer.batch_norm
# Out:
# Using gpu device 2: GeForce GTX TITAN Black (CNMeM is disabled, CuDNN 3007)
# /home/zli/2016/ntm-lasagne/src/theano/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
############# TrainData and TestData Preparation #############

# trainx: 780*50*6 
# trainy: 780*52 or 780
# mask_train: 780*50
loaddata = scipy.io.loadmat('../dataset/Data3.mat')
traindata = loaddata['TrainData']
testdata = loaddata['TestData']

trainx = []
trainy = []

for i in xrange(traindata.shape[0]):
	for j in xrange(traindata.shape[1]):
		trainx.append(traindata[i][j])
		trainy.append(i)

trainx = np.asarray(trainx)
trainy = np.asarray(trainy)
mask_train = np.ones([trainx.shape[0], trainx.shape[1]])
#print trainy.shape
#print trainy

# testx: 624*20*6
# testy: 624*52 or 624
# mask_test: 624*20
testx = []
testy = []

for i in xrange(testdata.shape[0]):
	for j in xrange(testdata.shape[1]):
		testx.append(testdata[i][j])
		testy.append(i)

testx = np.asarray(testx)
testy = np.asarray(testy)
mask_test = np.ones([testx.shape[0], testx.shape[1]])
#print testy.shape
#print testy

# %%
##########  Initialize Parameters ########
N_BATCH = 52
MAX_LENGTH = trainx.shape[1]
features_num = 6
GRAD_CLIP = 100
TOL = 1e-5
LEARNING_RATE = 1e-2
N_HIDDEN = 120
num_epochs = 300

##########  Build Model for Prediction #######################
mask = np.ones([N_BATCH, MAX_LENGTH])
target_values = T.ivector('target_output')
sym_mask = T.matrix('mask')

print("Building network ...")

l_in = lasagne.layers.InputLayer(shape=(N_BATCH, MAX_LENGTH, features_num))
#l_mask = lasagne.layers.InputLayer(shape=(N_BATCH, MAX_LENGTH))
#### Bidirectional RNN layers ###
l_forward = lasagne.layers.GRULayer(
        l_in, N_HIDDEN, grad_clipping=GRAD_CLIP, only_return_final=True)
        #W_in_to_hid=lasagne.init.HeUniform(),
        #W_hid_to_hid=lasagne.init.HeUniform(),
        #nonlinearity=lasagne.nonlinearities.tanh, only_return_final=True)

l_backward = lasagne.layers.GRULayer(
        l_in, N_HIDDEN, grad_clipping=GRAD_CLIP, only_return_final=True, backwards=True)
        #W_in_to_hid=lasagne.init.HeUniform(),
        #W_hid_to_hid=lasagne.init.HeUniform(),
        #nonlinearity=lasagne.nonlinearities.tanh,
        #only_return_final=True, backwards=True)


l_concat = lasagne.layers.ConcatLayer([l_forward, l_backward])
l_concat = batch_norm(l_concat)

###  Softmax for prediction output ######
l_fc1 = lasagne.layers.DenseLayer(
	    lasagne.layers.dropout(l_concat, p=.5),
        num_units=100, nonlinearity=lasagne.nonlinearities.rectify)
l_fc1 = batch_norm(l_fc1)

l_out = lasagne.layers.DenseLayer(
	    lasagne.layers.dropout(l_fc1, p=.5),
        num_units=52, nonlinearity=lasagne.nonlinearities.softmax)
# Out:
# Building network ...

# %%
########### Debug ###########
all_layers = lasagne.layers.get_all_layers(l_out)
num_params = lasagne.layers.count_params(l_out)
print("  number of parameters: %d" % num_params)
print("  layer output shapes:")
for layer in all_layers:
	name = string.ljust(layer.__class__.__name__, 32)
	print("    %s %s" % (name, lasagne.layers.get_output_shape(layer)))

############## Compile the model, calculate cost, update ######################
#########  #######
network_output = lasagne.layers.get_output(l_out)

out_train = lasagne.layers.get_output(l_out, mask = sym_mask, deterministic=False)

out_test = lasagne.layers.get_output(l_out, mask = sym_mask, deterministic=True)

cost = T.nnet.categorical_crossentropy(T.clip(network_output, TOL, 1-TOL), target_values)
cost = cost.mean()
# Retrieve all parameters from the network
all_params = lasagne.layers.get_all_params(l_out, trainable=True)

all_grads = T.grad(cost, all_params)

updates, norm_calc = lasagne.updates.total_norm_constraint(all_grads, max_norm= 20, return_norm=True)

# Compute SGD updates for training
print("Computing updates ...")
#updates = lasagne.updates.adagrad(cost, all_params, LEARNING_RATE)
updates = lasagne.updates.adam(cost, all_params, LEARNING_RATE)

print("Compiling functions ...")
train = theano.function([l_in.input_var, target_values, sym_mask], \
	                    [cost, out_train], updates=updates, \
	                    on_unused_input='ignore', allow_input_downcast=True)
#compute_cost = theano.function([l_in.input_var, target_values, l_mask.input_var], cost)
test = theano.function([l_in.input_var, target_values, sym_mask], \
                        [cost, out_test], on_unused_input='ignore', allow_input_downcast=True)
# Out:
#   number of parameters: 122292
#   layer output shapes:
#     InputLayer                       (52, 100, 6)
#     GRULayer                         (52, 120)
#     GRULayer                         (52, 120)
#     ConcatLayer                      (52, 240)
#     BatchNormLayer                   (52, 240)
#     DropoutLayer                     (52, 240)
#     DenseLayer                       (52, 100)
#     BatchNormLayer                   (52, 100)
#     NonlinearityLayer                (52, 100)
#     DropoutLayer                     (52, 100)
#     DenseLayer                       (52, 52)
# Computing updates ...
# Compiling functions ...

# %%
print("Training ...")
seq_names = np.arange(0, trainx.shape[0])
np.random.shuffle(seq_names)
trainx = trainx[seq_names]
trainy = trainy[seq_names]  
mask_train = mask_train[seq_names]
cost_train = []
out_train = []
EPOCH_SIZE_TRAIN = trainx.shape[0]// N_BATCH
accuracy_train = []

seq_names_test = np.arange(0, testx.shape[0])
np.random.shuffle(seq_names_test)
testx = testx[seq_names_test]
testy = testy[seq_names_test]  
mask_test = mask_test[seq_names_test]
cost_test = []
out_test = []
EPOCH_SIZE_TEST = testx.shape[0]// N_BATCH
accuracy_test = []

for epoch in range(num_epochs):
	### Train part ###
    out_train_epoch = []
    cost_train_epoch = 0
    for i in xrange(EPOCH_SIZE_TRAIN):
    	idx = xrange(i*N_BATCH, (i+1)*N_BATCH)
    	x_batch = trainx[idx]
    	y_batch = trainy[idx]
    	mask_batch = mask_train[idx]

    	cost_train_batch, out_train_batch = train(x_batch, y_batch, mask_batch)
    	out_train_epoch.append(out_train_batch)
    	cost_train_epoch += cost_train_batch

    out_train_epoch = np.asarray(out_train_epoch)
    out_train_epoch = out_train_epoch.reshape(-1, 52)    
    out_train.append(out_train_epoch)
    cost_train.append(cost_train_epoch)
    ### Accuracy calculation ####
    sum = 0
    for i in xrange(out_train_epoch.shape[0]):
    	predict_label = np.argmax(out_train_epoch[i,:])
    	if predict_label == trainy[i]:
    		sum += 1
    accuracytrain = float(sum)/float(out_train_epoch.shape[0])
    accuracy_train.append(accuracytrain)
    print("Epoch {} train cost = {}".format(epoch, cost_train_epoch))
    print("Epoch {} train accuracy = {}".format(epoch, accuracytrain))

    ### Inference Part ###
    out_test_epoch = []
    cost_test_epoch = 0
    for i in range(EPOCH_SIZE_TEST):
		idx = range(i*N_BATCH, (i+1)*N_BATCH)
		x_batch = testx[idx]
		y_batch = testy[idx]
		mask_batch = mask_test[idx]

		cost_test_batch, out_test_batch = test(x_batch, y_batch, mask_batch)
		out_test_epoch.append(out_test_batch)
		cost_test_epoch += cost_test_batch

    out_test_epoch = np.asarray(out_test_epoch)
    out_test_epoch = out_test_epoch.reshape(-1, 52)
    out_test.append(out_test_epoch)
    cost_test.append(cost_test_epoch)
    #print out_test_epoch.shape
    #print out_test_epoch
    ### Accuracy calculation ####
    sum = 0
    for i in xrange(out_test_epoch.shape[0]):
    	predict_label = np.argmax(out_test_epoch[i,:])
    	if predict_label == testy[i]:
    		sum += 1
    accuracytest = float(sum)/float(out_test_epoch.shape[0])
    accuracy_test.append(accuracytest)
    print("Epoch {} test cost = {}".format(epoch, cost_test_epoch))
    print("Epoch {} test accuracy = {}".format(epoch, accuracytest))
# Out:
# Training ...
# Epoch 0 train cost = 59.459002018
# Epoch 0 train accuracy = 0.0589743589744
# Epoch 0 test cost = 40.1932826042
# Epoch 0 test accuracy = 0.0208333333333
# Epoch 1 train cost = 42.6897008419
# Epoch 1 train accuracy = 0.224358974359
# Epoch 1 test cost = 30.1495563984
# Epoch 1 test accuracy = 0.0432692307692
# Epoch 2 train cost = 33.6094149351
# Epoch 2 train accuracy = 0.329487179487
# Epoch 2 test cost = 25.1338933706
# Epoch 2 test accuracy = 0.133012820513
# Epoch 3 train cost = 27.5622451305
# Epoch 3 train accuracy = 0.420512820513
# Epoch 3 test cost = 21.4397633076
# Epoch 3 test accuracy = 0.163461538462
# Epoch 4 train cost = 22.9200246334
# Epoch 4 train accuracy = 0.498717948718
# Epoch 4 test cost = 19.6091940403
# Epoch 4 test accuracy = 0.217948717949
# Epoch 5 train cost = 21.3327196836
# Epoch 5 train accuracy = 0.538461538462
# Epoch 5 test cost = 17.6905485392
# Epoch 5 test accuracy = 0.216346153846
# Epoch 6 train cost = 18.7912461758
# Epoch 6 train accuracy = 0.630769230769
# Epoch 6 test cost = 17.0357153416
# Epoch 6 test accuracy = 0.286858974359
# Epoch 7 train cost = 18.6239883304
# Epoch 7 train accuracy = 0.632051282051
# Epoch 7 test cost = 16.8090717793
# Epoch 7 test accuracy = 0.200320512821
# Epoch 8 train cost = 15.6513509154
# Epoch 8 train accuracy = 0.641025641026
# Epoch 8 test cost = 16.0949178934
# Epoch 8 test accuracy = 0.216346153846
# Epoch 9 train cost = 16.0079683661
# Epoch 9 train accuracy = 0.669230769231
# Epoch 9 test cost = 15.1234335899
# Epoch 9 test accuracy = 0.405448717949
# Epoch 10 train cost = 14.2604604363
# Epoch 10 train accuracy = 0.657692307692
# Epoch 10 test cost = 15.4352713823
# Epoch 10 test accuracy = 0.360576923077
# Epoch 11 train cost = 14.259790957
# Epoch 11 train accuracy = 0.674358974359
# Epoch 11 test cost = 14.7253189683
# Epoch 11 test accuracy = 0.458333333333
# Epoch 12 train cost = 15.0030400157
# Epoch 12 train accuracy = 0.683333333333
# Epoch 12 test cost = 12.9971034527
# Epoch 12 test accuracy = 0.44391025641
# Epoch 13 train cost = 12.8260849416
# Epoch 13 train accuracy = 0.702564102564
# Epoch 13 test cost = 12.6222808957
# Epoch 13 test accuracy = 0.44391025641
# Epoch 14 train cost = 11.4765045047
# Epoch 14 train accuracy = 0.701282051282
# Epoch 14 test cost = 12.4415743351
# Epoch 14 test accuracy = 0.548076923077
# Epoch 15 train cost = 11.7234811783
# Epoch 15 train accuracy = 0.724358974359
# Epoch 15 test cost = 12.6421172023
# Epoch 15 test accuracy = 0.575320512821
# Epoch 16 train cost = 10.2348303199
# Epoch 16 train accuracy = 0.747435897436
# Epoch 16 test cost = 12.6660797
# Epoch 16 test accuracy = 0.663461538462
# Epoch 17 train cost = 10.9069575071
# Epoch 17 train accuracy = 0.758974358974
# Epoch 17 test cost = 12.1649825573
# Epoch 17 test accuracy = 0.650641025641
# Epoch 18 train cost = 10.5338586271
# Epoch 18 train accuracy = 0.748717948718
# Epoch 18 test cost = 12.0385254025
# Epoch 18 test accuracy = 0.581730769231
# Epoch 19 train cost = 10.7310471237
# Epoch 19 train accuracy = 0.74358974359
# Epoch 19 test cost = 11.6359113455
# Epoch 19 test accuracy = 0.604166666667
# Epoch 20 train cost = 9.8639511764
# Epoch 20 train accuracy = 0.761538461538
# Epoch 20 test cost = 11.5156487226
# Epoch 20 test accuracy = 0.748397435897
# Epoch 21 train cost = 9.19582784176
# Epoch 21 train accuracy = 0.773076923077
# Epoch 21 test cost = 12.5886169672
# Epoch 21 test accuracy = 0.770833333333
# Epoch 22 train cost = 8.85583281517
# Epoch 22 train accuracy = 0.785897435897
# Epoch 22 test cost = 11.840002656
# Epoch 22 test accuracy = 0.690705128205
# Epoch 23 train cost = 9.13802325726
# Epoch 23 train accuracy = 0.780769230769
# Epoch 23 test cost = 12.0519658923
# Epoch 23 test accuracy = 0.576923076923
# Epoch 24 train cost = 9.04979765415
# Epoch 24 train accuracy = 0.798717948718
# Epoch 24 test cost = 11.8682509065
# Epoch 24 test accuracy = 0.605769230769
# Epoch 25 train cost = 8.74792766571
# Epoch 25 train accuracy = 0.797435897436
# Epoch 25 test cost = 11.3348915577
# Epoch 25 test accuracy = 0.783653846154
# Epoch 26 train cost = 9.45452407002
# Epoch 26 train accuracy = 0.794871794872
# Epoch 26 test cost = 11.3478218913
# Epoch 26 test accuracy = 0.567307692308
# Epoch 27 train cost = 8.92919144034
# Epoch 27 train accuracy = 0.780769230769
# Epoch 27 test cost = 10.6678338051
# Epoch 27 test accuracy = 0.75641025641
# Epoch 28 train cost = 9.1487069726
# Epoch 28 train accuracy = 0.784615384615
# Epoch 28 test cost = 11.6643890738
# Epoch 28 test accuracy = 0.770833333333
# Epoch 29 train cost = 8.39149534702
# Epoch 29 train accuracy = 0.784615384615
# Epoch 29 test cost = 13.0650828481
# Epoch 29 test accuracy = 0.663461538462
# Epoch 30 train cost = 8.3470620513
# Epoch 30 train accuracy = 0.835897435897
# Epoch 30 test cost = 10.6453846693
# Epoch 30 test accuracy = 0.644230769231
# Epoch 31 train cost = 7.67721262574
# Epoch 31 train accuracy = 0.807692307692
# Epoch 31 test cost = 11.4596082568
# Epoch 31 test accuracy = 0.766025641026
# Epoch 32 train cost = 6.52486760914
# Epoch 32 train accuracy = 0.817948717949
# Epoch 32 test cost = 10.675062716
# Epoch 32 test accuracy = 0.666666666667
# Epoch 33 train cost = 7.15994590521
# Epoch 33 train accuracy = 0.832051282051
# Epoch 33 test cost = 10.1562345028
# Epoch 33 test accuracy = 0.817307692308
# Epoch 34 train cost = 6.75701509416
# Epoch 34 train accuracy = 0.841025641026
# Epoch 34 test cost = 9.97795307636
# Epoch 34 test accuracy = 0.786858974359
# Epoch 35 train cost = 6.75969207287
# Epoch 35 train accuracy = 0.832051282051
# Epoch 35 test cost = 11.1373047829
# Epoch 35 test accuracy = 0.799679487179
# Epoch 36 train cost = 6.48626512289
# Epoch 36 train accuracy = 0.848717948718
# Epoch 36 test cost = 10.0785609484
# Epoch 36 test accuracy = 0.799679487179
# Epoch 37 train cost = 6.19626779854
# Epoch 37 train accuracy = 0.855128205128
# Epoch 37 test cost = 10.7117706835
# Epoch 37 test accuracy = 0.706730769231
# Epoch 38 train cost = 6.20236495137
# Epoch 38 train accuracy = 0.839743589744
# Epoch 38 test cost = 10.8588266969
# Epoch 38 test accuracy = 0.839743589744
# Epoch 39 train cost = 6.58024911582
# Epoch 39 train accuracy = 0.839743589744
# Epoch 39 test cost = 10.0088698268
# Epoch 39 test accuracy = 0.798076923077
# Epoch 40 train cost = 5.92825594544
# Epoch 40 train accuracy = 0.873076923077
# Epoch 40 test cost = 10.7315475941
# Epoch 40 test accuracy = 0.838141025641
# Epoch 41 train cost = 5.41682311893
# Epoch 41 train accuracy = 0.857692307692
# Epoch 41 test cost = 9.36856406927
# Epoch 41 test accuracy = 0.870192307692
# Epoch 42 train cost = 5.86977089942
# Epoch 42 train accuracy = 0.866666666667
# Epoch 42 test cost = 10.4273534715
# Epoch 42 test accuracy = 0.807692307692
# Epoch 43 train cost = 6.98646745086
# Epoch 43 train accuracy = 0.865384615385
# Epoch 43 test cost = 11.3721311092
# Epoch 43 test accuracy = 0.684294871795
# Epoch 44 train cost = 6.00848898292
# Epoch 44 train accuracy = 0.848717948718
# Epoch 44 test cost = 10.2632565498
# Epoch 44 test accuracy = 0.814102564103
# Epoch 45 train cost = 5.64855715632
# Epoch 45 train accuracy = 0.857692307692
# Epoch 45 test cost = 10.2509451807
# Epoch 45 test accuracy = 0.878205128205
# Epoch 46 train cost = 5.50842951238
# Epoch 46 train accuracy = 0.855128205128
# Epoch 46 test cost = 10.518376112
# Epoch 46 test accuracy = 0.855769230769
# Epoch 47 train cost = 5.39469514787
# Epoch 47 train accuracy = 0.867948717949
# Epoch 47 test cost = 9.26314002275
# Epoch 47 test accuracy = 0.777243589744
# Epoch 48 train cost = 5.08647859097
# Epoch 48 train accuracy = 0.883333333333
# Epoch 48 test cost = 8.61460345984
# Epoch 48 test accuracy = 0.850961538462
# Epoch 49 train cost = 5.43509663641
# Epoch 49 train accuracy = 0.9
# Epoch 49 test cost = 9.76560795307
# Epoch 49 test accuracy = 0.817307692308
# Epoch 50 train cost = 5.60731568933
# Epoch 50 train accuracy = 0.880769230769
# Epoch 50 test cost = 9.24185842276
# Epoch 50 test accuracy = 0.847756410256
# Epoch 51 train cost = 5.48553666472
# Epoch 51 train accuracy = 0.892307692308
# Epoch 51 test cost = 9.99599856138
# Epoch 51 test accuracy = 0.834935897436
# Epoch 52 train cost = 5.41785922647
# Epoch 52 train accuracy = 0.892307692308
# Epoch 52 test cost = 9.16248357296
# Epoch 52 test accuracy = 0.798076923077
# Epoch 53 train cost = 4.41473521292
# Epoch 53 train accuracy = 0.878205128205
# Epoch 53 test cost = 9.79710668325
# Epoch 53 test accuracy = 0.883012820513
# Epoch 54 train cost = 4.20226836205
# Epoch 54 train accuracy = 0.880769230769
# Epoch 54 test cost = 8.99553927779
# Epoch 54 test accuracy = 0.865384615385
# Epoch 55 train cost = 4.82808686793
# Epoch 55 train accuracy = 0.884615384615
# Epoch 55 test cost = 8.31886091828
# Epoch 55 test accuracy = 0.873397435897
# Epoch 56 train cost = 4.77783595026
# Epoch 56 train accuracy = 0.894871794872
# Epoch 56 test cost = 8.72854542732
# Epoch 56 test accuracy = 0.858974358974
# Epoch 57 train cost = 4.80233074725
# Epoch 57 train accuracy = 0.896153846154
# Epoch 57 test cost = 9.2610976696
# Epoch 57 test accuracy = 0.863782051282
# Epoch 58 train cost = 6.01156519353
# Epoch 58 train accuracy = 0.887179487179
# Epoch 58 test cost = 8.37587034702
# Epoch 58 test accuracy = 0.894230769231
# Epoch 59 train cost = 5.12837472558
# Epoch 59 train accuracy = 0.897435897436
# Epoch 59 test cost = 10.130271256
# Epoch 59 test accuracy = 0.793269230769
# Epoch 60 train cost = 5.49229292572
# Epoch 60 train accuracy = 0.866666666667
# Epoch 60 test cost = 9.55426922441
# Epoch 60 test accuracy = 0.850961538462
# Epoch 61 train cost = 5.24368107319
# Epoch 61 train accuracy = 0.880769230769
# Epoch 61 test cost = 9.68113911152
# Epoch 61 test accuracy = 0.777243589744
# Epoch 62 train cost = 5.03520028293
# Epoch 62 train accuracy = 0.894871794872
# Epoch 62 test cost = 10.0672412813
# Epoch 62 test accuracy = 0.876602564103
# Epoch 63 train cost = 4.16005536914
# Epoch 63 train accuracy = 0.898717948718
# Epoch 63 test cost = 8.13670548797
# Epoch 63 test accuracy = 0.907051282051
# Epoch 64 train cost = 4.50485816598
# Epoch 64 train accuracy = 0.883333333333
# Epoch 64 test cost = 8.66468667984
# Epoch 64 test accuracy = 0.897435897436
# Epoch 65 train cost = 4.31738703698
# Epoch 65 train accuracy = 0.9
# Epoch 65 test cost = 7.74020135403
# Epoch 65 test accuracy = 0.897435897436
# Epoch 66 train cost = 4.52438266575
# Epoch 66 train accuracy = 0.910256410256
# Epoch 66 test cost = 8.11389663815
# Epoch 66 test accuracy = 0.88141025641
# Epoch 67 train cost = 3.7543426007
# Epoch 67 train accuracy = 0.898717948718
# Epoch 67 test cost = 8.99953609705
# Epoch 67 test accuracy = 0.889423076923
# Epoch 68 train cost = 3.87985733151
# Epoch 68 train accuracy = 0.888461538462
# Epoch 68 test cost = 9.10139667988
# Epoch 68 test accuracy = 0.830128205128
# Epoch 69 train cost = 3.85981744528
# Epoch 69 train accuracy = 0.897435897436
# Epoch 69 test cost = 8.22049149871
# Epoch 69 test accuracy = 0.871794871795
# Epoch 70 train cost = 4.01788404584
# Epoch 70 train accuracy = 0.897435897436
# Epoch 70 test cost = 9.61421296
# Epoch 70 test accuracy = 0.865384615385
# Epoch 71 train cost = 4.35497379303
# Epoch 71 train accuracy = 0.885897435897
# Epoch 71 test cost = 10.3035365343
# Epoch 71 test accuracy = 0.850961538462
# Epoch 72 train cost = 4.74647034705
# Epoch 72 train accuracy = 0.901282051282
# Epoch 72 test cost = 8.61501273513
# Epoch 72 test accuracy = 0.826923076923
# Epoch 73 train cost = 5.10315707326
# Epoch 73 train accuracy = 0.897435897436
# Epoch 73 test cost = 7.78386884928
# Epoch 73 test accuracy = 0.809294871795
# Epoch 74 train cost = 4.28922821581
# Epoch 74 train accuracy = 0.887179487179
# Epoch 74 test cost = 9.80352586508
# Epoch 74 test accuracy = 0.858974358974
# Epoch 75 train cost = 4.60036915541
# Epoch 75 train accuracy = 0.898717948718
# Epoch 75 test cost = 8.51404616237
# Epoch 75 test accuracy = 0.820512820513
# Epoch 76 train cost = 3.6658083275
# Epoch 76 train accuracy = 0.896153846154
# Epoch 76 test cost = 8.09477192163
# Epoch 76 test accuracy = 0.902243589744
# Epoch 77 train cost = 3.08614396304
# Epoch 77 train accuracy = 0.919230769231
# Epoch 77 test cost = 7.94174033403
# Epoch 77 test accuracy = 0.911858974359
# Epoch 78 train cost = 3.58199898899
# Epoch 78 train accuracy = 0.925641025641
# Epoch 78 test cost = 8.32308322191
# Epoch 78 test accuracy = 0.889423076923
# Epoch 79 train cost = 3.7544273138
# Epoch 79 train accuracy = 0.903846153846
# Epoch 79 test cost = 8.40957710147
# Epoch 79 test accuracy = 0.860576923077
# Epoch 80 train cost = 3.59866795689
# Epoch 80 train accuracy = 0.914102564103
# Epoch 80 test cost = 9.47732108831
# Epoch 80 test accuracy = 0.889423076923
# Epoch 81 train cost = 4.00218038261
# Epoch 81 train accuracy = 0.874358974359
# Epoch 81 test cost = 8.58388051391
# Epoch 81 test accuracy = 0.841346153846
# Epoch 82 train cost = 4.01182298362
# Epoch 82 train accuracy = 0.898717948718
# Epoch 82 test cost = 9.14477786422
# Epoch 82 test accuracy = 0.842948717949
# Epoch 83 train cost = 3.51414607465
# Epoch 83 train accuracy = 0.903846153846
# Epoch 83 test cost = 9.39074859023
# Epoch 83 test accuracy = 0.903846153846
# Epoch 84 train cost = 3.45953904465
# Epoch 84 train accuracy = 0.903846153846
# Epoch 84 test cost = 8.26888722181
# Epoch 84 test accuracy = 0.891025641026
# Epoch 85 train cost = 3.85480886698
# Epoch 85 train accuracy = 0.907692307692
# Epoch 85 test cost = 9.45091861486
# Epoch 85 test accuracy = 0.823717948718
# Epoch 86 train cost = 3.56008023024
# Epoch 86 train accuracy = 0.911538461538
# Epoch 86 test cost = 8.61141619086
# Epoch 86 test accuracy = 0.814102564103
# Epoch 87 train cost = 3.24337650836
# Epoch 87 train accuracy = 0.917948717949
# Epoch 87 test cost = 8.91850799322
# Epoch 87 test accuracy = 0.884615384615
# Epoch 88 train cost = 3.309369497
# Epoch 88 train accuracy = 0.929487179487
# Epoch 88 test cost = 9.07666954398
# Epoch 88 test accuracy = 0.886217948718
# Epoch 89 train cost = 3.45309708267
# Epoch 89 train accuracy = 0.928205128205
# Epoch 89 test cost = 7.58544942737
# Epoch 89 test accuracy = 0.905448717949
# Epoch 90 train cost = 3.43631250411
# Epoch 90 train accuracy = 0.908974358974
# Epoch 90 test cost = 8.93142208457
# Epoch 90 test accuracy = 0.903846153846
# Epoch 91 train cost = 3.20637094975
# Epoch 91 train accuracy = 0.938461538462
# Epoch 91 test cost = 8.32512307167
# Epoch 91 test accuracy = 0.913461538462
# Epoch 92 train cost = 3.50230191648
# Epoch 92 train accuracy = 0.932051282051
# Epoch 92 test cost = 9.08093437552
# Epoch 92 test accuracy = 0.884615384615
# Epoch 93 train cost = 3.50847481936
# Epoch 93 train accuracy = 0.926923076923
# Epoch 93 test cost = 9.20618748665
# Epoch 93 test accuracy = 0.907051282051
# Epoch 94 train cost = 3.14734102041
# Epoch 94 train accuracy = 0.919230769231
# Epoch 94 test cost = 8.17823457718
# Epoch 94 test accuracy = 0.892628205128
# Epoch 95 train cost = 3.13291247189
# Epoch 95 train accuracy = 0.915384615385
# Epoch 95 test cost = 8.53246697783
# Epoch 95 test accuracy = 0.887820512821
# Epoch 96 train cost = 3.04346691072
# Epoch 96 train accuracy = 0.929487179487
# Epoch 96 test cost = 9.32794511318
# Epoch 96 test accuracy = 0.892628205128
# Epoch 97 train cost = 3.00661221147
# Epoch 97 train accuracy = 0.939743589744
# Epoch 97 test cost = 8.4250459969
# Epoch 97 test accuracy = 0.894230769231
# Epoch 98 train cost = 3.56420778111
# Epoch 98 train accuracy = 0.935897435897
# Epoch 98 test cost = 8.89185267687
# Epoch 98 test accuracy = 0.918269230769
# Epoch 99 train cost = 2.96139863133
# Epoch 99 train accuracy = 0.937179487179
# Epoch 99 test cost = 8.13551956415
# Epoch 99 test accuracy = 0.883012820513
# Epoch 100 train cost = 2.60757806152
# Epoch 100 train accuracy = 0.928205128205
# Epoch 100 test cost = 8.63734063506
# Epoch 100 test accuracy = 0.900641025641
# Epoch 101 train cost = 2.70731142163
# Epoch 101 train accuracy = 0.928205128205
# Epoch 101 test cost = 7.89615732431
# Epoch 101 test accuracy = 0.915064102564
# Epoch 102 train cost = 3.42533521354
# Epoch 102 train accuracy = 0.937179487179
# Epoch 102 test cost = 7.38169024885
# Epoch 102 test accuracy = 0.899038461538
# Epoch 103 train cost = 2.8916227296
# Epoch 103 train accuracy = 0.924358974359
# Epoch 103 test cost = 8.4331535697
# Epoch 103 test accuracy = 0.921474358974
# Epoch 104 train cost = 2.69873758405
# Epoch 104 train accuracy = 0.926923076923
# Epoch 104 test cost = 9.58923584223
# Epoch 104 test accuracy = 0.897435897436
# Epoch 105 train cost = 2.73650237173
# Epoch 105 train accuracy = 0.926923076923
# Epoch 105 test cost = 8.22401824594
# Epoch 105 test accuracy = 0.884615384615
# Epoch 106 train cost = 3.0759761706
# Epoch 106 train accuracy = 0.926923076923
# Epoch 106 test cost = 8.63368904591
# Epoch 106 test accuracy = 0.889423076923
# Epoch 107 train cost = 3.52953889966
# Epoch 107 train accuracy = 0.923076923077
# Epoch 107 test cost = 8.7752596885
# Epoch 107 test accuracy = 0.791666666667
# Epoch 108 train cost = 3.235370785
# Epoch 108 train accuracy = 0.924358974359
# Epoch 108 test cost = 8.06662899256
# Epoch 108 test accuracy = 0.919871794872
# Epoch 109 train cost = 3.84407553822
# Epoch 109 train accuracy = 0.925641025641
# Epoch 109 test cost = 8.77203637362
# Epoch 109 test accuracy = 0.895833333333
# Epoch 110 train cost = 3.26262108982
# Epoch 110 train accuracy = 0.928205128205
# Epoch 110 test cost = 8.40470609069
# Epoch 110 test accuracy = 0.871794871795
# Epoch 111 train cost = 2.48871809244
# Epoch 111 train accuracy = 0.935897435897
# Epoch 111 test cost = 7.99203041196
# Epoch 111 test accuracy = 0.905448717949
# Epoch 112 train cost = 2.37771170214
# Epoch 112 train accuracy = 0.937179487179
# Epoch 112 test cost = 8.05393102765
# Epoch 112 test accuracy = 0.924679487179
# Epoch 113 train cost = 2.43112228066
# Epoch 113 train accuracy = 0.942307692308
# Epoch 113 test cost = 7.99964734912
# Epoch 113 test accuracy = 0.907051282051
# Epoch 114 train cost = 2.06336501986
# Epoch 114 train accuracy = 0.95
# Epoch 114 test cost = 7.43169297278
# Epoch 114 test accuracy = 0.910256410256
# Epoch 115 train cost = 2.64400465414
# Epoch 115 train accuracy = 0.953846153846
# Epoch 115 test cost = 8.24609383941
# Epoch 115 test accuracy = 0.883012820513
# Epoch 116 train cost = 3.07556137443
# Epoch 116 train accuracy = 0.937179487179
# Epoch 116 test cost = 7.87186685205
# Epoch 116 test accuracy = 0.889423076923
# Epoch 117 train cost = 2.98667281866
# Epoch 117 train accuracy = 0.934615384615
# Epoch 117 test cost = 7.6979445219
# Epoch 117 test accuracy = 0.899038461538
# Epoch 118 train cost = 2.87088505924
# Epoch 118 train accuracy = 0.942307692308
# Epoch 118 test cost = 7.31641501188
# Epoch 118 test accuracy = 0.884615384615
# Epoch 119 train cost = 2.9514542371
# Epoch 119 train accuracy = 0.916666666667
# Epoch 119 test cost = 8.17469215393
# Epoch 119 test accuracy = 0.889423076923
# Epoch 120 train cost = 2.58137284964
# Epoch 120 train accuracy = 0.933333333333
# Epoch 120 test cost = 8.62177801132
# Epoch 120 test accuracy = 0.900641025641
# Epoch 121 train cost = 2.4490230903
# Epoch 121 train accuracy = 0.925641025641
# Epoch 121 test cost = 8.55883124471
# Epoch 121 test accuracy = 0.915064102564
# Epoch 122 train cost = 2.67311814427
# Epoch 122 train accuracy = 0.941025641026
# Epoch 122 test cost = 9.48931974173
# Epoch 122 test accuracy = 0.891025641026
# Epoch 123 train cost = 3.27002900094
# Epoch 123 train accuracy = 0.917948717949
# Epoch 123 test cost = 7.7786051929
# Epoch 123 test accuracy = 0.903846153846
# Epoch 124 train cost = 2.80998558179
# Epoch 124 train accuracy = 0.935897435897
# Epoch 124 test cost = 8.85552126169
# Epoch 124 test accuracy = 0.915064102564
# Epoch 125 train cost = 2.85916965082
# Epoch 125 train accuracy = 0.957692307692
# Epoch 125 test cost = 7.65222251415
# Epoch 125 test accuracy = 0.929487179487
# Epoch 126 train cost = 2.47663184255
# Epoch 126 train accuracy = 0.941025641026
# Epoch 126 test cost = 8.51168361306
# Epoch 126 test accuracy = 0.929487179487
# Epoch 127 train cost = 2.36909293383
# Epoch 127 train accuracy = 0.95641025641
# Epoch 127 test cost = 8.61102572083
# Epoch 127 test accuracy = 0.93108974359
# Epoch 128 train cost = 2.37539455295
# Epoch 128 train accuracy = 0.938461538462
# Epoch 128 test cost = 6.34578877687
# Epoch 128 test accuracy = 0.929487179487
# Epoch 129 train cost = 3.01766189188
# Epoch 129 train accuracy = 0.953846153846
# Epoch 129 test cost = 8.95298787951
# Epoch 129 test accuracy = 0.855769230769
# Epoch 130 train cost = 3.74427469075
# Epoch 130 train accuracy = 0.934615384615
# Epoch 130 test cost = 8.08437776566
# Epoch 130 test accuracy = 0.905448717949
# Epoch 131 train cost = 2.31142789498
# Epoch 131 train accuracy = 0.932051282051
# Epoch 131 test cost = 7.82456082106
# Epoch 131 test accuracy = 0.876602564103
# Epoch 132 train cost = 2.84607017413
# Epoch 132 train accuracy = 0.928205128205
# Epoch 132 test cost = 7.96262806654
# Epoch 132 test accuracy = 0.926282051282
# Epoch 133 train cost = 2.58036268502
# Epoch 133 train accuracy = 0.935897435897
# Epoch 133 test cost = 7.6642242521
# Epoch 133 test accuracy = 0.918269230769
# Epoch 134 train cost = 2.0975757502
# Epoch 134 train accuracy = 0.948717948718
# Epoch 134 test cost = 8.09313794971
# Epoch 134 test accuracy = 0.915064102564
# Epoch 135 train cost = 2.02758575976
# Epoch 135 train accuracy = 0.947435897436
# Epoch 135 test cost = 7.9527733326
# Epoch 135 test accuracy = 0.919871794872
# Epoch 136 train cost = 2.57271015644
# Epoch 136 train accuracy = 0.939743589744
# Epoch 136 test cost = 7.81336048245
# Epoch 136 test accuracy = 0.895833333333
# Epoch 137 train cost = 2.48187190294
# Epoch 137 train accuracy = 0.938461538462
# Epoch 137 test cost = 9.31149715185
# Epoch 137 test accuracy = 0.913461538462
# Epoch 138 train cost = 2.78363972157
# Epoch 138 train accuracy = 0.946153846154
# Epoch 138 test cost = 8.10327041149
# Epoch 138 test accuracy = 0.93108974359
# Epoch 139 train cost = 2.03116684407
# Epoch 139 train accuracy = 0.947435897436
# Epoch 139 test cost = 8.80713272095
# Epoch 139 test accuracy = 0.913461538462
# Epoch 140 train cost = 2.40997420624
# Epoch 140 train accuracy = 0.951282051282
# Epoch 140 test cost = 8.61661699414
# Epoch 140 test accuracy = 0.919871794872
# Epoch 141 train cost = 2.2849916853
# Epoch 141 train accuracy = 0.932051282051
# Epoch 141 test cost = 8.50426083803
# Epoch 141 test accuracy = 0.921474358974
# Epoch 142 train cost = 1.98070305586
# Epoch 142 train accuracy = 0.944871794872
# Epoch 142 test cost = 8.44318562746
# Epoch 142 test accuracy = 0.899038461538
# Epoch 143 train cost = 1.64463297278
# Epoch 143 train accuracy = 0.94358974359
# Epoch 143 test cost = 8.01398634911
# Epoch 143 test accuracy = 0.934294871795
# Epoch 144 train cost = 2.01124148071
# Epoch 144 train accuracy = 0.952564102564
# Epoch 144 test cost = 8.53726804256
# Epoch 144 test accuracy = 0.926282051282
# Epoch 145 train cost = 2.24426888674
# Epoch 145 train accuracy = 0.948717948718
# Epoch 145 test cost = 7.61930510402
# Epoch 145 test accuracy = 0.915064102564
# Epoch 146 train cost = 2.50116870552
# Epoch 146 train accuracy = 0.941025641026
# Epoch 146 test cost = 8.86243912578
# Epoch 146 test accuracy = 0.927884615385
# Epoch 147 train cost = 2.25616613775
# Epoch 147 train accuracy = 0.95641025641
# Epoch 147 test cost = 7.35364538431
# Epoch 147 test accuracy = 0.918269230769
# Epoch 148 train cost = 2.04557737336
# Epoch 148 train accuracy = 0.938461538462
# Epoch 148 test cost = 8.85612255335
# Epoch 148 test accuracy = 0.926282051282
# Epoch 149 train cost = 1.96067403257
# Epoch 149 train accuracy = 0.948717948718
# Epoch 149 test cost = 8.50287377834
# Epoch 149 test accuracy = 0.919871794872
# Epoch 150 train cost = 2.19139815122
# Epoch 150 train accuracy = 0.953846153846
# Epoch 150 test cost = 8.04921039939
# Epoch 150 test accuracy = 0.892628205128
# Epoch 151 train cost = 1.6202425193
# Epoch 151 train accuracy = 0.95641025641
# Epoch 151 test cost = 7.21071836352
# Epoch 151 test accuracy = 0.900641025641
# Epoch 152 train cost = 1.99397992343
# Epoch 152 train accuracy = 0.964102564103
# Epoch 152 test cost = 6.92714518309
# Epoch 152 test accuracy = 0.924679487179
# Epoch 153 train cost = 1.71154833212
# Epoch 153 train accuracy = 0.952564102564
# Epoch 153 test cost = 7.69665023685
# Epoch 153 test accuracy = 0.891025641026
# Epoch 154 train cost = 2.21277618036
# Epoch 154 train accuracy = 0.944871794872
# Epoch 154 test cost = 8.32713606954
# Epoch 154 test accuracy = 0.926282051282
# Epoch 155 train cost = 2.22077179141
# Epoch 155 train accuracy = 0.935897435897
# Epoch 155 test cost = 7.33715718985
# Epoch 155 test accuracy = 0.910256410256
# Epoch 156 train cost = 2.55453857407
# Epoch 156 train accuracy = 0.933333333333
# Epoch 156 test cost = 9.7839345336
# Epoch 156 test accuracy = 0.887820512821
# Epoch 157 train cost = 1.99364741147
# Epoch 157 train accuracy = 0.944871794872
# Epoch 157 test cost = 8.25744691491
# Epoch 157 test accuracy = 0.900641025641
# Epoch 158 train cost = 2.1464615576
# Epoch 158 train accuracy = 0.961538461538
# Epoch 158 test cost = 8.26825588942
# Epoch 158 test accuracy = 0.929487179487
# Epoch 159 train cost = 2.50545807928
# Epoch 159 train accuracy = 0.95
# Epoch 159 test cost = 8.49004305899
# Epoch 159 test accuracy = 0.911858974359
# Epoch 160 train cost = 2.26937998272
# Epoch 160 train accuracy = 0.928205128205
# Epoch 160 test cost = 7.94623076916
# Epoch 160 test accuracy = 0.891025641026
# Epoch 161 train cost = 1.99317367375
# Epoch 161 train accuracy = 0.95641025641
# Epoch 161 test cost = 7.65825325251
# Epoch 161 test accuracy = 0.903846153846
# Epoch 162 train cost = 1.92163553834
# Epoch 162 train accuracy = 0.941025641026
# Epoch 162 test cost = 7.88418215513
# Epoch 162 test accuracy = 0.926282051282
# Epoch 163 train cost = 2.91372926533
# Epoch 163 train accuracy = 0.94358974359
# Epoch 163 test cost = 9.52556274831
# Epoch 163 test accuracy = 0.907051282051
# Epoch 164 train cost = 2.52025783807
# Epoch 164 train accuracy = 0.935897435897
# Epoch 164 test cost = 8.68406867981
# Epoch 164 test accuracy = 0.918269230769
# Epoch 165 train cost = 2.52717531472
# Epoch 165 train accuracy = 0.947435897436
# Epoch 165 test cost = 9.16494221985
# Epoch 165 test accuracy = 0.889423076923
# Epoch 166 train cost = 2.31262009591
# Epoch 166 train accuracy = 0.94358974359
# Epoch 166 test cost = 8.16022381186
# Epoch 166 test accuracy = 0.916666666667
# Epoch 167 train cost = 2.30961475894
# Epoch 167 train accuracy = 0.942307692308
# Epoch 167 test cost = 7.30628423393
# Epoch 167 test accuracy = 0.929487179487
# Epoch 168 train cost = 2.28454854339
# Epoch 168 train accuracy = 0.969230769231
# Epoch 168 test cost = 6.80397748947
# Epoch 168 test accuracy = 0.934294871795
# Epoch 169 train cost = 1.86339537706
# Epoch 169 train accuracy = 0.965384615385
# Epoch 169 test cost = 7.09046857059
# Epoch 169 test accuracy = 0.929487179487
# Epoch 170 train cost = 1.97725975513
# Epoch 170 train accuracy = 0.964102564103
# Epoch 170 test cost = 7.65110319853
# Epoch 170 test accuracy = 0.935897435897
# Epoch 171 train cost = 1.78034514561
# Epoch 171 train accuracy = 0.955128205128
# Epoch 171 test cost = 7.60973896086
# Epoch 171 test accuracy = 0.918269230769
# Epoch 172 train cost = 1.86813177541
# Epoch 172 train accuracy = 0.955128205128
# Epoch 172 test cost = 7.66198259592
# Epoch 172 test accuracy = 0.923076923077
# Epoch 173 train cost = 2.01980716828
# Epoch 173 train accuracy = 0.969230769231
# Epoch 173 test cost = 6.86028183997
# Epoch 173 test accuracy = 0.9375
# Epoch 174 train cost = 1.67627636716
# Epoch 174 train accuracy = 0.958974358974
# Epoch 174 test cost = 7.500651896
# Epoch 174 test accuracy = 0.934294871795
# Epoch 175 train cost = 1.49989205785
# Epoch 175 train accuracy = 0.958974358974
# Epoch 175 test cost = 8.00474578142
# Epoch 175 test accuracy = 0.926282051282
# Epoch 176 train cost = 2.22989982739
# Epoch 176 train accuracy = 0.952564102564
# Epoch 176 test cost = 7.23347406089
# Epoch 176 test accuracy = 0.934294871795
# Epoch 177 train cost = 1.84156948328
# Epoch 177 train accuracy = 0.955128205128
# Epoch 177 test cost = 7.9391593039
# Epoch 177 test accuracy = 0.94391025641
# Epoch 178 train cost = 1.72222725302
# Epoch 178 train accuracy = 0.965384615385
# Epoch 178 test cost = 7.72981745005
# Epoch 178 test accuracy = 0.923076923077
# Epoch 179 train cost = 2.02849122509
# Epoch 179 train accuracy = 0.964102564103
# Epoch 179 test cost = 6.34897772968
# Epoch 179 test accuracy = 0.9375
# Epoch 180 train cost = 1.66664714366
# Epoch 180 train accuracy = 0.953846153846
# Epoch 180 test cost = 8.23714026809
# Epoch 180 test accuracy = 0.9375
# Epoch 181 train cost = 2.06820929237
# Epoch 181 train accuracy = 0.967948717949
# Epoch 181 test cost = 7.84394818544
# Epoch 181 test accuracy = 0.924679487179
# Epoch 182 train cost = 2.03021443263
# Epoch 182 train accuracy = 0.969230769231
# Epoch 182 test cost = 6.81995145977
# Epoch 182 test accuracy = 0.903846153846
# Epoch 183 train cost = 2.06386718154
# Epoch 183 train accuracy = 0.932051282051
# Epoch 183 test cost = 7.21856918931
# Epoch 183 test accuracy = 0.926282051282
# Epoch 184 train cost = 1.66566542536
# Epoch 184 train accuracy = 0.955128205128
# Epoch 184 test cost = 7.78907765448
# Epoch 184 test accuracy = 0.919871794872
# Epoch 185 train cost = 2.01315456629
# Epoch 185 train accuracy = 0.964102564103
# Epoch 185 test cost = 8.59172677994
# Epoch 185 test accuracy = 0.932692307692
# Epoch 186 train cost = 1.5811367631
# Epoch 186 train accuracy = 0.952564102564
# Epoch 186 test cost = 8.25797331333
# Epoch 186 test accuracy = 0.924679487179
# Epoch 187 train cost = 1.60570419952
# Epoch 187 train accuracy = 0.964102564103
# Epoch 187 test cost = 6.53807616234
# Epoch 187 test accuracy = 0.927884615385
# Epoch 188 train cost = 1.44375378266
# Epoch 188 train accuracy = 0.967948717949
# Epoch 188 test cost = 7.12349313498
# Epoch 188 test accuracy = 0.939102564103
# Epoch 189 train cost = 1.4522570055
# Epoch 189 train accuracy = 0.95
# Epoch 189 test cost = 7.06362378597
# Epoch 189 test accuracy = 0.934294871795
# Epoch 190 train cost = 1.41226181574
# Epoch 190 train accuracy = 0.973076923077
# Epoch 190 test cost = 8.25704932213
# Epoch 190 test accuracy = 0.921474358974
# Epoch 191 train cost = 1.37889558449
# Epoch 191 train accuracy = 0.966666666667
# Epoch 191 test cost = 6.99284189939
# Epoch 191 test accuracy = 0.935897435897
# Epoch 192 train cost = 1.4426604528
# Epoch 192 train accuracy = 0.960256410256
# Epoch 192 test cost = 7.23171129823
# Epoch 192 test accuracy = 0.935897435897
# Epoch 193 train cost = 2.21106092073
# Epoch 193 train accuracy = 0.953846153846
# Epoch 193 test cost = 8.76345607638
# Epoch 193 test accuracy = 0.916666666667
# Epoch 194 train cost = 1.80803511851
# Epoch 194 train accuracy = 0.961538461538
# Epoch 194 test cost = 8.12832197547
# Epoch 194 test accuracy = 0.899038461538
# Epoch 195 train cost = 1.61656844802
# Epoch 195 train accuracy = 0.948717948718
# Epoch 195 test cost = 8.42039324343
# Epoch 195 test accuracy = 0.897435897436
# Epoch 196 train cost = 1.51958874613
# Epoch 196 train accuracy = 0.947435897436
# Epoch 196 test cost = 7.09786137938
# Epoch 196 test accuracy = 0.934294871795
# Epoch 197 train cost = 1.46388592478
# Epoch 197 train accuracy = 0.969230769231
# Epoch 197 test cost = 7.53120265901
# Epoch 197 test accuracy = 0.934294871795
# Epoch 198 train cost = 1.24941217061
# Epoch 198 train accuracy = 0.964102564103
# Epoch 198 test cost = 7.5216165781
# Epoch 198 test accuracy = 0.935897435897
# Epoch 199 train cost = 1.37416909635
# Epoch 199 train accuracy = 0.957692307692
# Epoch 199 test cost = 7.31744888425
# Epoch 199 test accuracy = 0.915064102564
# Epoch 200 train cost = 1.73636406288
# Epoch 200 train accuracy = 0.965384615385
# Epoch 200 test cost = 8.28130030632
# Epoch 200 test accuracy = 0.929487179487
# Epoch 201 train cost = 1.52149136178
# Epoch 201 train accuracy = 0.966666666667
# Epoch 201 test cost = 6.61883182824
# Epoch 201 test accuracy = 0.939102564103
# Epoch 202 train cost = 2.02546611987
# Epoch 202 train accuracy = 0.952564102564
# Epoch 202 test cost = 8.68062368035
# Epoch 202 test accuracy = 0.924679487179
# Epoch 203 train cost = 1.51253855042
# Epoch 203 train accuracy = 0.961538461538
# Epoch 203 test cost = 9.15024968982
# Epoch 203 test accuracy = 0.927884615385
# Epoch 204 train cost = 2.11749981716
# Epoch 204 train accuracy = 0.944871794872
# Epoch 204 test cost = 7.97889062762
# Epoch 204 test accuracy = 0.926282051282
# Epoch 205 train cost = 2.26075765863
# Epoch 205 train accuracy = 0.961538461538
# Epoch 205 test cost = 7.87873211503
# Epoch 205 test accuracy = 0.891025641026
# Epoch 206 train cost = 1.93181842938
# Epoch 206 train accuracy = 0.952564102564
# Epoch 206 test cost = 9.29169815779
# Epoch 206 test accuracy = 0.926282051282
# Epoch 207 train cost = 1.90566038713
# Epoch 207 train accuracy = 0.961538461538
# Epoch 207 test cost = 8.38933104277
# Epoch 207 test accuracy = 0.93108974359
# Epoch 208 train cost = 1.14454666525
# Epoch 208 train accuracy = 0.962820512821
# Epoch 208 test cost = 8.7787656188
# Epoch 208 test accuracy = 0.929487179487
# Epoch 209 train cost = 1.6598047968
# Epoch 209 train accuracy = 0.970512820513
# Epoch 209 test cost = 8.71972921491
# Epoch 209 test accuracy = 0.926282051282
# Epoch 210 train cost = 1.68427656684
# Epoch 210 train accuracy = 0.964102564103
# Epoch 210 test cost = 9.30962759256
# Epoch 210 test accuracy = 0.927884615385
# Epoch 211 train cost = 1.61541958526
# Epoch 211 train accuracy = 0.952564102564
# Epoch 211 test cost = 8.21320980787
# Epoch 211 test accuracy = 0.926282051282
# Epoch 212 train cost = 2.48128253501
# Epoch 212 train accuracy = 0.955128205128
# Epoch 212 test cost = 10.871180594
# Epoch 212 test accuracy = 0.899038461538
# Epoch 213 train cost = 2.41893360578
# Epoch 213 train accuracy = 0.955128205128
# Epoch 213 test cost = 8.87348905206
# Epoch 213 test accuracy = 0.894230769231
# Epoch 214 train cost = 1.7171326112
# Epoch 214 train accuracy = 0.942307692308
# Epoch 214 test cost = 8.23165152967
# Epoch 214 test accuracy = 0.932692307692
# Epoch 215 train cost = 3.11377821118
# Epoch 215 train accuracy = 0.953846153846
# Epoch 215 test cost = 8.16127213836
# Epoch 215 test accuracy = 0.918269230769
# Epoch 216 train cost = 1.71197876707
# Epoch 216 train accuracy = 0.948717948718
# Epoch 216 test cost = 8.26608029008
# Epoch 216 test accuracy = 0.924679487179
# Epoch 217 train cost = 1.98395287618
# Epoch 217 train accuracy = 0.952564102564
# Epoch 217 test cost = 9.44050583243
# Epoch 217 test accuracy = 0.889423076923
# Epoch 218 train cost = 2.53877622448
# Epoch 218 train accuracy = 0.951282051282
# Epoch 218 test cost = 7.38309961557
# Epoch 218 test accuracy = 0.929487179487
# Epoch 219 train cost = 2.46775010973
# Epoch 219 train accuracy = 0.951282051282
# Epoch 219 test cost = 9.70335125923
# Epoch 219 test accuracy = 0.919871794872
# Epoch 220 train cost = 2.41648420319
# Epoch 220 train accuracy = 0.951282051282
# Epoch 220 test cost = 9.65025138855
# Epoch 220 test accuracy = 0.900641025641
# Epoch 221 train cost = 1.89922999218
# Epoch 221 train accuracy = 0.944871794872
# Epoch 221 test cost = 8.92183154821
# Epoch 221 test accuracy = 0.924679487179
# Epoch 222 train cost = 1.73987666331
# Epoch 222 train accuracy = 0.942307692308
# Epoch 222 test cost = 7.65493097901
# Epoch 222 test accuracy = 0.934294871795
# Epoch 223 train cost = 1.95140377246
# Epoch 223 train accuracy = 0.970512820513
# Epoch 223 test cost = 8.12802624702
# Epoch 223 test accuracy = 0.926282051282
# Epoch 224 train cost = 1.85173001513
# Epoch 224 train accuracy = 0.948717948718
# Epoch 224 test cost = 7.49702170491
# Epoch 224 test accuracy = 0.924679487179
# Epoch 225 train cost = 1.89148227684
# Epoch 225 train accuracy = 0.946153846154
# Epoch 225 test cost = 8.71350866556
# Epoch 225 test accuracy = 0.927884615385
# Epoch 226 train cost = 1.51338736899
# Epoch 226 train accuracy = 0.958974358974
# Epoch 226 test cost = 7.30834057927
# Epoch 226 test accuracy = 0.942307692308
# Epoch 227 train cost = 1.64844034985
# Epoch 227 train accuracy = 0.960256410256
# Epoch 227 test cost = 9.13226541877
# Epoch 227 test accuracy = 0.932692307692
# Epoch 228 train cost = 2.25491342042
# Epoch 228 train accuracy = 0.953846153846
# Epoch 228 test cost = 7.1727693975
# Epoch 228 test accuracy = 0.927884615385
# Epoch 229 train cost = 2.15347350016
# Epoch 229 train accuracy = 0.969230769231
# Epoch 229 test cost = 5.91059890389
# Epoch 229 test accuracy = 0.945512820513
# Epoch 230 train cost = 1.8169740662
# Epoch 230 train accuracy = 0.974358974359
# Epoch 230 test cost = 7.56045992672
# Epoch 230 test accuracy = 0.932692307692
# Epoch 231 train cost = 1.14397618268
# Epoch 231 train accuracy = 0.966666666667
# Epoch 231 test cost = 7.09253719449
# Epoch 231 test accuracy = 0.93108974359
# Epoch 232 train cost = 1.4282142669
# Epoch 232 train accuracy = 0.973076923077
# Epoch 232 test cost = 7.06817758083
# Epoch 232 test accuracy = 0.927884615385
# Epoch 233 train cost = 1.41252409481
# Epoch 233 train accuracy = 0.957692307692
# Epoch 233 test cost = 8.58036968112
# Epoch 233 test accuracy = 0.945512820513
# Epoch 234 train cost = 0.986235225573
# Epoch 234 train accuracy = 0.971794871795
# Epoch 234 test cost = 6.68081067502
# Epoch 234 test accuracy = 0.939102564103
# Epoch 235 train cost = 1.29757598788
# Epoch 235 train accuracy = 0.976923076923
# Epoch 235 test cost = 7.48305605352
# Epoch 235 test accuracy = 0.927884615385
# Epoch 236 train cost = 1.4774597045
# Epoch 236 train accuracy = 0.967948717949
# Epoch 236 test cost = 7.66752735525
# Epoch 236 test accuracy = 0.934294871795
# Epoch 237 train cost = 1.38686372712
# Epoch 237 train accuracy = 0.966666666667
# Epoch 237 test cost = 7.68246808648
# Epoch 237 test accuracy = 0.9375
# Epoch 238 train cost = 1.39890846517
# Epoch 238 train accuracy = 0.975641025641
# Epoch 238 test cost = 7.17318376899
# Epoch 238 test accuracy = 0.932692307692
# Epoch 239 train cost = 1.01393226255
# Epoch 239 train accuracy = 0.970512820513
# Epoch 239 test cost = 7.99104996026
# Epoch 239 test accuracy = 0.923076923077
# Epoch 240 train cost = 1.43999962509
# Epoch 240 train accuracy = 0.974358974359
# Epoch 240 test cost = 7.85781249404
# Epoch 240 test accuracy = 0.94391025641
# Epoch 241 train cost = 0.928559467662
# Epoch 241 train accuracy = 0.969230769231
# Epoch 241 test cost = 8.3139180243
# Epoch 241 test accuracy = 0.940705128205
# Epoch 242 train cost = 1.17368012294
# Epoch 242 train accuracy = 0.971794871795
# Epoch 242 test cost = 6.67787179351
# Epoch 242 test accuracy = 0.951923076923
# Epoch 243 train cost = 1.240577586
# Epoch 243 train accuracy = 0.969230769231
# Epoch 243 test cost = 7.97057667375
# Epoch 243 test accuracy = 0.948717948718
# Epoch 244 train cost = 1.56014509453
# Epoch 244 train accuracy = 0.971794871795
# Epoch 244 test cost = 7.47943300009
# Epoch 244 test accuracy = 0.9375
# Epoch 245 train cost = 1.2968508983
# Epoch 245 train accuracy = 0.961538461538
# Epoch 245 test cost = 7.80620364845
# Epoch 245 test accuracy = 0.926282051282
# Epoch 246 train cost = 1.80768971518
# Epoch 246 train accuracy = 0.967948717949
# Epoch 246 test cost = 7.82880263031
# Epoch 246 test accuracy = 0.942307692308
# Epoch 247 train cost = 1.4637559969
# Epoch 247 train accuracy = 0.961538461538
# Epoch 247 test cost = 7.65991723537
# Epoch 247 test accuracy = 0.9375
# Epoch 248 train cost = 1.87536644191
# Epoch 248 train accuracy = 0.964102564103
# Epoch 248 test cost = 8.31333744526
# Epoch 248 test accuracy = 0.929487179487
# Epoch 249 train cost = 1.49259269144
# Epoch 249 train accuracy = 0.95641025641
# Epoch 249 test cost = 8.02169267833
# Epoch 249 test accuracy = 0.927884615385
# Epoch 250 train cost = 1.74285820127
# Epoch 250 train accuracy = 0.965384615385
# Epoch 250 test cost = 7.33335985243
# Epoch 250 test accuracy = 0.947115384615
# Epoch 251 train cost = 1.40486503858
# Epoch 251 train accuracy = 0.960256410256
# Epoch 251 test cost = 7.72508637607
# Epoch 251 test accuracy = 0.924679487179
# Epoch 252 train cost = 1.63810009137
# Epoch 252 train accuracy = 0.958974358974
# Epoch 252 test cost = 7.4501388967
# Epoch 252 test accuracy = 0.939102564103
# Epoch 253 train cost = 1.7126252302
# Epoch 253 train accuracy = 0.969230769231
# Epoch 253 test cost = 7.14280077815
# Epoch 253 test accuracy = 0.93108974359
# Epoch 254 train cost = 1.17955633579
# Epoch 254 train accuracy = 0.974358974359
# Epoch 254 test cost = 8.17612636089
# Epoch 254 test accuracy = 0.919871794872
# Epoch 255 train cost = 1.1938950764
# Epoch 255 train accuracy = 0.976923076923
# Epoch 255 test cost = 8.90363436937
# Epoch 255 test accuracy = 0.93108974359
# Epoch 256 train cost = 1.29519593576
# Epoch 256 train accuracy = 0.966666666667
# Epoch 256 test cost = 8.74232979119
# Epoch 256 test accuracy = 0.935897435897
# Epoch 257 train cost = 1.06109224539
# Epoch 257 train accuracy = 0.966666666667
# Epoch 257 test cost = 6.73879775405
# Epoch 257 test accuracy = 0.9375
# Epoch 258 train cost = 1.18232899439
# Epoch 258 train accuracy = 0.969230769231
# Epoch 258 test cost = 6.77401864529
# Epoch 258 test accuracy = 0.934294871795
# Epoch 259 train cost = 1.41878324188
# Epoch 259 train accuracy = 0.971794871795
# Epoch 259 test cost = 8.66712343693
# Epoch 259 test accuracy = 0.932692307692
# Epoch 260 train cost = 1.39441969479
# Epoch 260 train accuracy = 0.967948717949
# Epoch 260 test cost = 9.28770464659
# Epoch 260 test accuracy = 0.934294871795
# Epoch 261 train cost = 1.06161754671
# Epoch 261 train accuracy = 0.967948717949
# Epoch 261 test cost = 5.59137549996
# Epoch 261 test accuracy = 0.945512820513
# Epoch 262 train cost = 1.07363862544
# Epoch 262 train accuracy = 0.978205128205
# Epoch 262 test cost = 6.99682363868
# Epoch 262 test accuracy = 0.916666666667
# Epoch 263 train cost = 0.997056236491
# Epoch 263 train accuracy = 0.976923076923
# Epoch 263 test cost = 8.74502664804
# Epoch 263 test accuracy = 0.913461538462
# Epoch 264 train cost = 1.95919343084
# Epoch 264 train accuracy = 0.973076923077
# Epoch 264 test cost = 6.72691607475
# Epoch 264 test accuracy = 0.940705128205
# Epoch 265 train cost = 1.37041532248
# Epoch 265 train accuracy = 0.965384615385
# Epoch 265 test cost = 6.75831799209
# Epoch 265 test accuracy = 0.94391025641
# Epoch 266 train cost = 1.47332866164
# Epoch 266 train accuracy = 0.974358974359
# Epoch 266 test cost = 9.18832807243
# Epoch 266 test accuracy = 0.942307692308
# Epoch 267 train cost = 1.28212655615
# Epoch 267 train accuracy = 0.962820512821
# Epoch 267 test cost = 8.48250734806
# Epoch 267 test accuracy = 0.932692307692
# Epoch 268 train cost = 1.27353989333
# Epoch 268 train accuracy = 0.970512820513
# Epoch 268 test cost = 7.02729985118
# Epoch 268 test accuracy = 0.951923076923
# Epoch 269 train cost = 1.27903108578
# Epoch 269 train accuracy = 0.975641025641
# Epoch 269 test cost = 7.51125776768
# Epoch 269 test accuracy = 0.934294871795
# Epoch 270 train cost = 1.58997399174
# Epoch 270 train accuracy = 0.980769230769
# Epoch 270 test cost = 8.69863423705
# Epoch 270 test accuracy = 0.929487179487
# Epoch 271 train cost = 1.41579211131
# Epoch 271 train accuracy = 0.969230769231
# Epoch 271 test cost = 8.52063654363
# Epoch 271 test accuracy = 0.93108974359
# Epoch 272 train cost = 1.38905815501
# Epoch 272 train accuracy = 0.965384615385
# Epoch 272 test cost = 7.51889699697
# Epoch 272 test accuracy = 0.942307692308
# Epoch 273 train cost = 1.33449503127
# Epoch 273 train accuracy = 0.970512820513
# Epoch 273 test cost = 7.80753651261
# Epoch 273 test accuracy = 0.939102564103
# Epoch 274 train cost = 1.22947524115
# Epoch 274 train accuracy = 0.965384615385
# Epoch 274 test cost = 7.47269277275
# Epoch 274 test accuracy = 0.948717948718
# Epoch 275 train cost = 1.20896977093
# Epoch 275 train accuracy = 0.966666666667
# Epoch 275 test cost = 8.47109109163
# Epoch 275 test accuracy = 0.929487179487
# Epoch 276 train cost = 1.25837026164
# Epoch 276 train accuracy = 0.964102564103
# Epoch 276 test cost = 8.44093459845
# Epoch 276 test accuracy = 0.940705128205
# Epoch 277 train cost = 1.57816480845
# Epoch 277 train accuracy = 0.967948717949
# Epoch 277 test cost = 8.56137385964
# Epoch 277 test accuracy = 0.918269230769
# Epoch 278 train cost = 1.00659259502
# Epoch 278 train accuracy = 0.967948717949
# Epoch 278 test cost = 7.78599861264
# Epoch 278 test accuracy = 0.924679487179
# Epoch 279 train cost = 1.82077042386
# Epoch 279 train accuracy = 0.95641025641
# Epoch 279 test cost = 8.25989946723
# Epoch 279 test accuracy = 0.924679487179
# Epoch 280 train cost = 1.38695384935
# Epoch 280 train accuracy = 0.971794871795
# Epoch 280 test cost = 8.22764861584
# Epoch 280 test accuracy = 0.934294871795
# Epoch 281 train cost = 1.31023014802
# Epoch 281 train accuracy = 0.971794871795
# Epoch 281 test cost = 7.64772993326
# Epoch 281 test accuracy = 0.932692307692
# Epoch 282 train cost = 1.06721751392
# Epoch 282 train accuracy = 0.980769230769
# Epoch 282 test cost = 5.79567348957
# Epoch 282 test accuracy = 0.935897435897
# Epoch 283 train cost = 1.55004054308
# Epoch 283 train accuracy = 0.970512820513
# Epoch 283 test cost = 7.67350241542
# Epoch 283 test accuracy = 0.916666666667
# Epoch 284 train cost = 1.28752923105
# Epoch 284 train accuracy = 0.978205128205
# Epoch 284 test cost = 9.10599529743
# Epoch 284 test accuracy = 0.924679487179
# Epoch 285 train cost = 0.980817899108
# Epoch 285 train accuracy = 0.976923076923
# Epoch 285 test cost = 9.09537750483
# Epoch 285 test accuracy = 0.939102564103
# Epoch 286 train cost = 0.951543176081
# Epoch 286 train accuracy = 0.974358974359
# Epoch 286 test cost = 7.70788326859
# Epoch 286 test accuracy = 0.93108974359
# Epoch 287 train cost = 1.01245005429
# Epoch 287 train accuracy = 0.969230769231
# Epoch 287 test cost = 6.9780472666
# Epoch 287 test accuracy = 0.935897435897
# Epoch 288 train cost = 1.2537457305
# Epoch 288 train accuracy = 0.984615384615
# Epoch 288 test cost = 7.96803626418
# Epoch 288 test accuracy = 0.948717948718
# Epoch 289 train cost = 0.899534397759
# Epoch 289 train accuracy = 0.973076923077
# Epoch 289 test cost = 8.15373918414
# Epoch 289 test accuracy = 0.939102564103
# Epoch 290 train cost = 1.38045062963
# Epoch 290 train accuracy = 0.974358974359
# Epoch 290 test cost = 8.12947922945
# Epoch 290 test accuracy = 0.940705128205
# Epoch 291 train cost = 0.714085589163
# Epoch 291 train accuracy = 0.967948717949
# Epoch 291 test cost = 7.47803011537
# Epoch 291 test accuracy = 0.934294871795
# Epoch 292 train cost = 1.6802200973
# Epoch 292 train accuracy = 0.974358974359
# Epoch 292 test cost = 7.92307350039
# Epoch 292 test accuracy = 0.927884615385
# Epoch 293 train cost = 1.46937731095
# Epoch 293 train accuracy = 0.973076923077
# Epoch 293 test cost = 6.45238867402
# Epoch 293 test accuracy = 0.947115384615
# Epoch 294 train cost = 1.18387418427
# Epoch 294 train accuracy = 0.970512820513
# Epoch 294 test cost = 7.57458630204
# Epoch 294 test accuracy = 0.94391025641
# Epoch 295 train cost = 1.41018996201
# Epoch 295 train accuracy = 0.964102564103
# Epoch 295 test cost = 7.4883095026
# Epoch 295 test accuracy = 0.935897435897
# Epoch 296 train cost = 1.11145994253
# Epoch 296 train accuracy = 0.967948717949
# Epoch 296 test cost = 7.95469538867
# Epoch 296 test accuracy = 0.939102564103
# Epoch 297 train cost = 1.42437791172
# Epoch 297 train accuracy = 0.974358974359
# Epoch 297 test cost = 7.35688786209
# Epoch 297 test accuracy = 0.94391025641
# Epoch 298 train cost = 1.12155739963
# Epoch 298 train accuracy = 0.971794871795
# Epoch 298 test cost = 7.30830001086
# Epoch 298 test accuracy = 0.934294871795
# Epoch 299 train cost = 1.96312476322
# Epoch 299 train accuracy = 0.970512820513
# Epoch 299 test cost = 6.50983162224
# Epoch 299 test accuracy = 0.947115384615

# %%
# %matplotlib inline
plt.figure(1)
plt.plot(cost_train, 'c', cost_test, 'r', linewidth=2.0)
plt.legend(("cost_train", "cost_test"),'upper left')

plt.figure(2)
plt.plot(accuracy_train, 'y', accuracy_test, 'b', linewidth=2.0)
plt.legend(("accuracy_train", "accuracy_test"),'lower left')

print "train max", np.max(accuracy_train), " is at", np.argmax(accuracy_train), "epoch \n"  
print "test max", np.max(accuracy_test), " is at", np.argmax(accuracy_test), "epoch \n"  
#plt.show()
# Out:
# train max 0.984615384615  is at 288 epoch
#
# test max 0.951923076923  is at 242 epoch
# /home/zli/anaconda/lib/python2.7/site-packages/matplotlib/cbook.py:137: MatplotlibDeprecationWarning: The "loc" positional argument to legend is deprecated. Please use the "loc" keyword instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
