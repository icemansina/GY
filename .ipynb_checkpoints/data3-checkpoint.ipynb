# %%
import numpy as np
import scipy.io 
import theano.tensor as T
import lasagne
import string
import theano
import BatchNormLayer
import matplotlib.pylab as plt
batch_norm = BatchNormLayer.batch_norm
# Out:
# Using gpu device 2: GeForce GTX TITAN Black (CNMeM is disabled, CuDNN 3007)
# /home/zli/2016/ntm-lasagne/src/theano/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
############# TrainData and TestData Preparation #############

# trainx: 780*50*6 
# trainy: 780*52 or 780
# mask_train: 780*50
loaddata = scipy.io.loadmat('../dataset/Data2.mat')
traindata = loaddata['TrainData']
testdata = loaddata['TestData']

trainx = []
trainy = []

for i in xrange(traindata.shape[0]):
	for j in xrange(traindata.shape[1]):
		trainx.append(traindata[i][j])
		trainy.append(i)

trainx = np.asarray(trainx)
trainy = np.asarray(trainy)
mask_train = np.ones([trainx.shape[0], trainx.shape[1]])
#print trainy.shape
#print trainy

# testx: 624*20*6
# testy: 624*52 or 624
# mask_test: 624*20
testx = []
testy = []

for i in xrange(testdata.shape[0]):
	for j in xrange(testdata.shape[1]):
		testx.append(testdata[i][j])
		testy.append(i)

testx = np.asarray(testx)
testy = np.asarray(testy)
mask_test = np.ones([testx.shape[0], testx.shape[1]])
#print testy.shape
#print testy

# %%
##########  Initialize Parameters ########
N_BATCH = 52
MAX_LENGTH = 50
features_num = 6
GRAD_CLIP = 100
TOL = 1e-5
LEARNING_RATE = 1e-2
N_HIDDEN = 120
num_epochs = 300

##########  Build Model for Prediction #######################
mask = np.ones([N_BATCH, MAX_LENGTH])
target_values = T.ivector('target_output')
sym_mask = T.matrix('mask')

print("Building network ...")

l_in = lasagne.layers.InputLayer(shape=(N_BATCH, MAX_LENGTH, features_num))
#l_mask = lasagne.layers.InputLayer(shape=(N_BATCH, MAX_LENGTH))
#### Bidirectional RNN layers ###
l_forward = lasagne.layers.GRULayer(
        l_in, N_HIDDEN, grad_clipping=GRAD_CLIP, only_return_final=True)
        #W_in_to_hid=lasagne.init.HeUniform(),
        #W_hid_to_hid=lasagne.init.HeUniform(),
        #nonlinearity=lasagne.nonlinearities.tanh, only_return_final=True)

l_backward = lasagne.layers.GRULayer(
        l_in, N_HIDDEN, grad_clipping=GRAD_CLIP, only_return_final=True, backwards=True)
        #W_in_to_hid=lasagne.init.HeUniform(),
        #W_hid_to_hid=lasagne.init.HeUniform(),
        #nonlinearity=lasagne.nonlinearities.tanh,
        #only_return_final=True, backwards=True)


l_concat = lasagne.layers.ConcatLayer([l_forward, l_backward])
l_concat = batch_norm(l_concat)

###  Softmax for prediction output ######
l_fc1 = lasagne.layers.DenseLayer(
	    lasagne.layers.dropout(l_concat, p=.5),
        num_units=100, nonlinearity=lasagne.nonlinearities.rectify)
l_fc1 = batch_norm(l_fc1)

l_out = lasagne.layers.DenseLayer(
	    lasagne.layers.dropout(l_fc1, p=.5),
        num_units=52, nonlinearity=lasagne.nonlinearities.softmax)
# Out:
# Building network ...

# %%
########### Debug ###########
all_layers = lasagne.layers.get_all_layers(l_out)
num_params = lasagne.layers.count_params(l_out)
print("  number of parameters: %d" % num_params)
print("  layer output shapes:")
for layer in all_layers:
	name = string.ljust(layer.__class__.__name__, 32)
	print("    %s %s" % (name, lasagne.layers.get_output_shape(layer)))

############## Compile the model, calculate cost, update ######################
#########  #######
network_output = lasagne.layers.get_output(l_out)

out_train = lasagne.layers.get_output(l_out, mask = sym_mask, deterministic=False)

out_test = lasagne.layers.get_output(l_out, mask = sym_mask, deterministic=True)

cost = T.nnet.categorical_crossentropy(T.clip(network_output, TOL, 1-TOL), target_values)
cost = cost.mean()
# Retrieve all parameters from the network
all_params = lasagne.layers.get_all_params(l_out, trainable=True)

all_grads = T.grad(cost, all_params)

updates, norm_calc = lasagne.updates.total_norm_constraint(all_grads, max_norm= 20, return_norm=True)

# Compute SGD updates for training
print("Computing updates ...")
#updates = lasagne.updates.adagrad(cost, all_params, LEARNING_RATE)
updates = lasagne.updates.adam(cost, all_params, LEARNING_RATE)

print("Compiling functions ...")
train = theano.function([l_in.input_var, target_values, sym_mask], \
	                    [cost, out_train], updates=updates, \
	                    on_unused_input='ignore', allow_input_downcast=True)
#compute_cost = theano.function([l_in.input_var, target_values, l_mask.input_var], cost)
test = theano.function([l_in.input_var, target_values, sym_mask], \
                        [cost, out_test], on_unused_input='ignore', allow_input_downcast=True)
# Out:
#   number of parameters: 122292
#   layer output shapes:
#     InputLayer                       (52, 50, 6)
#     GRULayer                         (52, 120)
#     GRULayer                         (52, 120)
#     ConcatLayer                      (52, 240)
#     BatchNormLayer                   (52, 240)
#     DropoutLayer                     (52, 240)
#     DenseLayer                       (52, 100)
#     BatchNormLayer                   (52, 100)
#     NonlinearityLayer                (52, 100)
#     DropoutLayer                     (52, 100)
#     DenseLayer                       (52, 52)
# Computing updates ...
# Compiling functions ...

# %%
print("Training ...")
seq_names = np.arange(0, trainx.shape[0])
np.random.shuffle(seq_names)
trainx = trainx[seq_names]
trainy = trainy[seq_names]  
mask_train = mask_train[seq_names]
cost_train = []
out_train = []
EPOCH_SIZE_TRAIN = trainx.shape[0]// N_BATCH
accuracy_train = []

seq_names_test = np.arange(0, testx.shape[0])
np.random.shuffle(seq_names_test)
testx = testx[seq_names_test]
testy = testy[seq_names_test]  
mask_test = mask_test[seq_names_test]
cost_test = []
out_test = []
EPOCH_SIZE_TEST = testx.shape[0]// N_BATCH
accuracy_test = []

for epoch in range(num_epochs):
	### Train part ###
    out_train_epoch = []
    cost_train_epoch = 0
    for i in xrange(EPOCH_SIZE_TRAIN):
    	idx = xrange(i*N_BATCH, (i+1)*N_BATCH)
    	x_batch = trainx[idx]
    	y_batch = trainy[idx]
    	mask_batch = mask_train[idx]

    	cost_train_batch, out_train_batch = train(x_batch, y_batch, mask_batch)
    	out_train_epoch.append(out_train_batch)
    	cost_train_epoch += cost_train_batch

    out_train_epoch = np.asarray(out_train_epoch)
    out_train_epoch = out_train_epoch.reshape(-1, 52)    
    out_train.append(out_train_epoch)
    cost_train.append(cost_train_epoch)
    ### Accuracy calculation ####
    sum = 0
    for i in xrange(out_train_epoch.shape[0]):
    	predict_label = np.argmax(out_train_epoch[i,:])
    	if predict_label == trainy[i]:
    		sum += 1
    accuracytrain = float(sum)/float(out_train_epoch.shape[0])
    accuracy_train.append(accuracytrain)
    print("Epoch {} train cost = {}".format(epoch, cost_train_epoch))
    print("Epoch {} train accuracy = {}".format(epoch, accuracytrain))

    ### Inference Part ###
    out_test_epoch = []
    cost_test_epoch = 0
    for i in range(EPOCH_SIZE_TEST):
		idx = range(i*N_BATCH, (i+1)*N_BATCH)
		x_batch = testx[idx]
		y_batch = testy[idx]
		mask_batch = mask_test[idx]

		cost_test_batch, out_test_batch = test(x_batch, y_batch, mask_batch)
		out_test_epoch.append(out_test_batch)
		cost_test_epoch += cost_test_batch

    out_test_epoch = np.asarray(out_test_epoch)
    out_test_epoch = out_test_epoch.reshape(-1, 52)
    out_test.append(out_test_epoch)
    cost_test.append(cost_test_epoch)
    #print out_test_epoch.shape
    #print out_test_epoch
    ### Accuracy calculation ####
    sum = 0
    for i in xrange(out_test_epoch.shape[0]):
    	predict_label = np.argmax(out_test_epoch[i,:])
    	if predict_label == testy[i]:
    		sum += 1
    accuracytest = float(sum)/float(out_test_epoch.shape[0])
    accuracy_test.append(accuracytest)
    print("Epoch {} test cost = {}".format(epoch, cost_test_epoch))
    print("Epoch {} test accuracy = {}".format(epoch, accuracytest))
# Out:
# Training ...
# Epoch 0 train cost = 57.1767983437
# Epoch 0 train accuracy = 0.101282051282
# Epoch 0 test cost = 36.7419083118
# Epoch 0 test accuracy = 0.0673076923077
# Epoch 1 train cost = 40.4966013432
# Epoch 1 train accuracy = 0.241025641026
# Epoch 1 test cost = 28.2121329308
# Epoch 1 test accuracy = 0.262820512821
# Epoch 2 train cost = 31.2179211378
# Epoch 2 train accuracy = 0.403846153846
# Epoch 2 test cost = 22.6622731686
# Epoch 2 test accuracy = 0.258012820513
# Epoch 3 train cost = 24.4606329203
# Epoch 3 train accuracy = 0.480769230769
# Epoch 3 test cost = 20.0465587378
# Epoch 3 test accuracy = 0.660256410256
# Epoch 4 train cost = 21.250156045
# Epoch 4 train accuracy = 0.570512820513
# Epoch 4 test cost = 18.135778904
# Epoch 4 test accuracy = 0.5625
# Epoch 5 train cost = 19.013006568
# Epoch 5 train accuracy = 0.567948717949
# Epoch 5 test cost = 16.2134410739
# Epoch 5 test accuracy = 0.543269230769
# Epoch 6 train cost = 17.8517455459
# Epoch 6 train accuracy = 0.626923076923
# Epoch 6 test cost = 16.2665086985
# Epoch 6 test accuracy = 0.471153846154
# Epoch 7 train cost = 16.6363801956
# Epoch 7 train accuracy = 0.65641025641
# Epoch 7 test cost = 14.8121052384
# Epoch 7 test accuracy = 0.605769230769
# Epoch 8 train cost = 14.6428638697
# Epoch 8 train accuracy = 0.682051282051
# Epoch 8 test cost = 14.5767730474
# Epoch 8 test accuracy = 0.634615384615
# Epoch 9 train cost = 14.1947689056
# Epoch 9 train accuracy = 0.698717948718
# Epoch 9 test cost = 14.3477371931
# Epoch 9 test accuracy = 0.487179487179
# Epoch 10 train cost = 13.184800446
# Epoch 10 train accuracy = 0.701282051282
# Epoch 10 test cost = 13.7282504439
# Epoch 10 test accuracy = 0.663461538462
# Epoch 11 train cost = 12.2061899304
# Epoch 11 train accuracy = 0.711538461538
# Epoch 11 test cost = 12.3239827156
# Epoch 11 test accuracy = 0.671474358974
# Epoch 12 train cost = 11.7423196733
# Epoch 12 train accuracy = 0.724358974359
# Epoch 12 test cost = 13.4082801938
# Epoch 12 test accuracy = 0.671474358974
# Epoch 13 train cost = 11.5257733464
# Epoch 13 train accuracy = 0.75641025641
# Epoch 13 test cost = 12.3592084646
# Epoch 13 test accuracy = 0.769230769231
# Epoch 14 train cost = 11.3202967346
# Epoch 14 train accuracy = 0.760256410256
# Epoch 14 test cost = 11.3702902794
# Epoch 14 test accuracy = 0.774038461538
# Epoch 15 train cost = 9.68186745048
# Epoch 15 train accuracy = 0.785897435897
# Epoch 15 test cost = 11.3489059806
# Epoch 15 test accuracy = 0.807692307692
# Epoch 16 train cost = 9.21543732285
# Epoch 16 train accuracy = 0.802564102564
# Epoch 16 test cost = 10.4670817256
# Epoch 16 test accuracy = 0.820512820513
# Epoch 17 train cost = 8.24118626118
# Epoch 17 train accuracy = 0.798717948718
# Epoch 17 test cost = 11.3037696183
# Epoch 17 test accuracy = 0.796474358974
# Epoch 18 train cost = 8.89538145065
# Epoch 18 train accuracy = 0.798717948718
# Epoch 18 test cost = 10.134762466
# Epoch 18 test accuracy = 0.774038461538
# Epoch 19 train cost = 7.76603680849
# Epoch 19 train accuracy = 0.814102564103
# Epoch 19 test cost = 10.4192098975
# Epoch 19 test accuracy = 0.830128205128
# Epoch 20 train cost = 7.66920784116
# Epoch 20 train accuracy = 0.821794871795
# Epoch 20 test cost = 10.1133529544
# Epoch 20 test accuracy = 0.823717948718
# Epoch 21 train cost = 8.0279738903
# Epoch 21 train accuracy = 0.814102564103
# Epoch 21 test cost = 9.28021609783
# Epoch 21 test accuracy = 0.823717948718
# Epoch 22 train cost = 6.70297062397
# Epoch 22 train accuracy = 0.824358974359
# Epoch 22 test cost = 9.54701775312
# Epoch 22 test accuracy = 0.847756410256
# Epoch 23 train cost = 7.17024931312
# Epoch 23 train accuracy = 0.817948717949
# Epoch 23 test cost = 11.597630322
# Epoch 23 test accuracy = 0.865384615385
# Epoch 24 train cost = 7.43913342059
# Epoch 24 train accuracy = 0.812820512821
# Epoch 24 test cost = 10.5002387166
# Epoch 24 test accuracy = 0.836538461538
# Epoch 25 train cost = 7.64443910122
# Epoch 25 train accuracy = 0.815384615385
# Epoch 25 test cost = 10.2402690649
# Epoch 25 test accuracy = 0.855769230769
# Epoch 26 train cost = 7.38877007365
# Epoch 26 train accuracy = 0.830769230769
# Epoch 26 test cost = 10.0010118186
# Epoch 26 test accuracy = 0.786858974359
# Epoch 27 train cost = 7.37889012694
# Epoch 27 train accuracy = 0.84358974359
# Epoch 27 test cost = 9.48402899504
# Epoch 27 test accuracy = 0.860576923077
# Epoch 28 train cost = 7.03713288903
# Epoch 28 train accuracy = 0.853846153846
# Epoch 28 test cost = 9.86170786619
# Epoch 28 test accuracy = 0.883012820513
# Epoch 29 train cost = 6.03268018365
# Epoch 29 train accuracy = 0.869230769231
# Epoch 29 test cost = 8.91171431541
# Epoch 29 test accuracy = 0.884615384615
# Epoch 30 train cost = 5.48370748758
# Epoch 30 train accuracy = 0.864102564103
# Epoch 30 test cost = 9.11387935281
# Epoch 30 test accuracy = 0.883012820513
# Epoch 31 train cost = 6.04726159573
# Epoch 31 train accuracy = 0.866666666667
# Epoch 31 test cost = 9.59926456213
# Epoch 31 test accuracy = 0.870192307692
# Epoch 32 train cost = 5.68794238567
# Epoch 32 train accuracy = 0.869230769231
# Epoch 32 test cost = 8.75788533688
# Epoch 32 test accuracy = 0.889423076923
# Epoch 33 train cost = 4.47349701822
# Epoch 33 train accuracy = 0.885897435897
# Epoch 33 test cost = 7.71669071913
# Epoch 33 test accuracy = 0.88141025641
# Epoch 34 train cost = 5.3773214221
# Epoch 34 train accuracy = 0.882051282051
# Epoch 34 test cost = 10.0805745125
# Epoch 34 test accuracy = 0.873397435897
# Epoch 35 train cost = 4.88186272979
# Epoch 35 train accuracy = 0.867948717949
# Epoch 35 test cost = 8.92204129696
# Epoch 35 test accuracy = 0.879807692308
# Epoch 36 train cost = 4.76022480428
# Epoch 36 train accuracy = 0.880769230769
# Epoch 36 test cost = 8.9533688724
# Epoch 36 test accuracy = 0.886217948718
# Epoch 37 train cost = 5.6850746572
# Epoch 37 train accuracy = 0.860256410256
# Epoch 37 test cost = 8.36702784896
# Epoch 37 test accuracy = 0.887820512821
# Epoch 38 train cost = 6.02489686012
# Epoch 38 train accuracy = 0.865384615385
# Epoch 38 test cost = 9.32181537151
# Epoch 38 test accuracy = 0.863782051282
# Epoch 39 train cost = 5.16306716204
# Epoch 39 train accuracy = 0.889743589744
# Epoch 39 test cost = 9.30621370673
# Epoch 39 test accuracy = 0.889423076923
# Epoch 40 train cost = 5.23267251253
# Epoch 40 train accuracy = 0.883333333333
# Epoch 40 test cost = 9.8654049933
# Epoch 40 test accuracy = 0.889423076923
# Epoch 41 train cost = 4.06607337296
# Epoch 41 train accuracy = 0.90641025641
# Epoch 41 test cost = 9.29483872652
# Epoch 41 test accuracy = 0.891025641026
# Epoch 42 train cost = 4.70864644647
# Epoch 42 train accuracy = 0.90641025641
# Epoch 42 test cost = 8.95809668303
# Epoch 42 test accuracy = 0.903846153846
# Epoch 43 train cost = 5.06487601995
# Epoch 43 train accuracy = 0.89358974359
# Epoch 43 test cost = 9.50627934933
# Epoch 43 test accuracy = 0.857371794872
# Epoch 44 train cost = 4.23257872462
# Epoch 44 train accuracy = 0.880769230769
# Epoch 44 test cost = 9.59163755178
# Epoch 44 test accuracy = 0.862179487179
# Epoch 45 train cost = 4.6917014122
# Epoch 45 train accuracy = 0.898717948718
# Epoch 45 test cost = 8.35348841548
# Epoch 45 test accuracy = 0.891025641026
# Epoch 46 train cost = 3.82051570714
# Epoch 46 train accuracy = 0.902564102564
# Epoch 46 test cost = 9.1732596755
# Epoch 46 test accuracy = 0.894230769231
# Epoch 47 train cost = 4.03352960944
# Epoch 47 train accuracy = 0.898717948718
# Epoch 47 test cost = 9.40124887228
# Epoch 47 test accuracy = 0.903846153846
# Epoch 48 train cost = 3.46824008226
# Epoch 48 train accuracy = 0.898717948718
# Epoch 48 test cost = 9.20755821466
# Epoch 48 test accuracy = 0.900641025641
# Epoch 49 train cost = 4.07350658625
# Epoch 49 train accuracy = 0.905128205128
# Epoch 49 test cost = 8.62810328603
# Epoch 49 test accuracy = 0.891025641026
# Epoch 50 train cost = 4.27147849649
# Epoch 50 train accuracy = 0.9
# Epoch 50 test cost = 9.88927164674
# Epoch 50 test accuracy = 0.88141025641
# Epoch 51 train cost = 4.06543380022
# Epoch 51 train accuracy = 0.894871794872
# Epoch 51 test cost = 7.83958801627
# Epoch 51 test accuracy = 0.894230769231
# Epoch 52 train cost = 4.55425198376
# Epoch 52 train accuracy = 0.9
# Epoch 52 test cost = 9.52282267809
# Epoch 52 test accuracy = 0.887820512821
# Epoch 53 train cost = 4.27336595207
# Epoch 53 train accuracy = 0.921794871795
# Epoch 53 test cost = 9.63558351994
# Epoch 53 test accuracy = 0.878205128205
# Epoch 54 train cost = 4.10536389053
# Epoch 54 train accuracy = 0.907692307692
# Epoch 54 test cost = 8.47332960367
# Epoch 54 test accuracy = 0.908653846154
# Epoch 55 train cost = 4.14170533419
# Epoch 55 train accuracy = 0.908974358974
# Epoch 55 test cost = 8.29406452179
# Epoch 55 test accuracy = 0.897435897436
# Epoch 56 train cost = 4.27250662446
# Epoch 56 train accuracy = 0.90641025641
# Epoch 56 test cost = 8.81647360325
# Epoch 56 test accuracy = 0.913461538462
# Epoch 57 train cost = 3.42897013575
# Epoch 57 train accuracy = 0.921794871795
# Epoch 57 test cost = 8.05160617828
# Epoch 57 test accuracy = 0.908653846154
# Epoch 58 train cost = 3.33870971203
# Epoch 58 train accuracy = 0.908974358974
# Epoch 58 test cost = 7.47405323386
# Epoch 58 test accuracy = 0.916666666667
# Epoch 59 train cost = 3.04788596183
# Epoch 59 train accuracy = 0.928205128205
# Epoch 59 test cost = 9.25924044847
# Epoch 59 test accuracy = 0.884615384615
# Epoch 60 train cost = 3.3100348562
# Epoch 60 train accuracy = 0.903846153846
# Epoch 60 test cost = 9.07352429628
# Epoch 60 test accuracy = 0.921474358974
# Epoch 61 train cost = 3.7892799601
# Epoch 61 train accuracy = 0.915384615385
# Epoch 61 test cost = 7.98706015944
# Epoch 61 test accuracy = 0.910256410256
# Epoch 62 train cost = 3.03801875561
# Epoch 62 train accuracy = 0.912820512821
# Epoch 62 test cost = 8.31938973069
# Epoch 62 test accuracy = 0.929487179487
# Epoch 63 train cost = 3.14035314322
# Epoch 63 train accuracy = 0.919230769231
# Epoch 63 test cost = 7.68414151669
# Epoch 63 test accuracy = 0.902243589744
# Epoch 64 train cost = 2.84908547997
# Epoch 64 train accuracy = 0.937179487179
# Epoch 64 test cost = 7.56024633348
# Epoch 64 test accuracy = 0.911858974359
# Epoch 65 train cost = 3.0555601269
# Epoch 65 train accuracy = 0.916666666667
# Epoch 65 test cost = 6.46461141109
# Epoch 65 test accuracy = 0.927884615385
# Epoch 66 train cost = 3.23877039552
# Epoch 66 train accuracy = 0.941025641026
# Epoch 66 test cost = 8.15791529417
# Epoch 66 test accuracy = 0.919871794872
# Epoch 67 train cost = 3.58433583379
# Epoch 67 train accuracy = 0.923076923077
# Epoch 67 test cost = 8.90157994628
# Epoch 67 test accuracy = 0.900641025641
# Epoch 68 train cost = 2.92449268699
# Epoch 68 train accuracy = 0.920512820513
# Epoch 68 test cost = 8.29751557112
# Epoch 68 test accuracy = 0.894230769231
# Epoch 69 train cost = 3.00186934322
# Epoch 69 train accuracy = 0.910256410256
# Epoch 69 test cost = 8.65809005499
# Epoch 69 test accuracy = 0.919871794872
# Epoch 70 train cost = 3.44944944233
# Epoch 70 train accuracy = 0.914102564103
# Epoch 70 test cost = 7.7987600565
# Epoch 70 test accuracy = 0.923076923077
# Epoch 71 train cost = 3.6264917776
# Epoch 71 train accuracy = 0.926923076923
# Epoch 71 test cost = 7.75282159448
# Epoch 71 test accuracy = 0.900641025641
# Epoch 72 train cost = 4.35392777249
# Epoch 72 train accuracy = 0.912820512821
# Epoch 72 test cost = 9.40902608633
# Epoch 72 test accuracy = 0.892628205128
# Epoch 73 train cost = 2.78539134562
# Epoch 73 train accuracy = 0.911538461538
# Epoch 73 test cost = 8.39619085193
# Epoch 73 test accuracy = 0.916666666667
# Epoch 74 train cost = 2.95781122148
# Epoch 74 train accuracy = 0.932051282051
# Epoch 74 test cost = 7.76678627729
# Epoch 74 test accuracy = 0.918269230769
# Epoch 75 train cost = 2.85060592741
# Epoch 75 train accuracy = 0.932051282051
# Epoch 75 test cost = 8.87843951583
# Epoch 75 test accuracy = 0.911858974359
# Epoch 76 train cost = 3.17097455263
# Epoch 76 train accuracy = 0.94358974359
# Epoch 76 test cost = 9.63731756806
# Epoch 76 test accuracy = 0.902243589744
# Epoch 77 train cost = 3.00793679804
# Epoch 77 train accuracy = 0.933333333333
# Epoch 77 test cost = 7.91676211357
# Epoch 77 test accuracy = 0.923076923077
# Epoch 78 train cost = 3.11416401714
# Epoch 78 train accuracy = 0.925641025641
# Epoch 78 test cost = 7.86768868566
# Epoch 78 test accuracy = 0.911858974359
# Epoch 79 train cost = 2.80441539735
# Epoch 79 train accuracy = 0.928205128205
# Epoch 79 test cost = 8.65749156475
# Epoch 79 test accuracy = 0.923076923077
# Epoch 80 train cost = 2.82117880881
# Epoch 80 train accuracy = 0.935897435897
# Epoch 80 test cost = 7.42340418696
# Epoch 80 test accuracy = 0.918269230769
# Epoch 81 train cost = 2.56075961143
# Epoch 81 train accuracy = 0.941025641026
# Epoch 81 test cost = 7.68007710576
# Epoch 81 test accuracy = 0.918269230769
# Epoch 82 train cost = 2.26318791509
# Epoch 82 train accuracy = 0.946153846154
# Epoch 82 test cost = 7.84606808424
# Epoch 82 test accuracy = 0.929487179487
# Epoch 83 train cost = 2.51132677495
# Epoch 83 train accuracy = 0.937179487179
# Epoch 83 test cost = 8.04288434982
# Epoch 83 test accuracy = 0.918269230769
# Epoch 84 train cost = 2.36402790993
# Epoch 84 train accuracy = 0.947435897436
# Epoch 84 test cost = 7.58269423246
# Epoch 84 test accuracy = 0.918269230769
# Epoch 85 train cost = 2.00594446063
# Epoch 85 train accuracy = 0.941025641026
# Epoch 85 test cost = 7.96641886234
# Epoch 85 test accuracy = 0.926282051282
# Epoch 86 train cost = 2.85978307948
# Epoch 86 train accuracy = 0.947435897436
# Epoch 86 test cost = 7.41544231772
# Epoch 86 test accuracy = 0.927884615385
# Epoch 87 train cost = 2.4376357682
# Epoch 87 train accuracy = 0.952564102564
# Epoch 87 test cost = 8.33780729771
# Epoch 87 test accuracy = 0.919871794872
# Epoch 88 train cost = 2.58796391636
# Epoch 88 train accuracy = 0.938461538462
# Epoch 88 test cost = 9.30375415087
# Epoch 88 test accuracy = 0.905448717949
# Epoch 89 train cost = 2.77593991905
# Epoch 89 train accuracy = 0.941025641026
# Epoch 89 test cost = 8.94570574164
# Epoch 89 test accuracy = 0.913461538462
# Epoch 90 train cost = 3.04075036943
# Epoch 90 train accuracy = 0.930769230769
# Epoch 90 test cost = 8.93332520127
# Epoch 90 test accuracy = 0.919871794872
# Epoch 91 train cost = 2.54833787307
# Epoch 91 train accuracy = 0.939743589744
# Epoch 91 test cost = 7.77291613817
# Epoch 91 test accuracy = 0.932692307692
# Epoch 92 train cost = 2.40257496759
# Epoch 92 train accuracy = 0.947435897436
# Epoch 92 test cost = 7.35982954502
# Epoch 92 test accuracy = 0.942307692308
# Epoch 93 train cost = 1.78258676082
# Epoch 93 train accuracy = 0.962820512821
# Epoch 93 test cost = 7.02537378669
# Epoch 93 test accuracy = 0.955128205128
# Epoch 94 train cost = 2.39391536079
# Epoch 94 train accuracy = 0.941025641026
# Epoch 94 test cost = 8.91904395819
# Epoch 94 test accuracy = 0.935897435897
# Epoch 95 train cost = 2.12234694511
# Epoch 95 train accuracy = 0.951282051282
# Epoch 95 test cost = 8.41488739848
# Epoch 95 test accuracy = 0.921474358974
# Epoch 96 train cost = 2.12467386574
# Epoch 96 train accuracy = 0.941025641026
# Epoch 96 test cost = 8.98704171181
# Epoch 96 test accuracy = 0.9375
# Epoch 97 train cost = 2.30847295746
# Epoch 97 train accuracy = 0.938461538462
# Epoch 97 test cost = 7.96345517039
# Epoch 97 test accuracy = 0.910256410256
# Epoch 98 train cost = 2.33256112784
# Epoch 98 train accuracy = 0.952564102564
# Epoch 98 test cost = 8.60424017906
# Epoch 98 test accuracy = 0.919871794872
# Epoch 99 train cost = 1.47838225681
# Epoch 99 train accuracy = 0.948717948718
# Epoch 99 test cost = 8.348513484
# Epoch 99 test accuracy = 0.927884615385
# Epoch 100 train cost = 2.99232976884
# Epoch 100 train accuracy = 0.946153846154
# Epoch 100 test cost = 9.04513457417
# Epoch 100 test accuracy = 0.927884615385
# Epoch 101 train cost = 2.4343801029
# Epoch 101 train accuracy = 0.951282051282
# Epoch 101 test cost = 9.08787983656
# Epoch 101 test accuracy = 0.916666666667
# Epoch 102 train cost = 2.65050441772
# Epoch 102 train accuracy = 0.952564102564
# Epoch 102 test cost = 8.95375010371
# Epoch 102 test accuracy = 0.916666666667
# Epoch 103 train cost = 2.85445208102
# Epoch 103 train accuracy = 0.933333333333
# Epoch 103 test cost = 10.7115035951
# Epoch 103 test accuracy = 0.919871794872
# Epoch 104 train cost = 2.18193863705
# Epoch 104 train accuracy = 0.938461538462
# Epoch 104 test cost = 10.4328203499
# Epoch 104 test accuracy = 0.915064102564
# Epoch 105 train cost = 2.62347801775
# Epoch 105 train accuracy = 0.95641025641
# Epoch 105 test cost = 8.67502701283
# Epoch 105 test accuracy = 0.907051282051
# Epoch 106 train cost = 2.68767993152
# Epoch 106 train accuracy = 0.941025641026
# Epoch 106 test cost = 8.71528032422
# Epoch 106 test accuracy = 0.921474358974
# Epoch 107 train cost = 2.40391456336
# Epoch 107 train accuracy = 0.929487179487
# Epoch 107 test cost = 8.01882238686
# Epoch 107 test accuracy = 0.916666666667
# Epoch 108 train cost = 2.80278123915
# Epoch 108 train accuracy = 0.953846153846
# Epoch 108 test cost = 9.00464504957
# Epoch 108 test accuracy = 0.915064102564
# Epoch 109 train cost = 1.99041981995
# Epoch 109 train accuracy = 0.944871794872
# Epoch 109 test cost = 10.3860204816
# Epoch 109 test accuracy = 0.915064102564
# Epoch 110 train cost = 2.07406533137
# Epoch 110 train accuracy = 0.937179487179
# Epoch 110 test cost = 8.84763258696
# Epoch 110 test accuracy = 0.929487179487
# Epoch 111 train cost = 3.17880978435
# Epoch 111 train accuracy = 0.937179487179
# Epoch 111 test cost = 9.94990676641
# Epoch 111 test accuracy = 0.899038461538
# Epoch 112 train cost = 2.83787758276
# Epoch 112 train accuracy = 0.938461538462
# Epoch 112 test cost = 9.56084272265
# Epoch 112 test accuracy = 0.908653846154
# Epoch 113 train cost = 3.43941700459
# Epoch 113 train accuracy = 0.924358974359
# Epoch 113 test cost = 7.57486374676
# Epoch 113 test accuracy = 0.924679487179
# Epoch 114 train cost = 2.99683105201
# Epoch 114 train accuracy = 0.938461538462
# Epoch 114 test cost = 8.25361895561
# Epoch 114 test accuracy = 0.887820512821
# Epoch 115 train cost = 3.09226437658
# Epoch 115 train accuracy = 0.933333333333
# Epoch 115 test cost = 8.96801513433
# Epoch 115 test accuracy = 0.918269230769
# Epoch 116 train cost = 2.27364611253
# Epoch 116 train accuracy = 0.935897435897
# Epoch 116 test cost = 8.90824899077
# Epoch 116 test accuracy = 0.918269230769
# Epoch 117 train cost = 2.2301446693
# Epoch 117 train accuracy = 0.948717948718
# Epoch 117 test cost = 7.75043287873
# Epoch 117 test accuracy = 0.926282051282
# Epoch 118 train cost = 2.3922990188
# Epoch 118 train accuracy = 0.966666666667
# Epoch 118 test cost = 8.33113211393
# Epoch 118 test accuracy = 0.9375
# Epoch 119 train cost = 1.85106865317
# Epoch 119 train accuracy = 0.95641025641
# Epoch 119 test cost = 6.8362108171
# Epoch 119 test accuracy = 0.934294871795
# Epoch 120 train cost = 1.93482656404
# Epoch 120 train accuracy = 0.952564102564
# Epoch 120 test cost = 8.42656363547
# Epoch 120 test accuracy = 0.93108974359
# Epoch 121 train cost = 1.65182048082
# Epoch 121 train accuracy = 0.948717948718
# Epoch 121 test cost = 7.52744826674
# Epoch 121 test accuracy = 0.927884615385
# Epoch 122 train cost = 1.89618884027
# Epoch 122 train accuracy = 0.964102564103
# Epoch 122 test cost = 7.59498995543
# Epoch 122 test accuracy = 0.905448717949
# Epoch 123 train cost = 1.95758781582
# Epoch 123 train accuracy = 0.964102564103
# Epoch 123 test cost = 8.06346845627
# Epoch 123 test accuracy = 0.921474358974
# Epoch 124 train cost = 2.31064046547
# Epoch 124 train accuracy = 0.969230769231
# Epoch 124 test cost = 6.27085854113
# Epoch 124 test accuracy = 0.940705128205
# Epoch 125 train cost = 1.46340286359
# Epoch 125 train accuracy = 0.955128205128
# Epoch 125 test cost = 6.75673960149
# Epoch 125 test accuracy = 0.942307692308
# Epoch 126 train cost = 1.6496437192
# Epoch 126 train accuracy = 0.962820512821
# Epoch 126 test cost = 6.92035603523
# Epoch 126 test accuracy = 0.934294871795
# Epoch 127 train cost = 1.96740641817
# Epoch 127 train accuracy = 0.971794871795
# Epoch 127 test cost = 7.16767545044
# Epoch 127 test accuracy = 0.935897435897
# Epoch 128 train cost = 2.30882727355
# Epoch 128 train accuracy = 0.952564102564
# Epoch 128 test cost = 7.42078231275
# Epoch 128 test accuracy = 0.921474358974
# Epoch 129 train cost = 1.42078833096
# Epoch 129 train accuracy = 0.973076923077
# Epoch 129 test cost = 7.814522475
# Epoch 129 test accuracy = 0.926282051282
# Epoch 130 train cost = 2.43337769434
# Epoch 130 train accuracy = 0.960256410256
# Epoch 130 test cost = 8.65145674348
# Epoch 130 test accuracy = 0.911858974359
# Epoch 131 train cost = 1.81221743114
# Epoch 131 train accuracy = 0.962820512821
# Epoch 131 test cost = 8.79463145137
# Epoch 131 test accuracy = 0.910256410256
# Epoch 132 train cost = 2.03295862675
# Epoch 132 train accuracy = 0.958974358974
# Epoch 132 test cost = 8.22823929787
# Epoch 132 test accuracy = 0.910256410256
# Epoch 133 train cost = 1.96089513972
# Epoch 133 train accuracy = 0.95641025641
# Epoch 133 test cost = 9.04615733027
# Epoch 133 test accuracy = 0.910256410256
# Epoch 134 train cost = 1.91198754124
# Epoch 134 train accuracy = 0.967948717949
# Epoch 134 test cost = 8.97924792767
# Epoch 134 test accuracy = 0.924679487179
# Epoch 135 train cost = 2.03264677897
# Epoch 135 train accuracy = 0.948717948718
# Epoch 135 test cost = 8.85341784358
# Epoch 135 test accuracy = 0.929487179487
# Epoch 136 train cost = 1.71104324795
# Epoch 136 train accuracy = 0.961538461538
# Epoch 136 test cost = 8.17759585381
# Epoch 136 test accuracy = 0.934294871795
# Epoch 137 train cost = 1.94336926751
# Epoch 137 train accuracy = 0.957692307692
# Epoch 137 test cost = 9.15428701043
# Epoch 137 test accuracy = 0.934294871795
# Epoch 138 train cost = 1.41122834012
# Epoch 138 train accuracy = 0.967948717949
# Epoch 138 test cost = 7.55347087979
# Epoch 138 test accuracy = 0.942307692308
# Epoch 139 train cost = 1.49645779841
# Epoch 139 train accuracy = 0.95641025641
# Epoch 139 test cost = 7.82741548121
# Epoch 139 test accuracy = 0.935897435897
# Epoch 140 train cost = 1.44765132666
# Epoch 140 train accuracy = 0.966666666667
# Epoch 140 test cost = 8.11848855019
# Epoch 140 test accuracy = 0.919871794872
# Epoch 141 train cost = 1.19836458098
# Epoch 141 train accuracy = 0.951282051282
# Epoch 141 test cost = 8.27189745009
# Epoch 141 test accuracy = 0.932692307692
# Epoch 142 train cost = 1.95660014637
# Epoch 142 train accuracy = 0.95641025641
# Epoch 142 test cost = 7.40888878703
# Epoch 142 test accuracy = 0.929487179487
# Epoch 143 train cost = 1.33414847776
# Epoch 143 train accuracy = 0.969230769231
# Epoch 143 test cost = 8.0285962224
# Epoch 143 test accuracy = 0.93108974359
# Epoch 144 train cost = 1.28800620511
# Epoch 144 train accuracy = 0.958974358974
# Epoch 144 test cost = 7.11934094131
# Epoch 144 test accuracy = 0.929487179487
# Epoch 145 train cost = 1.89891507477
# Epoch 145 train accuracy = 0.962820512821
# Epoch 145 test cost = 8.61401045322
# Epoch 145 test accuracy = 0.927884615385
# Epoch 146 train cost = 1.65736855753
# Epoch 146 train accuracy = 0.973076923077
# Epoch 146 test cost = 9.57379566133
# Epoch 146 test accuracy = 0.923076923077
# Epoch 147 train cost = 1.79553268477
# Epoch 147 train accuracy = 0.962820512821
# Epoch 147 test cost = 7.13665911555
# Epoch 147 test accuracy = 0.908653846154
# Epoch 148 train cost = 2.25630414579
# Epoch 148 train accuracy = 0.961538461538
# Epoch 148 test cost = 8.4653981179
# Epoch 148 test accuracy = 0.910256410256
# Epoch 149 train cost = 2.26001183875
# Epoch 149 train accuracy = 0.946153846154
# Epoch 149 test cost = 8.40108156204
# Epoch 149 test accuracy = 0.921474358974
# Epoch 150 train cost = 2.116607178
# Epoch 150 train accuracy = 0.965384615385
# Epoch 150 test cost = 8.11271819472
# Epoch 150 test accuracy = 0.934294871795
# Epoch 151 train cost = 1.79308058321
# Epoch 151 train accuracy = 0.962820512821
# Epoch 151 test cost = 8.02365627885
# Epoch 151 test accuracy = 0.93108974359
# Epoch 152 train cost = 1.98567728046
# Epoch 152 train accuracy = 0.962820512821
# Epoch 152 test cost = 8.18815040588
# Epoch 152 test accuracy = 0.918269230769
# Epoch 153 train cost = 2.23346085474
# Epoch 153 train accuracy = 0.95
# Epoch 153 test cost = 8.49105000496
# Epoch 153 test accuracy = 0.923076923077
# Epoch 154 train cost = 2.5343830213
# Epoch 154 train accuracy = 0.953846153846
# Epoch 154 test cost = 7.93972605467
# Epoch 154 test accuracy = 0.93108974359
# Epoch 155 train cost = 2.33965023234
# Epoch 155 train accuracy = 0.961538461538
# Epoch 155 test cost = 7.88155816495
# Epoch 155 test accuracy = 0.929487179487
# Epoch 156 train cost = 1.87539946288
# Epoch 156 train accuracy = 0.958974358974
# Epoch 156 test cost = 8.97946855426
# Epoch 156 test accuracy = 0.926282051282
# Epoch 157 train cost = 1.45307538658
# Epoch 157 train accuracy = 0.95641025641
# Epoch 157 test cost = 8.31788775325
# Epoch 157 test accuracy = 0.926282051282
# Epoch 158 train cost = 1.87402626872
# Epoch 158 train accuracy = 0.960256410256
# Epoch 158 test cost = 8.2546672821
# Epoch 158 test accuracy = 0.942307692308
# Epoch 159 train cost = 1.437003728
# Epoch 159 train accuracy = 0.961538461538
# Epoch 159 test cost = 8.13426879048
# Epoch 159 test accuracy = 0.934294871795
# Epoch 160 train cost = 1.76328526065
# Epoch 160 train accuracy = 0.961538461538
# Epoch 160 test cost = 7.33799257874
# Epoch 160 test accuracy = 0.924679487179
# Epoch 161 train cost = 1.43923026137
# Epoch 161 train accuracy = 0.965384615385
# Epoch 161 test cost = 7.64069840312
# Epoch 161 test accuracy = 0.934294871795
# Epoch 162 train cost = 1.52672784775
# Epoch 162 train accuracy = 0.964102564103
# Epoch 162 test cost = 7.42423427105
# Epoch 162 test accuracy = 0.935897435897
# Epoch 163 train cost = 2.10818273015
# Epoch 163 train accuracy = 0.962820512821
# Epoch 163 test cost = 6.76330604404
# Epoch 163 test accuracy = 0.942307692308
# Epoch 164 train cost = 1.18246182613
# Epoch 164 train accuracy = 0.970512820513
# Epoch 164 test cost = 8.19860801101
# Epoch 164 test accuracy = 0.948717948718
# Epoch 165 train cost = 1.42226958089
# Epoch 165 train accuracy = 0.969230769231
# Epoch 165 test cost = 8.3293236196
# Epoch 165 test accuracy = 0.942307692308
# Epoch 166 train cost = 1.19759668596
# Epoch 166 train accuracy = 0.947435897436
# Epoch 166 test cost = 8.21947687864
# Epoch 166 test accuracy = 0.939102564103
# Epoch 167 train cost = 1.25641623512
# Epoch 167 train accuracy = 0.961538461538
# Epoch 167 test cost = 5.77578747272
# Epoch 167 test accuracy = 0.929487179487
# Epoch 168 train cost = 1.47640512139
# Epoch 168 train accuracy = 0.975641025641
# Epoch 168 test cost = 7.29216131568
# Epoch 168 test accuracy = 0.947115384615
# Epoch 169 train cost = 1.22807954624
# Epoch 169 train accuracy = 0.978205128205
# Epoch 169 test cost = 7.59689390659
# Epoch 169 test accuracy = 0.947115384615
# Epoch 170 train cost = 1.21192410029
# Epoch 170 train accuracy = 0.965384615385
# Epoch 170 test cost = 7.33025969565
# Epoch 170 test accuracy = 0.945512820513
# Epoch 171 train cost = 1.28991185501
# Epoch 171 train accuracy = 0.973076923077
# Epoch 171 test cost = 7.31727835536
# Epoch 171 test accuracy = 0.947115384615
# Epoch 172 train cost = 1.58739679679
# Epoch 172 train accuracy = 0.982051282051
# Epoch 172 test cost = 7.15756361187
# Epoch 172 test accuracy = 0.947115384615
# Epoch 173 train cost = 1.82971981354
# Epoch 173 train accuracy = 0.964102564103
# Epoch 173 test cost = 8.49710294604
# Epoch 173 test accuracy = 0.934294871795
# Epoch 174 train cost = 1.27440723963
# Epoch 174 train accuracy = 0.957692307692
# Epoch 174 test cost = 7.47466239333
# Epoch 174 test accuracy = 0.939102564103
# Epoch 175 train cost = 2.33795419522
# Epoch 175 train accuracy = 0.95
# Epoch 175 test cost = 8.26375374198
# Epoch 175 test accuracy = 0.932692307692
# Epoch 176 train cost = 2.24072758108
# Epoch 176 train accuracy = 0.960256410256
# Epoch 176 test cost = 7.59346616268
# Epoch 176 test accuracy = 0.929487179487
# Epoch 177 train cost = 1.90336960927
# Epoch 177 train accuracy = 0.958974358974
# Epoch 177 test cost = 9.33610966802
# Epoch 177 test accuracy = 0.907051282051
# Epoch 178 train cost = 2.00649444759
# Epoch 178 train accuracy = 0.95641025641
# Epoch 178 test cost = 8.38573928177
# Epoch 178 test accuracy = 0.918269230769
# Epoch 179 train cost = 1.32963609323
# Epoch 179 train accuracy = 0.967948717949
# Epoch 179 test cost = 8.91066561639
# Epoch 179 test accuracy = 0.915064102564
# Epoch 180 train cost = 3.57291327789
# Epoch 180 train accuracy = 0.932051282051
# Epoch 180 test cost = 10.2315630019
# Epoch 180 test accuracy = 0.907051282051
# Epoch 181 train cost = 3.32349849492
# Epoch 181 train accuracy = 0.930769230769
# Epoch 181 test cost = 9.86998596787
# Epoch 181 test accuracy = 0.915064102564
# Epoch 182 train cost = 2.45846964419
# Epoch 182 train accuracy = 0.953846153846
# Epoch 182 test cost = 10.2172231674
# Epoch 182 test accuracy = 0.919871794872
# Epoch 183 train cost = 2.0372576043
# Epoch 183 train accuracy = 0.962820512821
# Epoch 183 test cost = 8.66369855404
# Epoch 183 test accuracy = 0.918269230769
# Epoch 184 train cost = 1.99426984508
# Epoch 184 train accuracy = 0.952564102564
# Epoch 184 test cost = 9.04706156254
# Epoch 184 test accuracy = 0.927884615385
# Epoch 185 train cost = 1.60197870806
# Epoch 185 train accuracy = 0.948717948718
# Epoch 185 test cost = 9.03809225559
# Epoch 185 test accuracy = 0.93108974359
# Epoch 186 train cost = 2.07173098996
# Epoch 186 train accuracy = 0.95
# Epoch 186 test cost = 8.68477523327
# Epoch 186 test accuracy = 0.93108974359
# Epoch 187 train cost = 1.8396965377
# Epoch 187 train accuracy = 0.961538461538
# Epoch 187 test cost = 7.76222407818
# Epoch 187 test accuracy = 0.94391025641
# Epoch 188 train cost = 1.94873452559
# Epoch 188 train accuracy = 0.95
# Epoch 188 test cost = 7.2847700119
# Epoch 188 test accuracy = 0.929487179487
# Epoch 189 train cost = 1.88948390633
# Epoch 189 train accuracy = 0.962820512821
# Epoch 189 test cost = 7.20684316754
# Epoch 189 test accuracy = 0.945512820513
# Epoch 190 train cost = 1.56895278301
# Epoch 190 train accuracy = 0.971794871795
# Epoch 190 test cost = 8.02859824896
# Epoch 190 test accuracy = 0.926282051282
# Epoch 191 train cost = 2.01408452354
# Epoch 191 train accuracy = 0.979487179487
# Epoch 191 test cost = 8.94206465781
# Epoch 191 test accuracy = 0.921474358974
# Epoch 192 train cost = 2.14189609326
# Epoch 192 train accuracy = 0.965384615385
# Epoch 192 test cost = 8.6650981009
# Epoch 192 test accuracy = 0.934294871795
# Epoch 193 train cost = 1.41810806096
# Epoch 193 train accuracy = 0.955128205128
# Epoch 193 test cost = 8.32067118585
# Epoch 193 test accuracy = 0.927884615385
# Epoch 194 train cost = 2.39703166112
# Epoch 194 train accuracy = 0.960256410256
# Epoch 194 test cost = 8.03166781366
# Epoch 194 test accuracy = 0.924679487179
# Epoch 195 train cost = 1.95441522077
# Epoch 195 train accuracy = 0.955128205128
# Epoch 195 test cost = 7.43474414945
# Epoch 195 test accuracy = 0.939102564103
# Epoch 196 train cost = 1.35416026972
# Epoch 196 train accuracy = 0.961538461538
# Epoch 196 test cost = 8.88520729542
# Epoch 196 test accuracy = 0.921474358974
# Epoch 197 train cost = 1.33320503309
# Epoch 197 train accuracy = 0.960256410256
# Epoch 197 test cost = 7.67530357093
# Epoch 197 test accuracy = 0.9375
# Epoch 198 train cost = 1.5804747534
# Epoch 198 train accuracy = 0.964102564103
# Epoch 198 test cost = 6.68670057505
# Epoch 198 test accuracy = 0.934294871795
# Epoch 199 train cost = 1.42702165619
# Epoch 199 train accuracy = 0.974358974359
# Epoch 199 test cost = 7.89098416269
# Epoch 199 test accuracy = 0.940705128205
# Epoch 200 train cost = 0.945028581657
# Epoch 200 train accuracy = 0.973076923077
# Epoch 200 test cost = 7.34867839515
# Epoch 200 test accuracy = 0.9375
# Epoch 201 train cost = 0.982845997903
# Epoch 201 train accuracy = 0.979487179487
# Epoch 201 test cost = 8.8051135242
# Epoch 201 test accuracy = 0.935897435897
# Epoch 202 train cost = 0.890797610395
# Epoch 202 train accuracy = 0.975641025641
# Epoch 202 test cost = 7.78084681183
# Epoch 202 test accuracy = 0.9375
# Epoch 203 train cost = 0.856713333167
# Epoch 203 train accuracy = 0.974358974359
# Epoch 203 test cost = 7.9494189322
# Epoch 203 test accuracy = 0.94391025641
# Epoch 204 train cost = 0.915903009474
# Epoch 204 train accuracy = 0.980769230769
# Epoch 204 test cost = 7.74060451984
# Epoch 204 test accuracy = 0.929487179487
# Epoch 205 train cost = 0.972110630944
# Epoch 205 train accuracy = 0.969230769231
# Epoch 205 test cost = 8.57809387147
# Epoch 205 test accuracy = 0.929487179487
# Epoch 206 train cost = 1.22260237485
# Epoch 206 train accuracy = 0.962820512821
# Epoch 206 test cost = 7.71542821825
# Epoch 206 test accuracy = 0.932692307692
# Epoch 207 train cost = 2.08105210215
# Epoch 207 train accuracy = 0.966666666667
# Epoch 207 test cost = 6.97285038233
# Epoch 207 test accuracy = 0.9375
# Epoch 208 train cost = 1.57565525919
# Epoch 208 train accuracy = 0.971794871795
# Epoch 208 test cost = 8.59139946103
# Epoch 208 test accuracy = 0.935897435897
# Epoch 209 train cost = 1.61559061706
# Epoch 209 train accuracy = 0.971794871795
# Epoch 209 test cost = 9.59926527739
# Epoch 209 test accuracy = 0.93108974359
# Epoch 210 train cost = 1.58568034694
# Epoch 210 train accuracy = 0.966666666667
# Epoch 210 test cost = 7.64253935218
# Epoch 210 test accuracy = 0.910256410256
# Epoch 211 train cost = 1.28250314016
# Epoch 211 train accuracy = 0.962820512821
# Epoch 211 test cost = 8.35372522473
# Epoch 211 test accuracy = 0.918269230769
# Epoch 212 train cost = 1.74215366691
# Epoch 212 train accuracy = 0.953846153846
# Epoch 212 test cost = 8.82700526714
# Epoch 212 test accuracy = 0.923076923077
# Epoch 213 train cost = 1.56364210881
# Epoch 213 train accuracy = 0.951282051282
# Epoch 213 test cost = 6.2665554136
# Epoch 213 test accuracy = 0.93108974359
# Epoch 214 train cost = 1.11002881732
# Epoch 214 train accuracy = 0.964102564103
# Epoch 214 test cost = 7.28167968243
# Epoch 214 test accuracy = 0.948717948718
# Epoch 215 train cost = 1.21626094822
# Epoch 215 train accuracy = 0.967948717949
# Epoch 215 test cost = 6.51191884279
# Epoch 215 test accuracy = 0.945512820513
# Epoch 216 train cost = 1.12033340614
# Epoch 216 train accuracy = 0.965384615385
# Epoch 216 test cost = 7.03093856573
# Epoch 216 test accuracy = 0.934294871795
# Epoch 217 train cost = 1.02311438788
# Epoch 217 train accuracy = 0.983333333333
# Epoch 217 test cost = 8.33386607468
# Epoch 217 test accuracy = 0.9375
# Epoch 218 train cost = 0.855630649719
# Epoch 218 train accuracy = 0.961538461538
# Epoch 218 test cost = 6.42191410065
# Epoch 218 test accuracy = 0.94391025641
# Epoch 219 train cost = 1.3456828706
# Epoch 219 train accuracy = 0.974358974359
# Epoch 219 test cost = 9.97538429499
# Epoch 219 test accuracy = 0.9375
# Epoch 220 train cost = 1.25331926253
# Epoch 220 train accuracy = 0.969230769231
# Epoch 220 test cost = 8.3801419735
# Epoch 220 test accuracy = 0.945512820513
# Epoch 221 train cost = 1.00198881514
# Epoch 221 train accuracy = 0.966666666667
# Epoch 221 test cost = 7.38231851161
# Epoch 221 test accuracy = 0.939102564103
# Epoch 222 train cost = 0.847446414642
# Epoch 222 train accuracy = 0.978205128205
# Epoch 222 test cost = 8.24615094066
# Epoch 222 test accuracy = 0.942307692308
# Epoch 223 train cost = 1.57894332893
# Epoch 223 train accuracy = 0.983333333333
# Epoch 223 test cost = 8.09778483212
# Epoch 223 test accuracy = 0.934294871795
# Epoch 224 train cost = 1.73529561143
# Epoch 224 train accuracy = 0.958974358974
# Epoch 224 test cost = 8.6825709343
# Epoch 224 test accuracy = 0.921474358974
# Epoch 225 train cost = 1.17516586557
# Epoch 225 train accuracy = 0.975641025641
# Epoch 225 test cost = 9.08453914523
# Epoch 225 test accuracy = 0.940705128205
# Epoch 226 train cost = 1.23413272575
# Epoch 226 train accuracy = 0.969230769231
# Epoch 226 test cost = 8.72360885143
# Epoch 226 test accuracy = 0.942307692308
# Epoch 227 train cost = 1.67463992257
# Epoch 227 train accuracy = 0.970512820513
# Epoch 227 test cost = 9.11256513
# Epoch 227 test accuracy = 0.932692307692
# Epoch 228 train cost = 1.42789207306
# Epoch 228 train accuracy = 0.966666666667
# Epoch 228 test cost = 8.36338111758
# Epoch 228 test accuracy = 0.927884615385
# Epoch 229 train cost = 1.55534198461
# Epoch 229 train accuracy = 0.969230769231
# Epoch 229 test cost = 7.78888575733
# Epoch 229 test accuracy = 0.940705128205
# Epoch 230 train cost = 1.20401891693
# Epoch 230 train accuracy = 0.975641025641
# Epoch 230 test cost = 7.63780978322
# Epoch 230 test accuracy = 0.932692307692
# Epoch 231 train cost = 1.32835357683
# Epoch 231 train accuracy = 0.975641025641
# Epoch 231 test cost = 8.23378960788
# Epoch 231 test accuracy = 0.939102564103
# Epoch 232 train cost = 1.21270613931
# Epoch 232 train accuracy = 0.961538461538
# Epoch 232 test cost = 8.32196816802
# Epoch 232 test accuracy = 0.9375
# Epoch 233 train cost = 1.09139665589
# Epoch 233 train accuracy = 0.978205128205
# Epoch 233 test cost = 7.22469893843
# Epoch 233 test accuracy = 0.935897435897
# Epoch 234 train cost = 1.20904836804
# Epoch 234 train accuracy = 0.983333333333
# Epoch 234 test cost = 9.04701328278
# Epoch 234 test accuracy = 0.926282051282
# Epoch 235 train cost = 0.949344651308
# Epoch 235 train accuracy = 0.969230769231
# Epoch 235 test cost = 7.82037560642
# Epoch 235 test accuracy = 0.942307692308
# Epoch 236 train cost = 0.904921074864
# Epoch 236 train accuracy = 0.978205128205
# Epoch 236 test cost = 7.4848074913
# Epoch 236 test accuracy = 0.929487179487
# Epoch 237 train cost = 1.25777099468
# Epoch 237 train accuracy = 0.969230769231
# Epoch 237 test cost = 8.88365423679
# Epoch 237 test accuracy = 0.94391025641
# Epoch 238 train cost = 1.86326558702
# Epoch 238 train accuracy = 0.960256410256
# Epoch 238 test cost = 10.4620660543
# Epoch 238 test accuracy = 0.918269230769
# Epoch 239 train cost = 1.87540340796
# Epoch 239 train accuracy = 0.957692307692
# Epoch 239 test cost = 8.01034720242
# Epoch 239 test accuracy = 0.942307692308
# Epoch 240 train cost = 1.43750496954
# Epoch 240 train accuracy = 0.960256410256
# Epoch 240 test cost = 7.91297441721
# Epoch 240 test accuracy = 0.929487179487
# Epoch 241 train cost = 1.40217749495
# Epoch 241 train accuracy = 0.958974358974
# Epoch 241 test cost = 8.04963454604
# Epoch 241 test accuracy = 0.935897435897
# Epoch 242 train cost = 1.29057550617
# Epoch 242 train accuracy = 0.979487179487
# Epoch 242 test cost = 6.98285195976
# Epoch 242 test accuracy = 0.934294871795
# Epoch 243 train cost = 1.47453573346
# Epoch 243 train accuracy = 0.962820512821
# Epoch 243 test cost = 9.33270782232
# Epoch 243 test accuracy = 0.924679487179
# Epoch 244 train cost = 1.02867314965
# Epoch 244 train accuracy = 0.974358974359
# Epoch 244 test cost = 9.17417271435
# Epoch 244 test accuracy = 0.927884615385
# Epoch 245 train cost = 1.34694820084
# Epoch 245 train accuracy = 0.967948717949
# Epoch 245 test cost = 8.95128697157
# Epoch 245 test accuracy = 0.939102564103
# Epoch 246 train cost = 1.16607068945
# Epoch 246 train accuracy = 0.979487179487
# Epoch 246 test cost = 7.27539055049
# Epoch 246 test accuracy = 0.94391025641
# Epoch 247 train cost = 0.893309270963
# Epoch 247 train accuracy = 0.973076923077
# Epoch 247 test cost = 6.90301604569
# Epoch 247 test accuracy = 0.953525641026
# Epoch 248 train cost = 1.18747745268
# Epoch 248 train accuracy = 0.962820512821
# Epoch 248 test cost = 8.37163251638
# Epoch 248 test accuracy = 0.93108974359
# Epoch 249 train cost = 1.56767828204
# Epoch 249 train accuracy = 0.966666666667
# Epoch 249 test cost = 8.57252684236
# Epoch 249 test accuracy = 0.94391025641
# Epoch 250 train cost = 1.87387746572
# Epoch 250 train accuracy = 0.957692307692
# Epoch 250 test cost = 9.63976565003
# Epoch 250 test accuracy = 0.921474358974
# Epoch 251 train cost = 2.02586562932
# Epoch 251 train accuracy = 0.958974358974
# Epoch 251 test cost = 9.63923573494
# Epoch 251 test accuracy = 0.923076923077
# Epoch 252 train cost = 1.91948343115
# Epoch 252 train accuracy = 0.957692307692
# Epoch 252 test cost = 9.19042688608
# Epoch 252 test accuracy = 0.93108974359
# Epoch 253 train cost = 1.56740757637
# Epoch 253 train accuracy = 0.948717948718
# Epoch 253 test cost = 8.13322272897
# Epoch 253 test accuracy = 0.939102564103
# Epoch 254 train cost = 1.36883396935
# Epoch 254 train accuracy = 0.964102564103
# Epoch 254 test cost = 7.41085249186
# Epoch 254 test accuracy = 0.939102564103
# Epoch 255 train cost = 1.11579248309
# Epoch 255 train accuracy = 0.958974358974
# Epoch 255 test cost = 7.57436785102
# Epoch 255 test accuracy = 0.94391025641
# Epoch 256 train cost = 1.18811934534
# Epoch 256 train accuracy = 0.969230769231
# Epoch 256 test cost = 8.52404785156
# Epoch 256 test accuracy = 0.942307692308
# Epoch 257 train cost = 0.996200772002
# Epoch 257 train accuracy = 0.964102564103
# Epoch 257 test cost = 8.83002356067
# Epoch 257 test accuracy = 0.93108974359
# Epoch 258 train cost = 1.04999042768
# Epoch 258 train accuracy = 0.971794871795
# Epoch 258 test cost = 8.86714372039
# Epoch 258 test accuracy = 0.942307692308
# Epoch 259 train cost = 1.35348188551
# Epoch 259 train accuracy = 0.974358974359
# Epoch 259 test cost = 7.55982281268
# Epoch 259 test accuracy = 0.934294871795
# Epoch 260 train cost = 1.06739943102
# Epoch 260 train accuracy = 0.974358974359
# Epoch 260 test cost = 7.34241658449
# Epoch 260 test accuracy = 0.939102564103
# Epoch 261 train cost = 1.30538804806
# Epoch 261 train accuracy = 0.973076923077
# Epoch 261 test cost = 8.05755394697
# Epoch 261 test accuracy = 0.948717948718
# Epoch 262 train cost = 1.18613669183
# Epoch 262 train accuracy = 0.969230769231
# Epoch 262 test cost = 7.22916021943
# Epoch 262 test accuracy = 0.940705128205
# Epoch 263 train cost = 1.0580751705
# Epoch 263 train accuracy = 0.973076923077
# Epoch 263 test cost = 8.21933084726
# Epoch 263 test accuracy = 0.934294871795
# Epoch 264 train cost = 1.7679995466
# Epoch 264 train accuracy = 0.969230769231
# Epoch 264 test cost = 10.0454474986
# Epoch 264 test accuracy = 0.926282051282
# Epoch 265 train cost = 0.944977796637
# Epoch 265 train accuracy = 0.960256410256
# Epoch 265 test cost = 9.74531245232
# Epoch 265 test accuracy = 0.916666666667
# Epoch 266 train cost = 1.41588293482
# Epoch 266 train accuracy = 0.969230769231
# Epoch 266 test cost = 9.458627671
# Epoch 266 test accuracy = 0.929487179487
# Epoch 267 train cost = 1.61730750278
# Epoch 267 train accuracy = 0.976923076923
# Epoch 267 test cost = 10.054479748
# Epoch 267 test accuracy = 0.93108974359
# Epoch 268 train cost = 1.32591047511
# Epoch 268 train accuracy = 0.976923076923
# Epoch 268 test cost = 8.49235266447
# Epoch 268 test accuracy = 0.93108974359
# Epoch 269 train cost = 1.69569111522
# Epoch 269 train accuracy = 0.965384615385
# Epoch 269 test cost = 8.36333549023
# Epoch 269 test accuracy = 0.929487179487
# Epoch 270 train cost = 1.8343391344
# Epoch 270 train accuracy = 0.966666666667
# Epoch 270 test cost = 8.56915315986
# Epoch 270 test accuracy = 0.924679487179
# Epoch 271 train cost = 1.98951813858
# Epoch 271 train accuracy = 0.967948717949
# Epoch 271 test cost = 9.08509659767
# Epoch 271 test accuracy = 0.926282051282
# Epoch 272 train cost = 2.54774158262
# Epoch 272 train accuracy = 0.955128205128
# Epoch 272 test cost = 8.79726010561
# Epoch 272 test accuracy = 0.940705128205
# Epoch 273 train cost = 1.64225055836
# Epoch 273 train accuracy = 0.942307692308
# Epoch 273 test cost = 9.25654095411
# Epoch 273 test accuracy = 0.929487179487
# Epoch 274 train cost = 1.90973540209
# Epoch 274 train accuracy = 0.967948717949
# Epoch 274 test cost = 9.49162271619
# Epoch 274 test accuracy = 0.926282051282
# Epoch 275 train cost = 2.07315331697
# Epoch 275 train accuracy = 0.95
# Epoch 275 test cost = 9.23942196369
# Epoch 275 test accuracy = 0.923076923077
# Epoch 276 train cost = 1.50537163951
# Epoch 276 train accuracy = 0.960256410256
# Epoch 276 test cost = 10.2182173431
# Epoch 276 test accuracy = 0.924679487179
# Epoch 277 train cost = 1.53297386318
# Epoch 277 train accuracy = 0.962820512821
# Epoch 277 test cost = 8.88867142797
# Epoch 277 test accuracy = 0.923076923077
# Epoch 278 train cost = 1.35834908485
# Epoch 278 train accuracy = 0.952564102564
# Epoch 278 test cost = 9.31388519704
# Epoch 278 test accuracy = 0.932692307692
# Epoch 279 train cost = 2.03209971823
# Epoch 279 train accuracy = 0.973076923077
# Epoch 279 test cost = 7.55560818315
# Epoch 279 test accuracy = 0.939102564103
# Epoch 280 train cost = 1.36859052256
# Epoch 280 train accuracy = 0.982051282051
# Epoch 280 test cost = 7.32913115621
# Epoch 280 test accuracy = 0.942307692308
# Epoch 281 train cost = 1.07765713334
# Epoch 281 train accuracy = 0.974358974359
# Epoch 281 test cost = 7.75315096974
# Epoch 281 test accuracy = 0.956730769231
# Epoch 282 train cost = 1.43507339526
# Epoch 282 train accuracy = 0.974358974359
# Epoch 282 test cost = 8.4985294044
# Epoch 282 test accuracy = 0.940705128205
# Epoch 283 train cost = 1.02145466255
# Epoch 283 train accuracy = 0.980769230769
# Epoch 283 test cost = 7.6123239398
# Epoch 283 test accuracy = 0.945512820513
# Epoch 284 train cost = 0.728680926142
# Epoch 284 train accuracy = 0.966666666667
# Epoch 284 test cost = 7.31310021877
# Epoch 284 test accuracy = 0.950320512821
# Epoch 285 train cost = 0.931280480698
# Epoch 285 train accuracy = 0.969230769231
# Epoch 285 test cost = 7.72667679191
# Epoch 285 test accuracy = 0.94391025641
# Epoch 286 train cost = 1.20277702715
# Epoch 286 train accuracy = 0.982051282051
# Epoch 286 test cost = 8.06218275428
# Epoch 286 test accuracy = 0.942307692308
# Epoch 287 train cost = 1.28761623055
# Epoch 287 train accuracy = 0.969230769231
# Epoch 287 test cost = 8.43807047606
# Epoch 287 test accuracy = 0.9375
# Epoch 288 train cost = 0.886026216671
# Epoch 288 train accuracy = 0.985897435897
# Epoch 288 test cost = 8.49333396554
# Epoch 288 test accuracy = 0.942307692308
# Epoch 289 train cost = 0.729985184968
# Epoch 289 train accuracy = 0.983333333333
# Epoch 289 test cost = 7.34976989031
# Epoch 289 test accuracy = 0.929487179487
# Epoch 290 train cost = 1.15501358919
# Epoch 290 train accuracy = 0.975641025641
# Epoch 290 test cost = 6.66409471631
# Epoch 290 test accuracy = 0.939102564103
# Epoch 291 train cost = 0.859134330647
# Epoch 291 train accuracy = 0.984615384615
# Epoch 291 test cost = 8.27146175504
# Epoch 291 test accuracy = 0.940705128205
# Epoch 292 train cost = 0.774178285152
# Epoch 292 train accuracy = 0.983333333333
# Epoch 292 test cost = 7.58640390635
# Epoch 292 test accuracy = 0.950320512821
# Epoch 293 train cost = 0.942231341265
# Epoch 293 train accuracy = 0.983333333333
# Epoch 293 test cost = 6.31561115384
# Epoch 293 test accuracy = 0.940705128205
# Epoch 294 train cost = 0.631010376383
# Epoch 294 train accuracy = 0.982051282051
# Epoch 294 test cost = 7.55755287409
# Epoch 294 test accuracy = 0.929487179487
# Epoch 295 train cost = 1.05425303499
# Epoch 295 train accuracy = 0.989743589744
# Epoch 295 test cost = 8.15582461655
# Epoch 295 test accuracy = 0.935897435897
# Epoch 296 train cost = 0.713546257582
# Epoch 296 train accuracy = 0.980769230769
# Epoch 296 test cost = 9.31827071309
# Epoch 296 test accuracy = 0.929487179487
# Epoch 297 train cost = 0.900715629105
# Epoch 297 train accuracy = 0.979487179487
# Epoch 297 test cost = 8.00838977098
# Epoch 297 test accuracy = 0.939102564103
# Epoch 298 train cost = 1.19290802069
# Epoch 298 train accuracy = 0.979487179487
# Epoch 298 test cost = 8.85100531578
# Epoch 298 test accuracy = 0.942307692308
# Epoch 299 train cost = 1.0107969176
# Epoch 299 train accuracy = 0.984615384615
# Epoch 299 test cost = 7.15128643811
# Epoch 299 test accuracy = 0.939102564103

# %%
# %matplotlib inline
plt.figure(1)
plt.plot(cost_train, 'c', cost_test, 'r', linewidth=2.0)
plt.legend(("cost_train", "cost_test"),'upper left')

plt.figure(2)
plt.plot(accuracy_train, 'y', accuracy_test, 'b', linewidth=2.0)
plt.legend(("accuracy_train", "accuracy_test"),'lower left')

print "train max", np.max(accuracy_train), " is at", np.argmax(accuracy_train), "epoch \n"  
print "test max", np.max(accuracy_test), " is at", np.argmax(accuracy_test), "epoch \n"  
#plt.show()
# Out:
# train max 0.989743589744  is at 295 epoch
#
# test max 0.956730769231  is at 281 epoch
